# %%
import pandas as pd
from pandas import DataFrame as df
from scipy.stats import ttest_ind, mannwhitneyu

fold1 =  [{'tn': 24744.0, 'fp': 300.0, 'fn': 314.0, 'tp': 5745.0, 'precision': 0.9504, 'recall': 0.9482, 'AUCPRC': 0.9942, 'F1': 0.9493, 'ROCAUC': 0.9985, 'MCC': 0.937, 'ACC': 0.9803, 'GMEAN': 0.9679, 'model_name': '10pct_iterative'}, {'tn': 24732.0, 'fp': 312.0, 'fn': 311.0, 'tp': 5748.0, 'precision': 0.9485, 'recall': 0.9487, 'AUCPRC': 0.9941, 'F1': 0.9486, 'ROCAUC': 0.9985, 'MCC': 0.9362, 'ACC': 0.98, 'GMEAN': 0.9679, 'model_name': '20pct_iterative'}, {'tn': 24745.0, 'fp': 299.0, 'fn': 326.0, 'tp': 5733.0, 'precision': 0.9504, 'recall': 0.9462, 'AUCPRC': 0.994, 'F1': 0.9483, 'ROCAUC': 0.9985, 'MCC': 0.9358, 'ACC': 0.9799, 'GMEAN': 0.9669, 'model_name': '30pct_iterative'}, {'tn': 24743.0, 'fp': 301.0, 'fn': 331.0, 'tp': 5728.0, 'precision': 0.9501, 'recall': 0.9454, 'AUCPRC': 0.994, 'F1': 0.9477, 'ROCAUC': 0.9985, 'MCC': 0.9351, 'ACC': 0.9797, 'GMEAN': 0.9664, 'model_name': '50pct_iterative'}, {'tn': 24751.0, 'fp': 293.0, 'fn': 332.0, 'tp': 5727.0, 'precision': 0.9513, 'recall': 0.9452, 'AUCPRC': 0.9941, 'F1': 0.9483, 'ROCAUC': 0.9985, 'MCC': 0.9358, 'ACC': 0.9799, 'GMEAN': 0.9665, 'model_name': '10pct_mean'}, {'tn': 24730.0, 'fp': 314.0, 'fn': 305.0, 'tp': 5754.0, 'precision': 0.9483, 'recall': 0.9497, 'AUCPRC': 0.9942, 'F1': 0.949, 'ROCAUC': 0.9985, 'MCC': 0.9366, 'ACC': 0.9801, 'GMEAN': 0.9684, 'model_name': '10pct_median'}, {'tn': 24742.0, 'fp': 302.0, 'fn': 326.0, 'tp': 5733.0, 'precision': 0.95, 'recall': 0.9462, 'AUCPRC': 0.994, 'F1': 0.9481, 'ROCAUC': 0.9985, 'MCC': 0.9355, 'ACC': 0.9798, 'GMEAN': 0.9668, 'model_name': '20pct_mean'}, {'tn': 24715.0, 'fp': 329.0, 'fn': 295.0, 'tp': 5764.0, 'precision': 0.946, 'recall': 0.9513, 'AUCPRC': 0.9941, 'F1': 0.9487, 'ROCAUC': 0.9985, 'MCC': 0.9362, 'ACC': 0.9799, 'GMEAN': 0.9689, 'model_name': '20pct_median'}, {'tn': 24746.0, 'fp': 298.0, 'fn': 332.0, 'tp': 5727.0, 'precision': 0.9505, 'recall': 0.9452, 'AUCPRC': 0.994, 'F1': 0.9479, 'ROCAUC': 0.9985, 'MCC': 0.9353, 'ACC': 0.9797, 'GMEAN': 0.9664, 'model_name': '30pct_mean'}, {'tn': 24723.0, 'fp': 321.0, 'fn': 305.0, 'tp': 5754.0, 'precision': 0.9472, 'recall': 0.9497, 'AUCPRC': 0.994, 'F1': 0.9484, 'ROCAUC': 0.9985, 'MCC': 0.9359, 'ACC': 0.9799, 'GMEAN': 0.9682, 'model_name': '30pct_median'}, {'tn': 24742.0, 'fp': 302.0, 'fn': 324.0, 'tp': 5735.0, 'precision': 0.95, 'recall': 0.9465, 'AUCPRC': 0.9942, 'F1': 0.9482, 'ROCAUC': 0.9985, 'MCC': 0.9358, 'ACC': 0.9799, 'GMEAN': 0.967, 'model_name': '50pct_mean'}, {'tn': 24730.0, 'fp': 314.0, 'fn': 313.0, 'tp': 5746.0, 'precision': 0.9482, 'recall': 0.9483, 'AUCPRC': 0.994, 'F1': 0.9483, 'ROCAUC': 0.9985, 'MCC': 0.9357, 'ACC': 0.9798, 'GMEAN': 0.9677, 'model_name': '50pct_median'}]

fold2 = [{'tn': 24800.0, 'fp': 244.0, 'fn': 355.0, 'tp': 5704.0, 'precision': 0.959, 'recall': 0.9414, 'AUCPRC': 0.9945, 'F1': 0.9501, 'ROCAUC': 0.9986, 'MCC': 0.9382, 'ACC': 0.9807, 'GMEAN': 0.9655, 'model_name': '10pct_iterative'}, {'tn': 24742.0, 'fp': 302.0, 'fn': 278.0, 'tp': 5781.0, 'precision': 0.9504, 'recall': 0.9541, 'AUCPRC': 0.9945, 'F1': 0.9522, 'ROCAUC': 0.9986, 'MCC': 0.9406, 'ACC': 0.9814, 'GMEAN': 0.9709, 'model_name': '20pct_iterative'}, {'tn': 24712.0, 'fp': 332.0, 'fn': 251.0, 'tp': 5808.0, 'precision': 0.9459, 'recall': 0.9586, 'AUCPRC': 0.9945, 'F1': 0.9522, 'ROCAUC': 0.9986, 'MCC': 0.9406, 'ACC': 0.9813, 'GMEAN': 0.9726, 'model_name': '30pct_iterative'}, {'tn': 24715.0, 'fp': 329.0, 'fn': 262.0, 'tp': 5797.0, 'precision': 0.9463, 'recall': 0.9568, 'AUCPRC': 0.9945, 'F1': 0.9515, 'ROCAUC': 0.9986, 'MCC': 0.9397, 'ACC': 0.981, 'GMEAN': 0.9717, 'model_name': '50pct_iterative'}, {'tn': 24746.0, 'fp': 298.0, 'fn': 282.0, 'tp': 5777.0, 'precision': 0.9509, 'recall': 0.9535, 'AUCPRC': 0.9947, 'F1': 0.9522, 'ROCAUC': 0.9987, 'MCC': 0.9406, 'ACC': 0.9814, 'GMEAN': 0.9706, 'model_name': '10pct_mean'}, {'tn': 24672.0, 'fp': 372.0, 'fn': 282.0, 'tp': 5777.0, 'precision': 0.9395, 'recall': 0.9535, 'AUCPRC': 0.9941, 'F1': 0.9464, 'ROCAUC': 0.9985, 'MCC': 0.9334, 'ACC': 0.979, 'GMEAN': 0.9692, 'model_name': '10pct_median'}, {'tn': 24744.0, 'fp': 300.0, 'fn': 280.0, 'tp': 5779.0, 'precision': 0.9506, 'recall': 0.9538, 'AUCPRC': 0.9946, 'F1': 0.9522, 'ROCAUC': 0.9986, 'MCC': 0.9406, 'ACC': 0.9814, 'GMEAN': 0.9708, 'model_name': '20pct_mean'}, {'tn': 24692.0, 'fp': 352.0, 'fn': 301.0, 'tp': 5758.0, 'precision': 0.9424, 'recall': 0.9503, 'AUCPRC': 0.9943, 'F1': 0.9463, 'ROCAUC': 0.9986, 'MCC': 0.9333, 'ACC': 0.979, 'GMEAN': 0.968, 'model_name': '20pct_median'}, {'tn': 24711.0, 'fp': 333.0, 'fn': 252.0, 'tp': 5807.0, 'precision': 0.9458, 'recall': 0.9584, 'AUCPRC': 0.9946, 'F1': 0.952, 'ROCAUC': 0.9986, 'MCC': 0.9404, 'ACC': 0.9812, 'GMEAN': 0.9725, 'model_name': '30pct_mean'}, {'tn': 24655.0, 'fp': 389.0, 'fn': 262.0, 'tp': 5797.0, 'precision': 0.9371, 'recall': 0.9568, 'AUCPRC': 0.9942, 'F1': 0.9468, 'ROCAUC': 0.9985, 'MCC': 0.9339, 'ACC': 0.9791, 'GMEAN': 0.9705, 'model_name': '30pct_median'}, {'tn': 24712.0, 'fp': 332.0, 'fn': 264.0, 'tp': 5795.0, 'precision': 0.9458, 'recall': 0.9564, 'AUCPRC': 0.9944, 'F1': 0.9511, 'ROCAUC': 0.9986, 'MCC': 0.9392, 'ACC': 0.9808, 'GMEAN': 0.9715, 'model_name': '50pct_mean'}, {'tn': 24713.0, 'fp': 331.0, 'fn': 268.0, 'tp': 5791.0, 'precision': 0.9459, 'recall': 0.9558, 'AUCPRC': 0.9943, 'F1': 0.9508, 'ROCAUC': 0.9986, 'MCC': 0.9389, 'ACC': 0.9807, 'GMEAN': 0.9712, 'model_name': '50pct_median'}]

fold3 =  [{'tn': 24729.0, 'fp': 315.0, 'fn': 284.0, 'tp': 5775.0, 'precision': 0.9483, 'recall': 0.9531, 'AUCPRC': 0.9947, 'F1': 0.9507, 'ROCAUC': 0.9987, 'MCC': 0.9387, 'ACC': 0.9807, 'GMEAN': 0.9701, 'model_name': '10pct_iterative'}, {'tn': 24671.0, 'fp': 373.0, 'fn': 281.0, 'tp': 5778.0, 'precision': 0.9394, 'recall': 0.9536, 'AUCPRC': 0.9942, 'F1': 0.9464, 'ROCAUC': 0.9986, 'MCC': 0.9334, 'ACC': 0.979, 'GMEAN': 0.9692, 'model_name': '20pct_iterative'}, {'tn': 24717.0, 'fp': 327.0, 'fn': 274.0, 'tp': 5785.0, 'precision': 0.9465, 'recall': 0.9548, 'AUCPRC': 0.9947, 'F1': 0.9506, 'ROCAUC': 0.9987, 'MCC': 0.9386, 'ACC': 0.9807, 'GMEAN': 0.9707, 'model_name': '30pct_iterative'}, {'tn': 24739.0, 'fp': 305.0, 'fn': 286.0, 'tp': 5773.0, 'precision': 0.9498, 'recall': 0.9528, 'AUCPRC': 0.9946, 'F1': 0.9513, 'ROCAUC': 0.9987, 'MCC': 0.9395, 'ACC': 0.981, 'GMEAN': 0.9702, 'model_name': '50pct_iterative'}, {'tn': 24727.0, 'fp': 317.0, 'fn': 278.0, 'tp': 5781.0, 'precision': 0.948, 'recall': 0.9541, 'AUCPRC': 0.9947, 'F1': 0.9511, 'ROCAUC': 0.9987, 'MCC': 0.9392, 'ACC': 0.9809, 'GMEAN': 0.9706, 'model_name': '10pct_mean'}, {'tn': 24730.0, 'fp': 314.0, 'fn': 282.0, 'tp': 5777.0, 'precision': 0.9484, 'recall': 0.9535, 'AUCPRC': 0.9947, 'F1': 0.9509, 'ROCAUC': 0.9987, 'MCC': 0.939, 'ACC': 0.9808, 'GMEAN': 0.9703, 'model_name': '10pct_median'}, {'tn': 24720.0, 'fp': 324.0, 'fn': 282.0, 'tp': 5777.0, 'precision': 0.9469, 'recall': 0.9535, 'AUCPRC': 0.9946, 'F1': 0.9502, 'ROCAUC': 0.9987, 'MCC': 0.9381, 'ACC': 0.9805, 'GMEAN': 0.9701, 'model_name': '20pct_mean'}, {'tn': 24725.0, 'fp': 319.0, 'fn': 279.0, 'tp': 5780.0, 'precision': 0.9477, 'recall': 0.954, 'AUCPRC': 0.9947, 'F1': 0.9508, 'ROCAUC': 0.9987, 'MCC': 0.9389, 'ACC': 0.9808, 'GMEAN': 0.9705, 'model_name': '20pct_median'}, {'tn': 24725.0, 'fp': 319.0, 'fn': 281.0, 'tp': 5778.0, 'precision': 0.9477, 'recall': 0.9536, 'AUCPRC': 0.9947, 'F1': 0.9506, 'ROCAUC': 0.9987, 'MCC': 0.9387, 'ACC': 0.9807, 'GMEAN': 0.9703, 'model_name': '30pct_mean'}, {'tn': 24715.0, 'fp': 329.0, 'fn': 259.0, 'tp': 5800.0, 'precision': 0.9463, 'recall': 0.9573, 'AUCPRC': 0.9948, 'F1': 0.9518, 'ROCAUC': 0.9987, 'MCC': 0.94, 'ACC': 0.9811, 'GMEAN': 0.9719, 'model_name': '30pct_median'}, {'tn': 24745.0, 'fp': 299.0, 'fn': 298.0, 'tp': 5761.0, 'precision': 0.9507, 'recall': 0.9508, 'AUCPRC': 0.9946, 'F1': 0.9507, 'ROCAUC': 0.9986, 'MCC': 0.9388, 'ACC': 0.9808, 'GMEAN': 0.9693, 'model_name': '50pct_mean'}, {'tn': 24741.0, 'fp': 303.0, 'fn': 291.0, 'tp': 5768.0, 'precision': 0.9501, 'recall': 0.952, 'AUCPRC': 0.9946, 'F1': 0.951, 'ROCAUC': 0.9987, 'MCC': 0.9392, 'ACC': 0.9809, 'GMEAN': 0.9698, 'model_name': '50pct_median'}]

fold4 = [{'tn': 24745.0, 'fp': 298.0, 'fn': 277.0, 'tp': 5783.0, 'precision': 0.951, 'recall': 0.9543, 'AUCPRC': 0.995, 'F1': 0.9526, 'ROCAUC': 0.9988, 'MCC': 0.9412, 'ACC': 0.9815, 'GMEAN': 0.971, 'model_name': '10pct_iterative'}, {'tn': 24741.0, 'fp': 302.0, 'fn': 282.0, 'tp': 5778.0, 'precision': 0.9503, 'recall': 0.9535, 'AUCPRC': 0.9949, 'F1': 0.9519, 'ROCAUC': 0.9987, 'MCC': 0.9402, 'ACC': 0.9812, 'GMEAN': 0.9705, 'model_name': '20pct_iterative'}, {'tn': 24793.0, 'fp': 250.0, 'fn': 351.0, 'tp': 5709.0, 'precision': 0.958, 'recall': 0.9421, 'AUCPRC': 0.9949, 'F1': 0.95, 'ROCAUC': 0.9987, 'MCC': 0.9381, 'ACC': 0.9807, 'GMEAN': 0.9658, 'model_name': '30pct_iterative'}, {'tn': 24723.0, 'fp': 320.0, 'fn': 277.0, 'tp': 5783.0, 'precision': 0.9476, 'recall': 0.9543, 'AUCPRC': 0.9948, 'F1': 0.9509, 'ROCAUC': 0.9987, 'MCC': 0.939, 'ACC': 0.9808, 'GMEAN': 0.9706, 'model_name': '50pct_iterative'}, {'tn': 24724.0, 'fp': 319.0, 'fn': 271.0, 'tp': 5789.0, 'precision': 0.9478, 'recall': 0.9553, 'AUCPRC': 0.9949, 'F1': 0.9515, 'ROCAUC': 0.9987, 'MCC': 0.9397, 'ACC': 0.981, 'GMEAN': 0.9711, 'model_name': '10pct_mean'}, {'tn': 24732.0, 'fp': 311.0, 'fn': 260.0, 'tp': 5800.0, 'precision': 0.9491, 'recall': 0.9571, 'AUCPRC': 0.9951, 'F1': 0.9531, 'ROCAUC': 0.9988, 'MCC': 0.9417, 'ACC': 0.9816, 'GMEAN': 0.9722, 'model_name': '10pct_median'}, {'tn': 24745.0, 'fp': 298.0, 'fn': 286.0, 'tp': 5774.0, 'precision': 0.9509, 'recall': 0.9528, 'AUCPRC': 0.9949, 'F1': 0.9519, 'ROCAUC': 0.9987, 'MCC': 0.9402, 'ACC': 0.9812, 'GMEAN': 0.9703, 'model_name': '20pct_mean'}, {'tn': 24727.0, 'fp': 316.0, 'fn': 262.0, 'tp': 5798.0, 'precision': 0.9483, 'recall': 0.9568, 'AUCPRC': 0.9949, 'F1': 0.9525, 'ROCAUC': 0.9987, 'MCC': 0.941, 'ACC': 0.9814, 'GMEAN': 0.972, 'model_name': '20pct_median'}, {'tn': 24747.0, 'fp': 296.0, 'fn': 284.0, 'tp': 5776.0, 'precision': 0.9513, 'recall': 0.9531, 'AUCPRC': 0.995, 'F1': 0.9522, 'ROCAUC': 0.9987, 'MCC': 0.9406, 'ACC': 0.9814, 'GMEAN': 0.9705, 'model_name': '30pct_mean'}, {'tn': 24736.0, 'fp': 307.0, 'fn': 275.0, 'tp': 5785.0, 'precision': 0.9496, 'recall': 0.9546, 'AUCPRC': 0.995, 'F1': 0.9521, 'ROCAUC': 0.9987, 'MCC': 0.9405, 'ACC': 0.9813, 'GMEAN': 0.971, 'model_name': '30pct_median'}, {'tn': 24750.0, 'fp': 293.0, 'fn': 301.0, 'tp': 5759.0, 'precision': 0.9516, 'recall': 0.9503, 'AUCPRC': 0.9948, 'F1': 0.951, 'ROCAUC': 0.9987, 'MCC': 0.9391, 'ACC': 0.9809, 'GMEAN': 0.9691, 'model_name': '50pct_mean'}, {'tn': 24723.0, 'fp': 320.0, 'fn': 274.0, 'tp': 5786.0, 'precision': 0.9476, 'recall': 0.9548, 'AUCPRC': 0.9948, 'F1': 0.9512, 'ROCAUC': 0.9987, 'MCC': 0.9393, 'ACC': 0.9809, 'GMEAN': 0.9709, 'model_name': '50pct_median'}]

fold5 = [{'tn': 24744.0, 'fp': 300.0, 'fn': 287.0, 'tp': 5772.0, 'precision': 0.9506, 'recall': 0.9526, 'AUCPRC': 0.9946, 'F1': 0.9516, 'ROCAUC': 0.9986, 'MCC': 0.9399, 'ACC': 0.9811, 'GMEAN': 0.9702, 'model_name': '10pct_iterative'}, {'tn': 24750.0, 'fp': 294.0, 'fn': 286.0, 'tp': 5773.0, 'precision': 0.9515, 'recall': 0.9528, 'AUCPRC': 0.9945, 'F1': 0.9522, 'ROCAUC': 0.9986, 'MCC': 0.9406, 'ACC': 0.9814, 'GMEAN': 0.9704, 'model_name': '20pct_iterative'}, {'tn': 24774.0, 'fp': 270.0, 'fn': 317.0, 'tp': 5742.0, 'precision': 0.9551, 'recall': 0.9477, 'AUCPRC': 0.9944, 'F1': 0.9514, 'ROCAUC': 0.9986, 'MCC': 0.9397, 'ACC': 0.9811, 'GMEAN': 0.9682, 'model_name': '30pct_iterative'}, {'tn': 24769.0, 'fp': 275.0, 'fn': 300.0, 'tp': 5759.0, 'precision': 0.9544, 'recall': 0.9505, 'AUCPRC': 0.9945, 'F1': 0.9525, 'ROCAUC': 0.9986, 'MCC': 0.941, 'ACC': 0.9815, 'GMEAN': 0.9696, 'model_name': '50pct_iterative'}, {'tn': 24763.0, 'fp': 281.0, 'fn': 305.0, 'tp': 5754.0, 'precision': 0.9534, 'recall': 0.9497, 'AUCPRC': 0.9945, 'F1': 0.9515, 'ROCAUC': 0.9986, 'MCC': 0.9399, 'ACC': 0.9812, 'GMEAN': 0.969, 'model_name': '10pct_mean'}, {'tn': 24677.0, 'fp': 367.0, 'fn': 296.0, 'tp': 5763.0, 'precision': 0.9401, 'recall': 0.9511, 'AUCPRC': 0.994, 'F1': 0.9456, 'ROCAUC': 0.9985, 'MCC': 0.9324, 'ACC': 0.9787, 'GMEAN': 0.9681, 'model_name': '10pct_median'}, {'tn': 24769.0, 'fp': 275.0, 'fn': 305.0, 'tp': 5754.0, 'precision': 0.9544, 'recall': 0.9497, 'AUCPRC': 0.9945, 'F1': 0.952, 'ROCAUC': 0.9986, 'MCC': 0.9405, 'ACC': 0.9814, 'GMEAN': 0.9691, 'model_name': '20pct_mean'}, {'tn': 24773.0, 'fp': 271.0, 'fn': 307.0, 'tp': 5752.0, 'precision': 0.955, 'recall': 0.9493, 'AUCPRC': 0.9946, 'F1': 0.9522, 'ROCAUC': 0.9986, 'MCC': 0.9406, 'ACC': 0.9814, 'GMEAN': 0.9691, 'model_name': '20pct_median'}, {'tn': 24750.0, 'fp': 294.0, 'fn': 294.0, 'tp': 5765.0, 'precision': 0.9515, 'recall': 0.9515, 'AUCPRC': 0.9945, 'F1': 0.9515, 'ROCAUC': 0.9986, 'MCC': 0.9397, 'ACC': 0.9811, 'GMEAN': 0.9697, 'model_name': '30pct_mean'}, {'tn': 24756.0, 'fp': 288.0, 'fn': 301.0, 'tp': 5758.0, 'precision': 0.9524, 'recall': 0.9503, 'AUCPRC': 0.9945, 'F1': 0.9513, 'ROCAUC': 0.9986, 'MCC': 0.9396, 'ACC': 0.9811, 'GMEAN': 0.9692, 'model_name': '30pct_median'}, {'tn': 24757.0, 'fp': 287.0, 'fn': 299.0, 'tp': 5760.0, 'precision': 0.9525, 'recall': 0.9507, 'AUCPRC': 0.9944, 'F1': 0.9516, 'ROCAUC': 0.9986, 'MCC': 0.9399, 'ACC': 0.9812, 'GMEAN': 0.9694, 'model_name': '50pct_mean'}, {'tn': 24815.0, 'fp': 229.0, 'fn': 388.0, 'tp': 5671.0, 'precision': 0.9612, 'recall': 0.936, 'AUCPRC': 0.9943, 'F1': 0.9484, 'ROCAUC': 0.9986, 'MCC': 0.9363, 'ACC': 0.9802, 'GMEAN': 0.963, 'model_name': '50pct_median'}]

fold6 =  [{'tn': 24719.0, 'fp': 324.0, 'fn': 303.0, 'tp': 5757.0, 'precision': 0.9467, 'recall': 0.95, 'AUCPRC': 0.9941, 'F1': 0.9484, 'ROCAUC': 0.9985, 'MCC': 0.9358, 'ACC': 0.9798, 'GMEAN': 0.9684, 'model_name': '10pct_iterative'}, {'tn': 24750.0, 'fp': 293.0, 'fn': 334.0, 'tp': 5726.0, 'precision': 0.9513, 'recall': 0.9449, 'AUCPRC': 0.9941, 'F1': 0.9481, 'ROCAUC': 0.9985, 'MCC': 0.9356, 'ACC': 0.9798, 'GMEAN': 0.9663, 'model_name': '20pct_iterative'}, {'tn': 24732.0, 'fp': 311.0, 'fn': 317.0, 'tp': 5743.0, 'precision': 0.9486, 'recall': 0.9477, 'AUCPRC': 0.994, 'F1': 0.9482, 'ROCAUC': 0.9985, 'MCC': 0.9356, 'ACC': 0.9798, 'GMEAN': 0.9674, 'model_name': '30pct_iterative'}, {'tn': 24720.0, 'fp': 323.0, 'fn': 312.0, 'tp': 5748.0, 'precision': 0.9468, 'recall': 0.9485, 'AUCPRC': 0.9939, 'F1': 0.9477, 'ROCAUC': 0.9985, 'MCC': 0.935, 'ACC': 0.9796, 'GMEAN': 0.9676, 'model_name': '50pct_iterative'}, {'tn': 24745.0, 'fp': 298.0, 'fn': 321.0, 'tp': 5739.0, 'precision': 0.9506, 'recall': 0.947, 'AUCPRC': 0.9943, 'F1': 0.9488, 'ROCAUC': 0.9986, 'MCC': 0.9365, 'ACC': 0.9801, 'GMEAN': 0.9673, 'model_name': '10pct_mean'}, {'tn': 24728.0, 'fp': 315.0, 'fn': 313.0, 'tp': 5747.0, 'precision': 0.948, 'recall': 0.9483, 'AUCPRC': 0.994, 'F1': 0.9482, 'ROCAUC': 0.9985, 'MCC': 0.9357, 'ACC': 0.9798, 'GMEAN': 0.9677, 'model_name': '10pct_median'}, {'tn': 24744.0, 'fp': 299.0, 'fn': 328.0, 'tp': 5732.0, 'precision': 0.9504, 'recall': 0.9459, 'AUCPRC': 0.994, 'F1': 0.9481, 'ROCAUC': 0.9985, 'MCC': 0.9356, 'ACC': 0.9798, 'GMEAN': 0.9667, 'model_name': '20pct_mean'}, {'tn': 24743.0, 'fp': 300.0, 'fn': 328.0, 'tp': 5732.0, 'precision': 0.9503, 'recall': 0.9459, 'AUCPRC': 0.9941, 'F1': 0.9481, 'ROCAUC': 0.9985, 'MCC': 0.9355, 'ACC': 0.9798, 'GMEAN': 0.9667, 'model_name': '20pct_median'}, {'tn': 24719.0, 'fp': 324.0, 'fn': 305.0, 'tp': 5755.0, 'precision': 0.9467, 'recall': 0.9497, 'AUCPRC': 0.9941, 'F1': 0.9482, 'ROCAUC': 0.9985, 'MCC': 0.9356, 'ACC': 0.9798, 'GMEAN': 0.9682, 'model_name': '30pct_mean'}, {'tn': 24729.0, 'fp': 314.0, 'fn': 309.0, 'tp': 5751.0, 'precision': 0.9482, 'recall': 0.949, 'AUCPRC': 0.9941, 'F1': 0.9486, 'ROCAUC': 0.9985, 'MCC': 0.9362, 'ACC': 0.98, 'GMEAN': 0.968, 'model_name': '30pct_median'}, {'tn': 24743.0, 'fp': 300.0, 'fn': 330.0, 'tp': 5730.0, 'precision': 0.9502, 'recall': 0.9455, 'AUCPRC': 0.994, 'F1': 0.9479, 'ROCAUC': 0.9985, 'MCC': 0.9353, 'ACC': 0.9797, 'GMEAN': 0.9665, 'model_name': '50pct_mean'}, {'tn': 24734.0, 'fp': 309.0, 'fn': 322.0, 'tp': 5738.0, 'precision': 0.9489, 'recall': 0.9469, 'AUCPRC': 0.994, 'F1': 0.9479, 'ROCAUC': 0.9985, 'MCC': 0.9353, 'ACC': 0.9797, 'GMEAN': 0.967, 'model_name': '50pct_median'}]

fold7 =  [{'tn': 24765.0, 'fp': 279.0, 'fn': 275.0, 'tp': 5784.0, 'precision': 0.954, 'recall': 0.9546, 'AUCPRC': 0.9951, 'F1': 0.9543, 'ROCAUC': 0.9988, 'MCC': 0.9432, 'ACC': 0.9822, 'GMEAN': 0.9716, 'model_name': '10pct_iterative'}, {'tn': 24749.0, 'fp': 295.0, 'fn': 271.0, 'tp': 5788.0, 'precision': 0.9515, 'recall': 0.9553, 'AUCPRC': 0.995, 'F1': 0.9534, 'ROCAUC': 0.9988, 'MCC': 0.9421, 'ACC': 0.9818, 'GMEAN': 0.9716, 'model_name': '20pct_iterative'}, {'tn': 24763.0, 'fp': 281.0, 'fn': 277.0, 'tp': 5782.0, 'precision': 0.9537, 'recall': 0.9543, 'AUCPRC': 0.9951, 'F1': 0.954, 'ROCAUC': 0.9988, 'MCC': 0.9428, 'ACC': 0.9821, 'GMEAN': 0.9714, 'model_name': '30pct_iterative'}, {'tn': 24761.0, 'fp': 283.0, 'fn': 286.0, 'tp': 5773.0, 'precision': 0.9533, 'recall': 0.9528, 'AUCPRC': 0.995, 'F1': 0.953, 'ROCAUC': 0.9987, 'MCC': 0.9417, 'ACC': 0.9817, 'GMEAN': 0.9706, 'model_name': '50pct_iterative'}, {'tn': 24766.0, 'fp': 278.0, 'fn': 280.0, 'tp': 5779.0, 'precision': 0.9541, 'recall': 0.9538, 'AUCPRC': 0.9952, 'F1': 0.9539, 'ROCAUC': 0.9988, 'MCC': 0.9428, 'ACC': 0.9821, 'GMEAN': 0.9712, 'model_name': '10pct_mean'}, {'tn': 24766.0, 'fp': 278.0, 'fn': 284.0, 'tp': 5775.0, 'precision': 0.9541, 'recall': 0.9531, 'AUCPRC': 0.9951, 'F1': 0.9536, 'ROCAUC': 0.9988, 'MCC': 0.9424, 'ACC': 0.9819, 'GMEAN': 0.9708, 'model_name': '10pct_median'}, {'tn': 24765.0, 'fp': 279.0, 'fn': 291.0, 'tp': 5768.0, 'precision': 0.9539, 'recall': 0.952, 'AUCPRC': 0.995, 'F1': 0.9529, 'ROCAUC': 0.9988, 'MCC': 0.9415, 'ACC': 0.9817, 'GMEAN': 0.9702, 'model_name': '20pct_mean'}, {'tn': 24706.0, 'fp': 338.0, 'fn': 282.0, 'tp': 5777.0, 'precision': 0.9447, 'recall': 0.9535, 'AUCPRC': 0.9947, 'F1': 0.9491, 'ROCAUC': 0.9987, 'MCC': 0.9367, 'ACC': 0.9801, 'GMEAN': 0.9698, 'model_name': '20pct_median'}, {'tn': 24765.0, 'fp': 279.0, 'fn': 287.0, 'tp': 5772.0, 'precision': 0.9539, 'recall': 0.9526, 'AUCPRC': 0.995, 'F1': 0.9533, 'ROCAUC': 0.9987, 'MCC': 0.942, 'ACC': 0.9818, 'GMEAN': 0.9706, 'model_name': '30pct_mean'}, {'tn': 24750.0, 'fp': 294.0, 'fn': 278.0, 'tp': 5781.0, 'precision': 0.9516, 'recall': 0.9541, 'AUCPRC': 0.995, 'F1': 0.9529, 'ROCAUC': 0.9988, 'MCC': 0.9414, 'ACC': 0.9816, 'GMEAN': 0.971, 'model_name': '30pct_median'}, {'tn': 24772.0, 'fp': 272.0, 'fn': 294.0, 'tp': 5765.0, 'precision': 0.9549, 'recall': 0.9515, 'AUCPRC': 0.995, 'F1': 0.9532, 'ROCAUC': 0.9987, 'MCC': 0.9419, 'ACC': 0.9818, 'GMEAN': 0.9701, 'model_name': '50pct_mean'}, {'tn': 24758.0, 'fp': 286.0, 'fn': 287.0, 'tp': 5772.0, 'precision': 0.9528, 'recall': 0.9526, 'AUCPRC': 0.9949, 'F1': 0.9527, 'ROCAUC': 0.9987, 'MCC': 0.9413, 'ACC': 0.9816, 'GMEAN': 0.9704, 'model_name': '50pct_median'}]

fold8 =  [{'tn': 24647.0, 'fp': 397.0, 'fn': 250.0, 'tp': 5809.0, 'precision': 0.936, 'recall': 0.9587, 'AUCPRC': 0.9944, 'F1': 0.9472, 'ROCAUC': 0.9986, 'MCC': 0.9344, 'ACC': 0.9792, 'GMEAN': 0.9714, 'model_name': '10pct_iterative'}, {'tn': 24720.0, 'fp': 324.0, 'fn': 290.0, 'tp': 5769.0, 'precision': 0.9468, 'recall': 0.9521, 'AUCPRC': 0.9946, 'F1': 0.9495, 'ROCAUC': 0.9986, 'MCC': 0.9372, 'ACC': 0.9803, 'GMEAN': 0.9694, 'model_name': '20pct_iterative'}, {'tn': 24730.0, 'fp': 314.0, 'fn': 293.0, 'tp': 5766.0, 'precision': 0.9484, 'recall': 0.9516, 'AUCPRC': 0.9946, 'F1': 0.95, 'ROCAUC': 0.9986, 'MCC': 0.9379, 'ACC': 0.9805, 'GMEAN': 0.9694, 'model_name': '30pct_iterative'}, {'tn': 24796.0, 'fp': 248.0, 'fn': 376.0, 'tp': 5683.0, 'precision': 0.9582, 'recall': 0.9379, 'AUCPRC': 0.9942, 'F1': 0.948, 'ROCAUC': 0.9985, 'MCC': 0.9356, 'ACC': 0.9799, 'GMEAN': 0.9637, 'model_name': '50pct_iterative'}, {'tn': 24730.0, 'fp': 314.0, 'fn': 291.0, 'tp': 5768.0, 'precision': 0.9484, 'recall': 0.952, 'AUCPRC': 0.9946, 'F1': 0.9502, 'ROCAUC': 0.9986, 'MCC': 0.9381, 'ACC': 0.9805, 'GMEAN': 0.9696, 'model_name': '10pct_mean'}, {'tn': 24714.0, 'fp': 330.0, 'fn': 278.0, 'tp': 5781.0, 'precision': 0.946, 'recall': 0.9541, 'AUCPRC': 0.9947, 'F1': 0.95, 'ROCAUC': 0.9987, 'MCC': 0.9379, 'ACC': 0.9805, 'GMEAN': 0.9703, 'model_name': '10pct_median'}, {'tn': 24737.0, 'fp': 307.0, 'fn': 294.0, 'tp': 5765.0, 'precision': 0.9494, 'recall': 0.9515, 'AUCPRC': 0.9946, 'F1': 0.9505, 'ROCAUC': 0.9986, 'MCC': 0.9385, 'ACC': 0.9807, 'GMEAN': 0.9694, 'model_name': '20pct_mean'}, {'tn': 24730.0, 'fp': 314.0, 'fn': 285.0, 'tp': 5774.0, 'precision': 0.9484, 'recall': 0.953, 'AUCPRC': 0.9946, 'F1': 0.9507, 'ROCAUC': 0.9986, 'MCC': 0.9387, 'ACC': 0.9807, 'GMEAN': 0.9701, 'model_name': '20pct_median'}, {'tn': 24733.0, 'fp': 311.0, 'fn': 302.0, 'tp': 5757.0, 'precision': 0.9487, 'recall': 0.9502, 'AUCPRC': 0.9946, 'F1': 0.9495, 'ROCAUC': 0.9986, 'MCC': 0.9372, 'ACC': 0.9803, 'GMEAN': 0.9687, 'model_name': '30pct_mean'}, {'tn': 24720.0, 'fp': 324.0, 'fn': 277.0, 'tp': 5782.0, 'precision': 0.9469, 'recall': 0.9543, 'AUCPRC': 0.9946, 'F1': 0.9506, 'ROCAUC': 0.9986, 'MCC': 0.9386, 'ACC': 0.9807, 'GMEAN': 0.9705, 'model_name': '30pct_median'}, {'tn': 24821.0, 'fp': 223.0, 'fn': 401.0, 'tp': 5658.0, 'precision': 0.9621, 'recall': 0.9338, 'AUCPRC': 0.9943, 'F1': 0.9477, 'ROCAUC': 0.9986, 'MCC': 0.9355, 'ACC': 0.9799, 'GMEAN': 0.962, 'model_name': '50pct_mean'}, {'tn': 24723.0, 'fp': 321.0, 'fn': 294.0, 'tp': 5765.0, 'precision': 0.9473, 'recall': 0.9515, 'AUCPRC': 0.9944, 'F1': 0.9494, 'ROCAUC': 0.9986, 'MCC': 0.9371, 'ACC': 0.9802, 'GMEAN': 0.9692, 'model_name': '50pct_median'}]

fold9 = [{'tn': 24780.0, 'fp': 264.0, 'fn': 301.0, 'tp': 5758.0, 'precision': 0.9562, 'recall': 0.9503, 'AUCPRC': 0.995, 'F1': 0.9532, 'ROCAUC': 0.9988, 'MCC': 0.942, 'ACC': 0.9818, 'GMEAN': 0.9697, 'model_name': '10pct_iterative'}, {'tn': 24795.0, 'fp': 249.0, 'fn': 313.0, 'tp': 5746.0, 'precision': 0.9585, 'recall': 0.9483, 'AUCPRC': 0.995, 'F1': 0.9534, 'ROCAUC': 0.9988, 'MCC': 0.9422, 'ACC': 0.9819, 'GMEAN': 0.969, 'model_name': '20pct_iterative'}, {'tn': 24718.0, 'fp': 326.0, 'fn': 294.0, 'tp': 5765.0, 'precision': 0.9465, 'recall': 0.9515, 'AUCPRC': 0.9947, 'F1': 0.949, 'ROCAUC': 0.9987, 'MCC': 0.9366, 'ACC': 0.9801, 'GMEAN': 0.9691, 'model_name': '30pct_iterative'}, {'tn': 24782.0, 'fp': 262.0, 'fn': 308.0, 'tp': 5751.0, 'precision': 0.9564, 'recall': 0.9492, 'AUCPRC': 0.995, 'F1': 0.9528, 'ROCAUC': 0.9988, 'MCC': 0.9414, 'ACC': 0.9817, 'GMEAN': 0.9691, 'model_name': '50pct_iterative'}, {'tn': 24845.0, 'fp': 199.0, 'fn': 401.0, 'tp': 5658.0, 'precision': 0.966, 'recall': 0.9338, 'AUCPRC': 0.9949, 'F1': 0.9496, 'ROCAUC': 0.9987, 'MCC': 0.9379, 'ACC': 0.9807, 'GMEAN': 0.9625, 'model_name': '10pct_mean'}, {'tn': 24780.0, 'fp': 264.0, 'fn': 304.0, 'tp': 5755.0, 'precision': 0.9561, 'recall': 0.9498, 'AUCPRC': 0.995, 'F1': 0.953, 'ROCAUC': 0.9987, 'MCC': 0.9416, 'ACC': 0.9817, 'GMEAN': 0.9694, 'model_name': '10pct_median'}, {'tn': 24865.0, 'fp': 179.0, 'fn': 415.0, 'tp': 5644.0, 'precision': 0.9693, 'recall': 0.9315, 'AUCPRC': 0.9951, 'F1': 0.95, 'ROCAUC': 0.9988, 'MCC': 0.9385, 'ACC': 0.9809, 'GMEAN': 0.9617, 'model_name': '20pct_mean'}, {'tn': 24845.0, 'fp': 199.0, 'fn': 405.0, 'tp': 5654.0, 'precision': 0.966, 'recall': 0.9332, 'AUCPRC': 0.995, 'F1': 0.9493, 'ROCAUC': 0.9987, 'MCC': 0.9375, 'ACC': 0.9806, 'GMEAN': 0.9622, 'model_name': '20pct_median'}, {'tn': 24785.0, 'fp': 259.0, 'fn': 309.0, 'tp': 5750.0, 'precision': 0.9569, 'recall': 0.949, 'AUCPRC': 0.995, 'F1': 0.9529, 'ROCAUC': 0.9988, 'MCC': 0.9416, 'ACC': 0.9817, 'GMEAN': 0.9691, 'model_name': '30pct_mean'}, {'tn': 24780.0, 'fp': 264.0, 'fn': 307.0, 'tp': 5752.0, 'precision': 0.9561, 'recall': 0.9493, 'AUCPRC': 0.995, 'F1': 0.9527, 'ROCAUC': 0.9987, 'MCC': 0.9413, 'ACC': 0.9816, 'GMEAN': 0.9692, 'model_name': '30pct_median'}, {'tn': 24783.0, 'fp': 261.0, 'fn': 307.0, 'tp': 5752.0, 'precision': 0.9566, 'recall': 0.9493, 'AUCPRC': 0.995, 'F1': 0.9529, 'ROCAUC': 0.9988, 'MCC': 0.9416, 'ACC': 0.9817, 'GMEAN': 0.9692, 'model_name': '50pct_mean'}, {'tn': 24778.0, 'fp': 266.0, 'fn': 302.0, 'tp': 5757.0, 'precision': 0.9558, 'recall': 0.9502, 'AUCPRC': 0.995, 'F1': 0.953, 'ROCAUC': 0.9988, 'MCC': 0.9417, 'ACC': 0.9817, 'GMEAN': 0.9696, 'model_name': '50pct_median'}]

fold10 = [{'tn': 24746.0, 'fp': 297.0, 'fn': 310.0, 'tp': 5750.0, 'precision': 0.9509, 'recall': 0.9488, 'AUCPRC': 0.9946, 'F1': 0.9499, 'ROCAUC': 0.9986, 'MCC': 0.9377, 'ACC': 0.9805, 'GMEAN': 0.9683, 'model_name': '10pct_iterative'}, {'tn': 24742.0, 'fp': 301.0, 'fn': 315.0, 'tp': 5745.0, 'precision': 0.9502, 'recall': 0.948, 'AUCPRC': 0.9944, 'F1': 0.9491, 'ROCAUC': 0.9986, 'MCC': 0.9368, 'ACC': 0.9802, 'GMEAN': 0.9678, 'model_name': '20pct_iterative'}, {'tn': 24750.0, 'fp': 293.0, 'fn': 310.0, 'tp': 5750.0, 'precision': 0.9515, 'recall': 0.9488, 'AUCPRC': 0.9946, 'F1': 0.9502, 'ROCAUC': 0.9986, 'MCC': 0.9381, 'ACC': 0.9806, 'GMEAN': 0.9684, 'model_name': '30pct_iterative'}, {'tn': 24742.0, 'fp': 301.0, 'fn': 310.0, 'tp': 5750.0, 'precision': 0.9503, 'recall': 0.9488, 'AUCPRC': 0.9944, 'F1': 0.9495, 'ROCAUC': 0.9986, 'MCC': 0.9374, 'ACC': 0.9804, 'GMEAN': 0.9682, 'model_name': '50pct_iterative'}, {'tn': 24735.0, 'fp': 308.0, 'fn': 296.0, 'tp': 5764.0, 'precision': 0.9493, 'recall': 0.9512, 'AUCPRC': 0.9946, 'F1': 0.9502, 'ROCAUC': 0.9986, 'MCC': 0.9382, 'ACC': 0.9806, 'GMEAN': 0.9693, 'model_name': '10pct_mean'}, {'tn': 24718.0, 'fp': 325.0, 'fn': 286.0, 'tp': 5774.0, 'precision': 0.9467, 'recall': 0.9528, 'AUCPRC': 0.9945, 'F1': 0.9497, 'ROCAUC': 0.9986, 'MCC': 0.9375, 'ACC': 0.9804, 'GMEAN': 0.9698, 'model_name': '10pct_median'}, {'tn': 24738.0, 'fp': 305.0, 'fn': 311.0, 'tp': 5749.0, 'precision': 0.9496, 'recall': 0.9487, 'AUCPRC': 0.9945, 'F1': 0.9491, 'ROCAUC': 0.9986, 'MCC': 0.9369, 'ACC': 0.9802, 'GMEAN': 0.9681, 'model_name': '20pct_mean'}, {'tn': 24744.0, 'fp': 299.0, 'fn': 312.0, 'tp': 5748.0, 'precision': 0.9506, 'recall': 0.9485, 'AUCPRC': 0.9945, 'F1': 0.9495, 'ROCAUC': 0.9986, 'MCC': 0.9373, 'ACC': 0.9804, 'GMEAN': 0.9681, 'model_name': '20pct_median'}, {'tn': 24741.0, 'fp': 302.0, 'fn': 308.0, 'tp': 5752.0, 'precision': 0.9501, 'recall': 0.9492, 'AUCPRC': 0.9946, 'F1': 0.9496, 'ROCAUC': 0.9986, 'MCC': 0.9375, 'ACC': 0.9804, 'GMEAN': 0.9684, 'model_name': '30pct_mean'}, {'tn': 24750.0, 'fp': 293.0, 'fn': 315.0, 'tp': 5745.0, 'precision': 0.9515, 'recall': 0.948, 'AUCPRC': 0.9945, 'F1': 0.9497, 'ROCAUC': 0.9986, 'MCC': 0.9376, 'ACC': 0.9805, 'GMEAN': 0.968, 'model_name': '30pct_median'}, {'tn': 24736.0, 'fp': 307.0, 'fn': 310.0, 'tp': 5750.0, 'precision': 0.9493, 'recall': 0.9488, 'AUCPRC': 0.9944, 'F1': 0.9491, 'ROCAUC': 0.9986, 'MCC': 0.9368, 'ACC': 0.9802, 'GMEAN': 0.9681, 'model_name': '50pct_mean'}, {'tn': 24801.0, 'fp': 242.0, 'fn': 397.0, 'tp': 5663.0, 'precision': 0.959, 'recall': 0.9345, 'AUCPRC': 0.9944, 'F1': 0.9466, 'ROCAUC': 0.9986, 'MCC': 0.934, 'ACC': 0.9795, 'GMEAN': 0.962, 'model_name': '50pct_median'}]

# %% [markdown]
# # Evaluation

# %%
kfold_results = df(columns=['tn', 'fp', 'fn', 'tp', 'precision', 'recall', 'AUCPRC', 'F1', 'ROCAUC',
       'MCC', 'ACC', 'GMEAN', 'model_name'])

for fold in [fold1, fold2, fold3, fold4, fold5, fold6, fold7, fold8, fold9, fold10]:
	kfold_results = pd.concat([kfold_results, df(fold)])

kfold_results = kfold_results.drop(['tn', 'fp', 'fn', 'tp', 'ROCAUC', 'ACC'], axis=1)

grouped_df = kfold_results.groupby("model_name")

result = grouped_df.agg(lambda x: f"{x.mean():.4f} ± {x.std():.4f}")

result
# Out:
# /var/folders/b5/y93p_qw91z98pk044cfd6b800000gn/T/ipykernel_62159/2264849202.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   kfold_results = pd.concat([kfold_results, df(fold)])
#                        precision           recall           AUCPRC  \
# model_name
# 10pct_iterative  0.9503 ± 0.0062  0.9512 ± 0.0047  0.9946 ± 0.0003
# 10pct_mean       0.9520 ± 0.0054  0.9496 ± 0.0064  0.9947 ± 0.0003
# 10pct_median     0.9476 ± 0.0052  0.9523 ± 0.0026  0.9945 ± 0.0004
# 20pct_iterative  0.9498 ± 0.0048  0.9511 ± 0.0034  0.9945 ± 0.0003
# 20pct_mean       0.9525 ± 0.0063  0.9486 ± 0.0066  0.9946 ± 0.0004
# 20pct_median     0.9499 ± 0.0066  0.9496 ± 0.0065  0.9945 ± 0.0003
# ...

# %% [markdown]
# # T-Test

# %%
# Drop the specified columns
ttest_data = df(columns=[ 'model_name', 'tn', 'fp', 'fn', 'tp', 'precision', 'recall', 'AUCPRC', 'F1', 'ROCAUC',
       'MCC', 'ACC', 'GMEAN',])

for fold in [fold1, fold2, fold3, fold4, fold5, fold6, fold7, fold8, fold9, fold10]:
	ttest_data = pd.concat([ttest_data, df(fold)], ignore_index=True)

datasets =  ['10pct', '20pct', '30pct', '50pct']
imputers = ['mean', 'median']
alpha = 0.05

for ds in datasets:
	for imputer in imputers:
		current_name = f"{ds}_{imputer}"
		iterative_name = f"{ds}_iterative"

		current_imputer_aucprc = ttest_data[ttest_data['model_name'] == current_name]['AUCPRC'].to_list()
		current_iterative_aucprc = ttest_data[ttest_data['model_name'] == iterative_name]['AUCPRC'].to_list()

		t_stat, p_value = ttest_ind(current_imputer_aucprc, current_iterative_aucprc)
		print("t-test:")
		if p_value < alpha:
			print(f"Reject the null hypothesis: There is a significant difference between the imputers ({current_name}, {iterative_name})")
		else:
			print(f"There is no significant difference between the imputers ({current_name}, {iterative_name})")

		print("mannwhitney test:")
		# Perform Mann-Whitney U test
		u_stat, p_value_mannwhitney = mannwhitneyu(current_imputer_aucprc, current_iterative_aucprc, alternative='two-sided')

		if p_value_mannwhitney < alpha:
			print(f"Reject the null hypothesis: There is a significant difference between the imputers ({current_name}, {iterative_name} (p = {p_value_mannwhitney:.4f}, u_stat = {u_stat:.4f}, alpha = {alpha}, n = {len(current_imputer_aucprc)}))")
		else:
			print(f"There is no significant difference between the imputers ({current_name}, {iterative_name}) (p = {p_value_mannwhitney:.4f}, u_stat = {u_stat:.4f}, alpha = {alpha}, n = {len(current_imputer_aucprc)})")
				
		print("")
# Out:
# t-test:
# There is no significant difference between the imputers (10pct_mean, 10pct_iterative)
# mannwhitney test:
# There is no significant difference between the imputers (10pct_mean, 10pct_iterative) (p = 0.8491, u_stat = 53.0000, alpha = 0.05, n = 10)
#
# t-test:
# There is no significant difference between the imputers (10pct_median, 10pct_iterative)
# mannwhitney test:
# There is no significant difference between the imputers (10pct_median, 10pct_iterative) (p = 0.7609, u_stat = 45.5000, alpha = 0.05, n = 10)
#
# t-test:
# There is no significant difference between the imputers (20pct_mean, 20pct_iterative)
# mannwhitney test:
# There is no significant difference between the imputers (20pct_mean, 20pct_iterative) (p = 0.6745, u_stat = 56.0000, alpha = 0.05, n = 10)
#
# t-test:
# There is no significant difference between the imputers (20pct_median, 20pct_iterative)
# mannwhitney test:
# ...
