# %%
# MO-GAAL Class
"""Multiple-Objective Generative Adversarial Active Learning.
Part of the codes are adapted from
https://github.com/leibinghe/GAAL-based-outlier-detection
"""
# Author: Winston Li <jk_zhengli@hotmail.com>
# License: BSD 2 clause

# Code slightly updated to run on Keras 3 by Markus Haug

from __future__ import division
from __future__ import print_function

from collections import defaultdict

import numpy as np
from sklearn.utils import check_array
from sklearn.utils.validation import check_is_fitted

from pyod.models.base import BaseDetector
from pyod.models.gaal_base import create_discriminator, create_generator

from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD


class MO_GAAL(BaseDetector):
    """Multi-Objective Generative Adversarial Active Learning.

    MO_GAAL directly generates informative potential outliers to assist the
    classifier in describing a boundary that can separate outliers from normal
    data effectively. Moreover, to prevent the generator from falling into the
    mode collapsing problem, the network structure of SO-GAAL is expanded from
    a single generator (SO-GAAL) to multiple generators with different
    objectives (MO-GAAL) to generate a reasonable reference distribution for
    the whole dataset.
    Read more in the :cite:`liu2019generative`.

    Parameters
    ----------
    contamination : float in (0., 0.5), optional (default=0.1)
        The amount of contamination of the data set, i.e.
        the proportion of outliers in the data set. Used when fitting to
        define the threshold on the decision function.

    k : int, optional (default=10)
        The number of sub generators.

    stop_epochs : int, optional (default=20)
        The number of epochs of training. The number of total epochs equals to three times of stop_epochs.

    lr_d : float, optional (default=0.01)
        The learn rate of the discriminator.

    lr_g : float, optional (default=0.0001)
        The learn rate of the generator.


    momentum : float, optional (default=0.9)
        The momentum parameter for SGD.

    Attributes
    ----------
    decision_scores_ : numpy array of shape (n_samples,)
        The outlier scores of the training data.
        The higher, the more abnormal. Outliers tend to have higher
        scores. This value is available once the detector is fitted.

    threshold_ : float
        The threshold is based on ``contamination``. It is the
        ``n_samples * contamination`` most abnormal samples in
        ``decision_scores_``. The threshold is calculated for generating
        binary outlier labels.

    labels_ : int, either 0 or 1
        The binary labels of the training data. 0 stands for inliers
        and 1 for outliers/anomalies. It is generated by applying
        ``threshold_`` on ``decision_scores_``.
    """

    def __init__(self, k=10, stop_epochs=20, lr_d=0.01, lr_g=0.0001, momentum=0.9, contamination=0.1):
        super(MO_GAAL, self).__init__(contamination=contamination)
        self.k = k
        self.stop_epochs = stop_epochs
        self.lr_d = lr_d
        self.lr_g = lr_g
        self.momentum = momentum

    def fit(self, X, y=None):
        """Fit detector. y is ignored in unsupervised methods.

        Parameters
        ----------
        X : numpy array of shape (n_samples, n_features)
            The input samples.

        y : Ignored
            Not used, present for API consistency by convention.

        Returns
        -------
        self : object
            Fitted estimator.
        """

        X = check_array(X)
        self._set_n_classes(y)
        self.train_history = defaultdict(list)
        names = locals()
        epochs = self.stop_epochs * 3
        stop = 0
        latent_size = X.shape 1 
        data_size = X.shape 0 
        # Create discriminator
        self.discriminator = create_discriminator(latent_size, data_size)
        self.discriminator.compile(
            optimizer=SGD(learning_rate=self.lr_d, momentum=self.momentum), loss='binary_crossentropy')

        # Create k combine models
        for i in range(self.k):
            names'sub_generator' + str(i)  = create_generator(latent_size)
            latent = Input(shape=(latent_size,))
            names 'fake' + str(i)  = names 'sub_generator' + str(i) (latent)
            self.discriminator.trainable = False
            names 'fake' + str(i)  = self.discriminator(names 'fake' + str(i) )
            names 'combine_model' + str(i)  = Model(latent,
                                                    names 'fake' + str(i) )
            names 'combine_model' + str(i) .compile(
                optimizer=SGD(learning_rate=self.lr_g,
                              momentum=self.momentum),
                loss='binary_crossentropy')

        # Start iteration
        for epoch in range(epochs):
            print('Epoch {} of {}'.format(epoch + 1, epochs))
            batch_size = min(500, data_size)
            num_batches = int(data_size / batch_size)

            for index in range(num_batches):
                print('\nTesting for epoch {} index {}:'.format(epoch + 1,
                                                                index + 1))

                # Generate noise
                noise_size = batch_size
                noise = np.random.uniform(0, 1, (int(noise_size), latent_size))

                # Get training data
                data_batch = X index * batch_size: (index + 1) * batch_size 

                # Generate potential outliers
                block = ((1 + self.k) * self.k) // 2
                for i in range(self.k):
                    if i != (self.k - 1):
                        noise_start = int(
                            (((self.k + (self.k - i + 1)) * i) / 2) * (
                                    noise_size // block))
                        noise_end = int(
                            (((self.k + (self.k - i)) * (i + 1)) / 2) * (
                                    noise_size // block))
                        names 'noise' + str(i)  = noise noise_start:noise_end 
                        names 'generated_data' + str(i)  = names 
                            'sub_generator' + str(i) .predict(
                            names 'noise' + str(i) , verbose=0)
                    else:
                        noise_start = int(
                            (((self.k + (self.k - i + 1)) * i) / 2) * (
                                    noise_size // block))
                        names 'noise' + str(i)  = noise noise_start:noise_size 
                        names 'generated_data' + str(i)  = names 
                            'sub_generator' + str(i) .predict(
                            names 'noise' + str(i) , verbose=0)

                # Concatenate real data to generated data
                for i in range(self.k):
                    if i == 0:
                        x = np.concatenate(
                            (data_batch, names 'generated_data' + str(i) ))
                    else:
                        x = np.concatenate(
                            (x, names 'generated_data' + str(i) ))
                y = np.array( 1  * batch_size +  0  * int(noise_size))

                # Train discriminator
                discriminator_loss = self.discriminator.train_on_batch(x, y)
                self.train_history 'discriminator_loss' .append(
                    discriminator_loss)

                # Get the target value of sub-generator
                pred_scores = self.discriminator.predict(X).ravel()

                for i in range(self.k):
                    names 'T' + str(i)  = np.percentile(pred_scores,
                                                        i / self.k * 100)
                    names 'trick' + str(i)  = np.array(
                         float(names 'T' + str(i) )  * noise_size)

                # Train generator
                noise = np.random.uniform(0, 1, (int(noise_size), latent_size))
                if stop == 0:
                    for i in range(self.k):
                        names 'sub_generator' + str(i) + '_loss'  = \
                            names 'combine_model' + str(i) .train_on_batch(
                                noise, names 'trick' + str(i) )
                        self.train_history 
                            'sub_generator{}_loss'.format(i) .append(
                            names 'sub_generator' + str(i) + '_loss' )
                else:
                    for i in range(self.k):
                        names 'sub_generator' + str(i) + '_loss'  = names 
                            'combine_model' + str(i) .evaluate(noise, names 
                            'trick' + str(i) )
                        self.train_history 
                            'sub_generator{}_loss'.format(i) .append(
                            names 'sub_generator' + str(i) + '_loss' )

                generator_loss = 0
                for i in range(self.k):
                    # Access the last loss value which is the most recent one
                    generator_loss += names 'sub_generator' + str(i) + '_loss'  -1 

                generator_loss = generator_loss / self.k
                self.train_history 'generator_loss' .append(generator_loss)

                # Stop training generator
                if epoch + 1 > self.stop_epochs:
                    stop = 1

        # Detection result
        self.decision_scores_ = self.discriminator.predict(X).ravel()
        self._process_decision_scores()
        return self

    def decision_function(self, X):
        """Predict raw anomaly score of X using the fitted detector.

        The anomaly score of an input sample is computed based on different
        detector algorithms. For consistency, outliers are assigned with
        larger anomaly scores.

        Parameters
        ----------
        X : numpy array of shape (n_samples, n_features)
            The training input samples. Sparse matrices are accepted only
            if they are supported by the base estimator.

        Returns
        -------
        anomaly_scores : numpy array of shape (n_samples,)
            The anomaly score of the input samples.
        """
        check_is_fitted(self,  'discriminator' )
        X = check_array(X)
        pred_scores = self.discriminator.predict(X).ravel()
        return pred_scores

# %%
import pickle

# imoprt data science libraries
import pandas as pd
from pandas import DataFrame as df
import matplotlib.pyplot as plt
import numpy as np

# Import ML libraries
import keras
import model_utils as mutils
from model_utils.evaluation import get_metrics, evaluate_model, table
from sklearn.preprocessing import StandardScaler
import pyod
import time
from joblib import dump, load

# %%
for current_k_fold in  3 :
  print("current fold: ", current_k_fold)

  # set seed
  SEED=current_k_fold**3
  np.random.seed(SEED)


  # deserialize pre-processed data
  path_to_pickle = f'../data/creditcard/cc13_preprocessed_k{current_k_fold}.pkl'

  with open(path_to_pickle, "rb") as f:
      data = pickle.load(f)
      X_train = data "X_train" .to_numpy()
      y_train = data "y_train" .to_numpy()

      X_val = data "X_val" .to_numpy()
      y_val = data "y_val" .to_numpy()

      X_test = data "X_test" .to_numpy()
      y_test = data "y_test" .to_numpy()

      col_names = data "col_names" 

  print("Data loaded successfully")

  # Reshape
  y_train = y_train.reshape(-1, 1)
  y_test = y_test.reshape(-1, 1)
  y_val = y_val.reshape(-1, 1)

  # Set Weight
  res_value_counts = df(y_train).value_counts()
  weight_for_0 = 1.0 / res_value_counts 0 
  weight_for_1 = 1.0 / res_value_counts 1 

  scaler = StandardScaler()
  scaler.fit(X_train)

  X_train = scaler.transform(X_train)
  X_val = scaler.transform(X_val)
  X_test = scaler.transform(X_test)

  # run for current fold
  contamination = len(y_train y_train == 1 ) / len(y_train) # proportion of frauds in the training dataset
  n_sub_generators = 5
  lr_discriminator = 0.01
  lr_generator = 0.0001
  epochs = 1

  mo_gaal = MO_GAAL(
      k=n_sub_generators,
      stop_epochs=epochs,
      contamination=contamination,
      lr_d=lr_discriminator,
      lr_g=lr_generator,
  )

  # train in supervised manner
  start = time.time()
  clf = mo_gaal.fit(X_train, y_train) # 67 min for 1 epoch and n_sub_generators = 5
  elapsed = time.time() - start

  # evaluate
  scores = mo_gaal.predict_proba(X_test)
  scores_normal = df(mo_gaal.predict_proba(df(X_train) y_train == 0 ) :,1 )
  scores_anomal = df(mo_gaal.predict_proba(df(X_train) y_train == 1 ) :, 0 )

  # let's find the best threshold
  best_metric = 0.
  best_th = 0.

  for threshold in np.arange(0., 1.0, 0.001):
      current_metric = get_metrics(y_test, scores :, 1 , op=">", threshold=threshold) "AUCPRC" 
      if current_metric > best_metric:
          best_metric = current_metric
          best_th = threshold

  print("Best Metric Score:", best_metric)
  print("Best Threshold: ", best_th)

  metrics = get_metrics(y_test, scores :, 1 , threshold=best_th)

  print("metrics for fold: ", current_k_fold)
  print(metrics)

  # save model
  dump(mo_gaal, f'./saved_models/MOGAAL/mo_gaal_CC_k{current_k_fold}.joblib')

  elapsed = time.strftime("%H:%M:%S", time.gmtime(elapsed))
# Out:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 267us/step
#
# Testing for epoch 1 index 196:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 254us/step
#
# Testing for epoch 1 index 197:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 244us/step
#
# Testing for epoch 1 index 198:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 252us/step
#
# Testing for epoch 1 index 199:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 277us/step
#
# Testing for epoch 1 index 200:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 268us/step
#
# Testing for epoch 1 index 201:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 275us/step
#
# Testing for epoch 1 index 202:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 276us/step
#
# Testing for epoch 1 index 203:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 269us/step
#
# Testing for epoch 1 index 204:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 260us/step
#
# Testing for epoch 1 index 205:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 256us/step
#
# Testing for epoch 1 index 206:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 265us/step
#
# Testing for epoch 1 index 207:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 359us/step
#
# Testing for epoch 1 index 208:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 323us/step
#
# Testing for epoch 1 index 209:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 279us/step
#
# Testing for epoch 1 index 210:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 325us/step
#
# Testing for epoch 1 index 211:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 275us/step
#
# Testing for epoch 1 index 212:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 287us/step
#
# Testing for epoch 1 index 213:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 286us/step
#
# Testing for epoch 1 index 214:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 299us/step
#
# Testing for epoch 1 index 215:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 326us/step
#
# Testing for epoch 1 index 216:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 298us/step
#
# Testing for epoch 1 index 217:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 298us/step
#
# Testing for epoch 1 index 218:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 273us/step
#
# Testing for epoch 1 index 219:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 307us/step
#
# Testing for epoch 1 index 220:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 289us/step
#
# Testing for epoch 1 index 221:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 331us/step
#
# Testing for epoch 1 index 222:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 278us/step
#
# Testing for epoch 1 index 223:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 294us/step
#
# Testing for epoch 1 index 224:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 288us/step
#
# Testing for epoch 1 index 225:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 282us/step
#
# Testing for epoch 1 index 226:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 284us/step
#
# Testing for epoch 1 index 227:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 278us/step
#
# Testing for epoch 1 index 228:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 331us/step
#
# Testing for epoch 1 index 229:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 318us/step
#
# Testing for epoch 1 index 230:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 310us/step
#
# Testing for epoch 1 index 231:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 320us/step
#
# Testing for epoch 1 index 232:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 277us/step
#
# Testing for epoch 1 index 233:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 307us/step
#
# Testing for epoch 1 index 234:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 310us/step
#
# Testing for epoch 1 index 235:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 308us/step
#
# Testing for epoch 1 index 236:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 288us/step
#
# Testing for epoch 1 index 237:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 355us/step
#
# Testing for epoch 1 index 238:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 320us/step
#
# Testing for epoch 1 index 239:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 288us/step
#
# Testing for epoch 1 index 240:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 297us/step
#
# Testing for epoch 1 index 241:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 291us/step
#
# Testing for epoch 1 index 242:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 290us/step
#
# Testing for epoch 1 index 243:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 296us/step
#
# Testing for epoch 1 index 244:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 278us/step
#
# Testing for epoch 1 index 245:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 267us/step
#
# Testing for epoch 1 index 246:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 274us/step
#
# Testing for epoch 1 index 247:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 265us/step
#
# Testing for epoch 1 index 248:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 294us/step
#
# Testing for epoch 1 index 249:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 271us/step
#
# Testing for epoch 1 index 250:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 300us/step
#
# Testing for epoch 1 index 251:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 287us/step
#
# Testing for epoch 1 index 252:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 334us/step
#
# Testing for epoch 1 index 253:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 300us/step
#
# Testing for epoch 1 index 254:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 291us/step
#
# Testing for epoch 1 index 255:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 298us/step
#
# Testing for epoch 1 index 256:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 273us/step
#
# Testing for epoch 1 index 257:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 271us/step
#
# Testing for epoch 1 index 258:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 259us/step
#
# Testing for epoch 1 index 259:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 266us/step
#
# Testing for epoch 1 index 260:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 270us/step
#
# Testing for epoch 1 index 261:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 256us/step
#
# Testing for epoch 1 index 262:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 265us/step
#
# Testing for epoch 1 index 263:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 250us/step
#
# Testing for epoch 1 index 264:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 282us/step
#
# Testing for epoch 1 index 265:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 268us/step
#
# Testing for epoch 1 index 266:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 256us/step
#
# Testing for epoch 1 index 267:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 246us/step
#
# Testing for epoch 1 index 268:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 253us/step
#
# Testing for epoch 1 index 269:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 296us/step
#
# Testing for epoch 1 index 270:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 308us/step
#
# Testing for epoch 1 index 271:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 254us/step
#
# Testing for epoch 1 index 272:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 273us/step
#
# Testing for epoch 1 index 273:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 342us/step
#
# Testing for epoch 1 index 274:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 263us/step
#
# Testing for epoch 1 index 275:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 274us/step
#
# Testing for epoch 1 index 276:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 298us/step
#
# Testing for epoch 1 index 277:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 333us/step
#
# Testing for epoch 1 index 278:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 374us/step
#
# Testing for epoch 1 index 279:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 279us/step
#
# Testing for epoch 1 index 280:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 340us/step
#
# Testing for epoch 1 index 281:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 263us/step
#
# Testing for epoch 1 index 282:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 258us/step
#
# Testing for epoch 1 index 283:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 282us/step
#
# Testing for epoch 1 index 284:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 266us/step
#
# Testing for epoch 1 index 285:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 273us/step
#
# Testing for epoch 1 index 286:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 280us/step
#
# Testing for epoch 1 index 287:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 298us/step
#
# Testing for epoch 1 index 288:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 270us/step
#
# Testing for epoch 1 index 289:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 314us/step
#
# Testing for epoch 1 index 290:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 291us/step
#
# Testing for epoch 1 index 291:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 292us/step
#
# Testing for epoch 1 index 292:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 280us/step
#
# Testing for epoch 1 index 293:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 288us/step
#
# Testing for epoch 1 index 294:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 276us/step
#
# Testing for epoch 1 index 295:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 270us/step
#
# Testing for epoch 1 index 296:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 279us/step
#
# Testing for epoch 1 index 297:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 275us/step
#
# Testing for epoch 1 index 298:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 275us/step
#
# Testing for epoch 1 index 299:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 268us/step
#
# Testing for epoch 1 index 300:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 275us/step
#
# Testing for epoch 1 index 301:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 274us/step
#
# Testing for epoch 1 index 302:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 279us/step
#
# Testing for epoch 1 index 303:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 270us/step
#
# Testing for epoch 1 index 304:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 327us/step
#
# Testing for epoch 1 index 305:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 274us/step
#
# Testing for epoch 1 index 306:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 259us/step
#
# Testing for epoch 1 index 307:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 270us/step
#
# Testing for epoch 1 index 308:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 267us/step
#
# Testing for epoch 1 index 309:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 274us/step
#
# Testing for epoch 1 index 310:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 271us/step
#
# Testing for epoch 1 index 311:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 272us/step
#
# Testing for epoch 1 index 312:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 286us/step
#
# Testing for epoch 1 index 313:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 270us/step
#
# Testing for epoch 1 index 314:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 257us/step
#
# Testing for epoch 1 index 315:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 265us/step
#
# Testing for epoch 1 index 316:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 268us/step
#
# Testing for epoch 1 index 317:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 278us/step
#
# Testing for epoch 1 index 318:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 265us/step
#
# Testing for epoch 1 index 319:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 267us/step
#
# Testing for epoch 1 index 320:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 271us/step
#
# Testing for epoch 1 index 321:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 299us/step
#
# Testing for epoch 1 index 322:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 297us/step
#
# Testing for epoch 1 index 323:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 279us/step
#
# Testing for epoch 1 index 324:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 279us/step
#
# Testing for epoch 1 index 325:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 281us/step
#
# Testing for epoch 1 index 326:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 274us/step
#
# Testing for epoch 1 index 327:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 279us/step
#
# Testing for epoch 1 index 328:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 280us/step
#
# Testing for epoch 1 index 329:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 282us/step
#
# Testing for epoch 1 index 330:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 306us/step
#
# Testing for epoch 1 index 331:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 283us/step
#
# Testing for epoch 1 index 332:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 291us/step
#
# Testing for epoch 1 index 333:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 281us/step
#
# Testing for epoch 1 index 334:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 342us/step
#
# Testing for epoch 1 index 335:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 270us/step
#
# Testing for epoch 1 index 336:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 289us/step
#
# Testing for epoch 1 index 337:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 270us/step
#
# Testing for epoch 1 index 338:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 295us/step
#
# Testing for epoch 1 index 339:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 263us/step
#
# Testing for epoch 1 index 340:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 288us/step
#
# Testing for epoch 1 index 341:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 254us/step
#
# Testing for epoch 1 index 342:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 274us/step
#
# Testing for epoch 1 index 343:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 282us/step
#
# Testing for epoch 1 index 344:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 276us/step
#
# Testing for epoch 1 index 345:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 256us/step
#
# Testing for epoch 1 index 346:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 249us/step
#
# Testing for epoch 1 index 347:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 255us/step
#
# Testing for epoch 1 index 348:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 258us/step
#
# Testing for epoch 1 index 349:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 276us/step
#
# Testing for epoch 1 index 350:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 253us/step
#
# Testing for epoch 1 index 351:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 261us/step
#
# Testing for epoch 1 index 352:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 294us/step
#
# Testing for epoch 1 index 353:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 257us/step
#
# Testing for epoch 1 index 354:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 277us/step
#
# Testing for epoch 1 index 355:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 261us/step
#
# Testing for epoch 1 index 356:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 261us/step
#
# Testing for epoch 1 index 357:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 335us/step
#
# Testing for epoch 1 index 358:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 290us/step
#
# Testing for epoch 1 index 359:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 297us/step
#
# Testing for epoch 1 index 360:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 278us/step
#
# Testing for epoch 1 index 361:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 277us/step
#
# Testing for epoch 1 index 362:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 274us/step
#
# Testing for epoch 1 index 363:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 289us/step
#
# Testing for epoch 1 index 364:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 273us/step
#
# Testing for epoch 1 index 365:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 339us/step
#
# Testing for epoch 1 index 366:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 284us/step
#
# Testing for epoch 1 index 367:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 276us/step
#
# Testing for epoch 1 index 368:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 270us/step
#
# Testing for epoch 1 index 369:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 290us/step
#
# Testing for epoch 1 index 370:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 288us/step
#
# Testing for epoch 1 index 371:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 303us/step
#
# Testing for epoch 1 index 372:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 305us/step
#
# Testing for epoch 1 index 373:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 324us/step
#
# Testing for epoch 1 index 374:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 333us/step
#
# Testing for epoch 1 index 375:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 295us/step
#
# Testing for epoch 1 index 376:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 397us/step
#
# Testing for epoch 1 index 377:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 322us/step
#
# Testing for epoch 1 index 378:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 306us/step
#
# Testing for epoch 1 index 379:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 291us/step
#
# Testing for epoch 1 index 380:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 279us/step
#
# Testing for epoch 1 index 381:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 290us/step
#
# Testing for epoch 1 index 382:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 304us/step
#
# Testing for epoch 1 index 383:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 317us/step
#
# Testing for epoch 1 index 384:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 310us/step
#
# Testing for epoch 1 index 385:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 308us/step
#
# Testing for epoch 1 index 386:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 312us/step
#
# Testing for epoch 1 index 387:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 301us/step
#
# Testing for epoch 1 index 388:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 296us/step
#
# Testing for epoch 1 index 389:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 298us/step
#
# Testing for epoch 1 index 390:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 274us/step
#
# Testing for epoch 1 index 391:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 315us/step
#
# Testing for epoch 1 index 392:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 281us/step
#
# Testing for epoch 1 index 393:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 275us/step
#
# Testing for epoch 1 index 394:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 278us/step
#
# Testing for epoch 1 index 395:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 295us/step
#
# Testing for epoch 1 index 396:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 279us/step
#
# Testing for epoch 1 index 397:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 295us/step
#
# Testing for epoch 1 index 398:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 268us/step
#
# Testing for epoch 1 index 399:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 281us/step
#
# Testing for epoch 1 index 400:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 274us/step
#
# Testing for epoch 1 index 401:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 277us/step
#
# Testing for epoch 1 index 402:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 276us/step
#
# Testing for epoch 1 index 403:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 276us/step
#
# Testing for epoch 1 index 404:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 286us/step
#
# Testing for epoch 1 index 405:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 289us/step
#
# Testing for epoch 1 index 406:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 279us/step
#
# Testing for epoch 1 index 407:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 262us/step
#
# Testing for epoch 1 index 408:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 269us/step
#
# Testing for epoch 1 index 409:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 264us/step
#
# Testing for epoch 1 index 410:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 266us/step
#
# Testing for epoch 1 index 411:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 264us/step
#
# Testing for epoch 1 index 412:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 262us/step
#
# Testing for epoch 1 index 413:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 277us/step
#
# Testing for epoch 1 index 414:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 260us/step
#
# Testing for epoch 1 index 415:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 273us/step
#
# Testing for epoch 1 index 416:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 265us/step
#
# Testing for epoch 1 index 417:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 340us/step
#
# Testing for epoch 1 index 418:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 360us/step
#
# Testing for epoch 1 index 419:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 275us/step
#
# Testing for epoch 1 index 420:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 308us/step
#
# Testing for epoch 1 index 421:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 284us/step
#
# Testing for epoch 1 index 422:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 306us/step
#
# Testing for epoch 1 index 423:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 335us/step
#
# Testing for epoch 1 index 424:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 292us/step
#
# Testing for epoch 1 index 425:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 303us/step
#
# Testing for epoch 1 index 426:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 293us/step
#
# Testing for epoch 1 index 427:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 361us/step
#
# Testing for epoch 1 index 428:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 307us/step
#
# Testing for epoch 1 index 429:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 355us/step
#
# Testing for epoch 1 index 430:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 337us/step
#
# Testing for epoch 1 index 431:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 342us/step
#
# Testing for epoch 1 index 432:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 264us/step
#
# Testing for epoch 1 index 433:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 284us/step
#
# Testing for epoch 1 index 434:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 322us/step
#
# Testing for epoch 1 index 435:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 288us/step
#
# Testing for epoch 1 index 436:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 417us/step
#
# Testing for epoch 1 index 437:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 306us/step
#
# Testing for epoch 1 index 438:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 331us/step
#
# Testing for epoch 1 index 439:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 315us/step
#
# Testing for epoch 1 index 440:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 307us/step
#
# Testing for epoch 1 index 441:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 283us/step
#
# Testing for epoch 1 index 442:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 280us/step
#
# Testing for epoch 1 index 443:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 273us/step
#
# Testing for epoch 1 index 444:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 287us/step
#
# Testing for epoch 1 index 445:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 280us/step
#
# Testing for epoch 1 index 446:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 270us/step
#
# Testing for epoch 1 index 447:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 311us/step
#
# Testing for epoch 1 index 448:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 301us/step
#
# Testing for epoch 1 index 449:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 287us/step
#
# Testing for epoch 1 index 450:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 298us/step
#
# Testing for epoch 1 index 451:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 292us/step
#
# Testing for epoch 1 index 452:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 271us/step
#
# Testing for epoch 1 index 453:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 295us/step
# Epoch 2 of 3
#
# Testing for epoch 2 index 1:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 297us/step
#
# Testing for epoch 2 index 2:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 292us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 3:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 311us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 4:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 356us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 5:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 336us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 6:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 298us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 7:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 292us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 8:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 369us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 9:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 324us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 350us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 323us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 10:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 356us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 335us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 354us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 11:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 301us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 358us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 12:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 303us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 337us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 13:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 301us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 14:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 311us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 15:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 303us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 16:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 300us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 17:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 307us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 345us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 18:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 296us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 354us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 19:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 302us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 347us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 20:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 301us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 21:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 305us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 358us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 22:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 295us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 443us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 23:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 269us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 24:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 276us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 25:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 284us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 26:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 284us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 27:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 277us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 28:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 264us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 29:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 269us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 30:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 276us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 31:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 282us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 32:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 422us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 33:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 279us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 34:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 270us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 35:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 277us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 36:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 275us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 422us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 37:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 282us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 38:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 281us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 39:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 282us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 443us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 40:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 284us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 41:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 271us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 448us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 440us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 42:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 277us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 43:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 282us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 443us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 44:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 347us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 45:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 289us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 448us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 46:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 299us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 47:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 455us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 48:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 270us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 49:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 287us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 50:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 295us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 51:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 387us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 52:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 281us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 440us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 53:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 302us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 424us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 54:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 308us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 362us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 55:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 291us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 437us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 358us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 56:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 293us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 437us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 57:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 312us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 340us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 58:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 307us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 59:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 347us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 445us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 60:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 372us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 433us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 61:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 369us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 337us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 354us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 345us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 338us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 62:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 353us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 424us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 351us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 63:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 329us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 64:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 316us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 355us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 341us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 337us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 335us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 65:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 304us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 422us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 66:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 359us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 67:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 336us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 68:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 342us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 422us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 69:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 324us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 70:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 312us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 71:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 301us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 352us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 72:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 300us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 432us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 73:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 324us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 74:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 310us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 421us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 441us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 75:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 329us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step - loss: 0.0000e+00
#
# Testing for epoch 2 index 76:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 296us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step - loss: 0.0000e+00
# ...
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 413:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 313us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 414:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 339us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 415:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 319us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 416:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 321us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 417:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 358us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 418:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 321us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 419:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 304us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 355us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 420:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 363us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 441us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 421:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 342us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 422:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 353us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 353us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 423:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 359us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 424:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 374us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 425:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 339us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 426:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 345us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 427:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 359us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 346us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 428:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 405us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 352us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 354us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 429:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 355us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 448us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 430:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 342us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 357us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 431:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 375us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 422us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 432:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 356us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 433:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 4s 532us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 434:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 4s 530us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 432us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 435:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 460us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 436:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 385us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 437:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 419us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 441us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 448us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 438:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 372us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 424us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 439:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 376us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 437us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 440:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 373us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 447us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 441:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 365us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 442:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 428us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 362us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 443:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 386us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 444:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 379us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 445:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 360us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 446:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 433us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 447:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 382us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 448:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 333us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 449:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 309us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 450:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 346us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 448us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 451:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 319us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 452:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 3s 369us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 424us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 0.0000e+00
#
# Testing for epoch 3 index 453:
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 332us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 441us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step - loss: 0.0000e+00
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - loss: 0.0000e+00
# 7094/7094 ━━━━━━━━━━━━━━━━━━━━ 2s 314us/step
# 887/887 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step
# 7082/7082 ━━━━━━━━━━━━━━━━━━━━ 2s 270us/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step
# Best Metric Score: 0.0979
# Best Threshold:  0.9500000000000001
# metrics for fold:  3
# {'tn': 28237.0, 'fp': 88.0, 'fn': 41.0, 'tp': 7.0, 'precision': 0.0737, 'recall': 0.1458, 'AUCPRC': 0.0174, 'F1': 0.0979, 'ROCAUC': 0.7625, 'MCC': 0.1015, 'ACC': 0.9955, 'GMEAN': 0.3813}

# %% [markdown]
# # Evaluate

# %%
fold1 =  {'tn': 28291.0, 'fp': 34.0, 'fn': 39.0, 'tp': 9.0, 'precision': 0.2093, 'recall': 0.1875, 'AUCPRC': 0.062, 'F1': 0.1978, 'ROCAUC': 0.7896, 'MCC': 0.1968, 'ACC': 0.9974, 'GMEAN': 0.4328} 

fold2 =  {'tn': 28219.0, 'fp': 106.0, 'fn': 46.0, 'tp': 2.0, 'precision': 0.0185, 'recall': 0.0417, 'AUCPRC': 0.0018, 'F1': 0.0256, 'ROCAUC': 0.204, 'MCC': 0.0253, 'ACC': 0.9946, 'GMEAN': 0.2037} 

fold3 =  {'tn': 28237.0, 'fp': 88.0, 'fn': 41.0, 'tp': 7.0, 'precision': 0.0737, 'recall': 0.1458, 'AUCPRC': 0.0174, 'F1': 0.0979, 'ROCAUC': 0.7625, 'MCC': 0.1015, 'ACC': 0.9955, 'GMEAN': 0.3813} 

fold4 =  {'tn': 28298.0, 'fp': 28.0, 'fn': 46.0, 'tp': 1.0, 'precision': 0.0345, 'recall': 0.0213, 'AUCPRC': 0.0021, 'F1': 0.0263, 'ROCAUC': 0.2507, 'MCC': 0.0258, 'ACC': 0.9974, 'GMEAN': 0.1458} 

fold5 = {'tn': 28278.0, 'fp': 47.0, 'fn': 46.0, 'tp': 2.0, 'precision': 0.0408, 'recall': 0.0417, 'AUCPRC': 0.0235, 'F1': 0.0412, 'ROCAUC': 0.2612, 'MCC': 0.0396, 'ACC': 0.9967, 'GMEAN': 0.204}

fold6 =  {'tn': 28270.0, 'fp': 56.0, 'fn': 37.0, 'tp': 10.0, 'precision': 0.1515, 'recall': 0.2128, 'AUCPRC': 0.0593, 'F1': 0.177, 'ROCAUC': 0.7943, 'MCC': 0.1779, 'ACC': 0.9967, 'GMEAN': 0.4608} 

fold7 =  {'tn': 28297.0, 'fp': 28.0, 'fn': 19.0, 'tp': 29.0, 'precision': 0.5088, 'recall': 0.6042, 'AUCPRC': 0.5197, 'F1': 0.5524, 'ROCAUC': 0.9596, 'MCC': 0.5536, 'ACC': 0.9983, 'GMEAN': 0.7769} 

fold8 =  {'tn': 28297.0, 'fp': 28.0, 'fn': 19.0, 'tp': 29.0, 'precision': 0.5088, 'recall': 0.6042, 'AUCPRC': 0.5197, 'F1': 0.5524, 'ROCAUC': 0.9596, 'MCC': 0.5536, 'ACC': 0.9983, 'GMEAN': 0.7769} 

fold9 =  {'tn': 28305.0, 'fp': 20.0, 'fn': 38.0, 'tp': 10.0, 'precision': 0.3333, 'recall': 0.2083, 'AUCPRC': 0.08, 'F1': 0.2564, 'ROCAUC': 0.7131, 'MCC': 0.2625, 'ACC': 0.998, 'GMEAN': 0.4563} 

fold10 =  {'tn': 28312.0, 'fp': 14.0, 'fn': 19.0, 'tp': 28.0, 'precision': 0.6667, 'recall': 0.5957, 'AUCPRC': 0.5711, 'F1': 0.6292, 'ROCAUC': 0.9932, 'MCC': 0.6296, 'ACC': 0.9988, 'GMEAN': 0.7717}

# %%
from model_utils.evaluation import table

# %%
import pandas as pd
from pandas import DataFrame as df

kfold_results = df(columns=['tn', 'fp', 'fn', 'tp', 'precision', 'recall', 'AUCPRC', 'F1', 'ROCAUC', 'MCC', 'ACC', 'GMEAN'])

for fold in [fold1, fold2, fold3, fold4, fold5, fold6, fold7, fold8, fold9, fold10]:
	kfold_results = pd.concat([kfold_results, df([fold])], ignore_index=True)

kfold_results = kfold_results.drop(['tn', 'fp', 'fn', 'tp', 'ROCAUC', 'ACC'] , axis=1)
kfold_results.agg(lambda x: f'{x.mean():.4f} ± {x.std():.4f}')
# Out:
# /var/folders/b5/y93p_qw91z98pk044cfd6b800000gn/T/ipykernel_28759/3826644129.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   kfold_results = pd.concat([kfold_results, df([fold])], ignore_index=True)
# precision    0.2546 ± 0.2358
# recall       0.2663 ± 0.2415
# AUCPRC       0.1857 ± 0.2441
# F1           0.2556 ± 0.2361
# MCC          0.2566 ± 0.2365
# GMEAN        0.4610 ± 0.2438
# dtype: object

# %%
kfold_results.describe().round(4)
# Out:
#        precision   recall   AUCPRC       F1      MCC    GMEAN
# count    10.0000  10.0000  10.0000  10.0000  10.0000  10.0000
# mean      0.2546   0.2663   0.1857   0.2556   0.2566   0.4610
# std       0.2358   0.2415   0.2441   0.2361   0.2365   0.2438
# min       0.0185   0.0213   0.0018   0.0256   0.0253   0.1458
# 25%       0.0490   0.0677   0.0189   0.0554   0.0551   0.2483
# 50%       0.1804   0.1979   0.0606   0.1874   0.1874   0.4446
# 75%       0.4649   0.5000   0.4098   0.4784   0.4808   0.6940
# max       0.6667   0.6042   0.5711   0.6292   0.6296   0.7769
