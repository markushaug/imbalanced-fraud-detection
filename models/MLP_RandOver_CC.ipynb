# %% [markdown]
# Model Architecture from https://keras.io/examples/structured_data/imbalanced_classification/

# %%
import pickle

# imoprt data science libraries
import pandas as pd
from pandas import DataFrame as df
import matplotlib.pyplot as plt
import numpy as np

# Import ML libraries
import keras
import model_utils as mutils
from model_utils.evaluation import get_metrics, evaluate_model, table
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler

current_k_fold = 9
# set seed
SEED=current_k_fold**3
np.random.seed(SEED)

# pandas options
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# deserialize pre-processed data
path_to_pickle = f'../data/creditcard/cc13_preprocessed_k{current_k_fold}.pkl'

with open(path_to_pickle, "rb") as f:
    data = pickle.load(f)
    X_train = data["X_train"].to_numpy()
    y_train = data["y_train"].to_numpy()

    X_val = data["X_val"].to_numpy()
    y_val = data["y_val"].to_numpy()

    X_test = data["X_test"].to_numpy()
    y_test = data["y_test"].to_numpy()

    col_names = data["col_names"]

print("Data loaded successfully")

# get imbalance ratio for each data set
IR_train = mutils.imb_ratio(data["y_train"].value_counts())
IR_val = mutils.imb_ratio(data["y_val"].value_counts())
IR_test = mutils.imb_ratio(data["y_test"].value_counts())

# print imbalance ratios. They should be (nearly) the same. pct = 0.172 such as in the paper!
print(f"Imbalance ratio in training data: {IR_train}")
print(f"Imbalance ratio in validation data: {IR_val}")
print(f"Imbalance ratio in test data: {IR_test}")

# print number of samples in each data set
print(f"\nNumber of samples in training data: {len(y_train)}")
print(f"Number of samples in validation data: {len(y_val)}")
print(f"Number of samples in test data: {len(y_test)}")

"""
## Oversample minority class for training only
"""

ros = RandomOverSampler(random_state=SEED, sampling_strategy=1)
X_train, y_train = ros.fit_resample(X_train, y_train)

res_value_counts = df(y_train).value_counts()

print("New Imbalance ratio:", mutils.imb_ratio(res_value_counts))

# Reshape
y_train = y_train.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)
y_val = y_val.reshape(-1, 1)

# Set Weight
weight_for_0 = 1.0 / res_value_counts[0]
weight_for_1 = 1.0 / res_value_counts[1]

# print number of samples in each data set
print(f"\nNumber of samples in training data: {len(y_train)}")
print(f"Number of samples in validation data: {len(y_val)}")
print(f"Number of samples in test data: {len(y_test)}")

# Normalize Data
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

"""
## Build a binary classification model. Credits: https://keras.io/examples/structured_data/imbalanced_classification/
"""
data_dim = np.shape(X_train)[1]
model = keras.Sequential(
    [
        keras.Input(shape=(data_dim,)),
        keras.layers.Dense(256, activation="relu"),
        keras.layers.Dense(256, activation="relu"),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(256, activation="relu"),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(1, activation="sigmoid"),
    ]
)
# Out:
# Data loaded successfully
# Imbalance ratio in training data: 599.48
# Imbalance ratio in validation data: 602.68
# Imbalance ratio in test data: 590.1
#
# Number of samples in training data: 226980
# Number of samples in validation data: 28373
# Number of samples in test data: 28373
# New Imbalance ratio: 1.0
#
# Number of samples in training data: 453204
# Number of samples in validation data: 28373
# Number of samples in test data: 28373

# %%
metrics = [
    keras.metrics.AUC(name="roc_auc", curve='ROC'),
    keras.metrics.AUC(name='auc_prc', curve="PR"),
	keras.metrics.F1Score(name="f1"),
	
    keras.metrics.FalseNegatives(name="fn"),
    keras.metrics.FalsePositives(name="fp"),
    keras.metrics.TrueNegatives(name="tn"),
    keras.metrics.TruePositives(name="tp"),
    keras.metrics.Precision(name="precision"),
    keras.metrics.Recall(name="recall"),
]

model.compile(
    optimizer=keras.optimizers.Adam(1e-2), loss="binary_crossentropy", metrics=metrics
)

callbacks = [keras.callbacks.ModelCheckpoint(f"./ckp/MLP_RandOver_CC/k{current_k_fold}"+"_epoch_{epoch}.keras")]
class_weight = {0: weight_for_0, 1: weight_for_1}
print("Weights: ", class_weight)

# TODO: check if you need callback! not that we overwrite good ckp's.
hist = model.fit(
    X_train,
    y_train,
    batch_size=2048,
    epochs=50,
    verbose=2,
    callbacks=callbacks,
    validation_data=(X_val, y_val),
    class_weight=class_weight,
)
# Out:
# Weights:  {0: 4.413023715589447e-06, 1: 4.413023715589447e-06}
# Epoch 1/50
# 222/222 - 4s - 16ms/step - auc_prc: 0.9745 - f1: 0.6667 - fn: 28152.0000 - fp: 11212.0000 - loss: 9.8281e-07 - precision: 0.9465 - recall: 0.8758 - roc_auc: 0.9696 - tn: 215390.0000 - tp: 198450.0000 - val_auc_prc: 0.6050 - val_f1: 0.0033 - val_fn: 4.0000 - val_fp: 446.0000 - val_loss: 0.0700 - val_precision: 0.0879 - val_recall: 0.9149 - val_roc_auc: 0.9829 - val_tn: 27880.0000 - val_tp: 43.0000
# Epoch 2/50
# 222/222 - 2s - 11ms/step - auc_prc: 0.9961 - f1: 0.6667 - fn: 9283.0000 - fp: 4328.0000 - loss: 3.5970e-07 - precision: 0.9805 - recall: 0.9590 - roc_auc: 0.9960 - tn: 222274.0000 - tp: 217319.0000 - val_auc_prc: 0.6306 - val_f1: 0.0033 - val_fn: 4.0000 - val_fp: 383.0000 - val_loss: 0.0493 - val_precision: 0.1009 - val_recall: 0.9149 - val_roc_auc: 0.9805 - val_tn: 27943.0000 - val_tp: 43.0000
# Epoch 3/50
# 222/222 - 2s - 10ms/step - auc_prc: 0.9990 - f1: 0.6677 - fn: 2254.0000 - fp: 2415.0000 - loss: 1.5507e-07 - precision: 0.9894 - recall: 0.9901 - roc_auc: 0.9992 - tn: 224187.0000 - tp: 224348.0000 - val_auc_prc: 0.6734 - val_f1: 0.0033 - val_fn: 5.0000 - val_fp: 194.0000 - val_loss: 0.0253 - val_precision: 0.1780 - val_recall: 0.8936 - val_roc_auc: 0.9818 - val_tn: 28132.0000 - val_tp: 42.0000
# Epoch 4/50
# 222/222 - 2s - 10ms/step - auc_prc: 0.9994 - f1: 0.6714 - fn: 295.0000 - fp: 1330.0000 - loss: 7.8886e-08 - precision: 0.9942 - recall: 0.9987 - roc_auc: 0.9996 - tn: 225272.0000 - tp: 226307.0000 - val_auc_prc: 0.7117 - val_f1: 0.0034 - val_fn: 6.0000 - val_fp: 101.0000 - val_loss: 0.0149 - val_precision: 0.2887 - val_recall: 0.8723 - val_roc_auc: 0.9652 - val_tn: 28225.0000 - val_tp: 41.0000
# Epoch 5/50
# 222/222 - 2s - 10ms/step - auc_prc: 0.9995 - f1: 0.6786 - fn: 94.0000 - fp: 882.0000 - loss: 5.2585e-08 - precision: 0.9961 - recall: 0.9996 - roc_auc: 0.9997 - tn: 225720.0000 - tp: 226508.0000 - val_auc_prc: 0.7132 - val_f1: 0.0035 - val_fn: 6.0000 - val_fp: 106.0000 - val_loss: 0.0154 - val_precision: 0.2789 - val_recall: 0.8723 - val_roc_auc: 0.9654 - val_tn: 28220.0000 - val_tp: 41.0000
# Epoch 6/50
# 222/222 - 2s - 11ms/step - auc_prc: 0.9996 - f1: 0.6876 - fn: 61.0000 - fp: 689.0000 - loss: 3.9789e-08 - precision: 0.9970 - recall: 0.9997 - roc_auc: 0.9998 - tn: 225913.0000 - tp: 226541.0000 - val_auc_prc: 0.7105 - val_f1: 0.0037 - val_fn: 7.0000 - val_fp: 61.0000 - val_loss: 0.0103 - val_precision: 0.3960 - val_recall: 0.8511 - val_roc_auc: 0.9558 - val_tn: 28265.0000 - val_tp: 40.0000
# Epoch 7/50
# 222/222 - 2s - 10ms/step - auc_prc: 0.9996 - f1: 0.6988 - fn: 26.0000 - fp: 506.0000 - loss: 3.1276e-08 - precision: 0.9978 - recall: 0.9999 - roc_auc: 0.9998 - tn: 226096.0000 - tp: 226576.0000 - val_auc_prc: 0.7149 - val_f1: 0.0039 - val_fn: 6.0000 - val_fp: 57.0000 - val_loss: 0.0095 - val_precision: 0.4184 - val_recall: 0.8723 - val_roc_auc: 0.9561 - val_tn: 28269.0000 - val_tp: 41.0000
# Epoch 8/50
# 222/222 - 2s - 10ms/step - auc_prc: 0.9996 - f1: 0.7092 - fn: 17.0000 - fp: 460.0000 - loss: 2.5641e-08 - precision: 0.9980 - recall: 0.9999 - roc_auc: 0.9998 - tn: 226142.0000 - tp: 226585.0000 - val_auc_prc: 0.7412 - val_f1: 0.0041 - val_fn: 6.0000 - val_fp: 37.0000 - val_loss: 0.0071 - val_precision: 0.5256 - val_recall: 0.8723 - val_roc_auc: 0.9564 - val_tn: 28289.0000 - val_tp: 41.0000
# Epoch 9/50
# 222/222 - 2s - 11ms/step - auc_prc: 0.9997 - f1: 0.7198 - fn: 8.0000 - fp: 388.0000 - loss: 2.1142e-08 - precision: 0.9983 - recall: 1.0000 - roc_auc: 0.9998 - tn: 226214.0000 - tp: 226594.0000 - val_auc_prc: 0.7397 - val_f1: 0.0043 - val_fn: 7.0000 - val_fp: 32.0000 - val_loss: 0.0064 - val_precision: 0.5556 - val_recall: 0.8511 - val_roc_auc: 0.9460 - val_tn: 28294.0000 - val_tp: 40.0000
# Epoch 10/50
# 222/222 - 2s - 10ms/step - auc_prc: 0.9997 - f1: 0.7321 - fn: 10.0000 - fp: 341.0000 - loss: 1.8013e-08 - precision: 0.9985 - recall: 1.0000 - roc_auc: 0.9998 - tn: 226261.0000 - tp: 226592.0000 - val_auc_prc: 0.7185 - val_f1: 0.0046 - val_fn: 6.0000 - val_fp: 27.0000 - val_loss: 0.0061 - val_precision: 0.6029 - val_recall: 0.8723 - val_roc_auc: 0.9460 - val_tn: 28299.0000 - val_tp: 41.0000
# Epoch 11/50
# 222/222 - 2s - 11ms/step - auc_prc: 0.9997 - f1: 0.7435 - fn: 4.0000 - fp: 288.0000 - loss: 1.5274e-08 - precision: 0.9987 - recall: 1.0000 - roc_auc: 0.9999 - tn: 226314.0000 - tp: 226598.0000 - val_auc_prc: 0.7459 - val_f1: 0.0049 - val_fn: 7.0000 - val_fp: 22.0000 - val_loss: 0.0056 - val_precision: 0.6452 - val_recall: 0.8511 - val_roc_auc: 0.9461 - val_tn: 28304.0000 - val_tp: 40.0000
# Epoch 12/50
# 222/222 - 3s - 11ms/step - auc_prc: 0.9998 - f1: 0.7539 - fn: 5.0000 - fp: 271.0000 - loss: 1.3487e-08 - precision: 0.9988 - recall: 1.0000 - roc_auc: 0.9999 - tn: 226331.0000 - tp: 226597.0000 - val_auc_prc: 0.7492 - val_f1: 0.0053 - val_fn: 7.0000 - val_fp: 26.0000 - val_loss: 0.0058 - val_precision: 0.6061 - val_recall: 0.8511 - val_roc_auc: 0.9462 - val_tn: 28300.0000 - val_tp: 40.0000
# Epoch 13/50
# 222/222 - 3s - 13ms/step - auc_prc: 0.9998 - f1: 0.7624 - fn: 2.0000 - fp: 242.0000 - loss: 1.2233e-08 - precision: 0.9989 - recall: 1.0000 - roc_auc: 0.9999 - tn: 226360.0000 - tp: 226600.0000 - val_auc_prc: 0.7856 - val_f1: 0.0059 - val_fn: 7.0000 - val_fp: 15.0000 - val_loss: 0.0051 - val_precision: 0.7273 - val_recall: 0.8511 - val_roc_auc: 0.9463 - val_tn: 28311.0000 - val_tp: 40.0000
# Epoch 14/50
# 222/222 - 3s - 14ms/step - auc_prc: 0.9998 - f1: 0.7724 - fn: 10.0000 - fp: 240.0000 - loss: 1.1431e-08 - precision: 0.9989 - recall: 1.0000 - roc_auc: 0.9999 - tn: 226362.0000 - tp: 226592.0000 - val_auc_prc: 0.7789 - val_f1: 0.0058 - val_fn: 7.0000 - val_fp: 18.0000 - val_loss: 0.0054 - val_precision: 0.6897 - val_recall: 0.8511 - val_roc_auc: 0.9463 - val_tn: 28308.0000 - val_tp: 40.0000
# Epoch 15/50
# 222/222 - 3s - 15ms/step - auc_prc: 0.9999 - f1: 0.7812 - fn: 2.0000 - fp: 202.0000 - loss: 9.9382e-09 - precision: 0.9991 - recall: 1.0000 - roc_auc: 0.9999 - tn: 226400.0000 - tp: 226600.0000 - val_auc_prc: 0.7759 - val_f1: 0.0066 - val_fn: 7.0000 - val_fp: 13.0000 - val_loss: 0.0053 - val_precision: 0.7547 - val_recall: 0.8511 - val_roc_auc: 0.9358 - val_tn: 28313.0000 - val_tp: 40.0000
# Epoch 16/50
# 222/222 - 3s - 13ms/step - auc_prc: 0.9998 - f1: 0.7880 - fn: 37.0000 - fp: 235.0000 - loss: 1.1727e-08 - precision: 0.9990 - recall: 0.9998 - roc_auc: 0.9999 - tn: 226367.0000 - tp: 226565.0000 - val_auc_prc: 0.7876 - val_f1: 0.0065 - val_fn: 7.0000 - val_fp: 17.0000 - val_loss: 0.0055 - val_precision: 0.7018 - val_recall: 0.8511 - val_roc_auc: 0.9463 - val_tn: 28309.0000 - val_tp: 40.0000
# Epoch 17/50
# 222/222 - 3s - 13ms/step - auc_prc: 0.9999 - f1: 0.7975 - fn: 3.0000 - fp: 177.0000 - loss: 8.4211e-09 - precision: 0.9992 - recall: 1.0000 - roc_auc: 0.9999 - tn: 226425.0000 - tp: 226599.0000 - val_auc_prc: 0.7866 - val_f1: 0.0073 - val_fn: 7.0000 - val_fp: 13.0000 - val_loss: 0.0053 - val_precision: 0.7547 - val_recall: 0.8511 - val_roc_auc: 0.9252 - val_tn: 28313.0000 - val_tp: 40.0000
# Epoch 18/50
# 222/222 - 3s - 13ms/step - auc_prc: 0.9999 - f1: 0.8078 - fn: 2.0000 - fp: 156.0000 - loss: 7.8851e-09 - precision: 0.9993 - recall: 1.0000 - roc_auc: 0.9999 - tn: 226446.0000 - tp: 226600.0000 - val_auc_prc: 0.8537 - val_f1: 0.0079 - val_fn: 7.0000 - val_fp: 15.0000 - val_loss: 0.0051 - val_precision: 0.7273 - val_recall: 0.8511 - val_roc_auc: 0.9360 - val_tn: 28311.0000 - val_tp: 40.0000
# Epoch 19/50
# 222/222 - 3s - 14ms/step - auc_prc: 0.9999 - f1: 0.8101 - fn: 9.0000 - fp: 165.0000 - loss: 7.6700e-09 - precision: 0.9993 - recall: 1.0000 - roc_auc: 0.9999 - tn: 226437.0000 - tp: 226593.0000 - val_auc_prc: 0.7943 - val_f1: 0.0068 - val_fn: 7.0000 - val_fp: 25.0000 - val_loss: 0.0059 - val_precision: 0.6154 - val_recall: 0.8511 - val_roc_auc: 0.9462 - val_tn: 28301.0000 - val_tp: 40.0000
# Epoch 20/50
# 222/222 - 3s - 14ms/step - auc_prc: 0.9999 - f1: 0.8196 - fn: 2.0000 - fp: 137.0000 - loss: 6.7365e-09 - precision: 0.9994 - recall: 1.0000 - roc_auc: 0.9999 - tn: 226465.0000 - tp: 226600.0000 - val_auc_prc: 0.8078 - val_f1: 0.0081 - val_fn: 7.0000 - val_fp: 14.0000 - val_loss: 0.0055 - val_precision: 0.7407 - val_recall: 0.8511 - val_roc_auc: 0.9358 - val_tn: 28312.0000 - val_tp: 40.0000
# Epoch 21/50
# 222/222 - 3s - 12ms/step - auc_prc: 0.9999 - f1: 0.8231 - fn: 1.0000 - fp: 131.0000 - loss: 6.5557e-09 - precision: 0.9994 - recall: 1.0000 - roc_auc: 0.9999 - tn: 226471.0000 - tp: 226601.0000 - val_auc_prc: 0.8110 - val_f1: 0.0087 - val_fn: 7.0000 - val_fp: 11.0000 - val_loss: 0.0054 - val_precision: 0.7843 - val_recall: 0.8511 - val_roc_auc: 0.9359 - val_tn: 28315.0000 - val_tp: 40.0000
# Epoch 22/50
# 222/222 - 3s - 13ms/step - auc_prc: 0.9999 - f1: 0.8294 - fn: 3.0000 - fp: 121.0000 - loss: 5.8929e-09 - precision: 0.9995 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226481.0000 - tp: 226599.0000 - val_auc_prc: 0.8479 - val_f1: 0.0089 - val_fn: 7.0000 - val_fp: 9.0000 - val_loss: 0.0050 - val_precision: 0.8163 - val_recall: 0.8511 - val_roc_auc: 0.9253 - val_tn: 28317.0000 - val_tp: 40.0000
# Epoch 23/50
# 222/222 - 3s - 13ms/step - auc_prc: 0.9999 - f1: 0.8342 - fn: 3.0000 - fp: 114.0000 - loss: 5.5575e-09 - precision: 0.9995 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226488.0000 - tp: 226599.0000 - val_auc_prc: 0.8196 - val_f1: 0.0084 - val_fn: 7.0000 - val_fp: 19.0000 - val_loss: 0.0056 - val_precision: 0.6780 - val_recall: 0.8511 - val_roc_auc: 0.9253 - val_tn: 28307.0000 - val_tp: 40.0000
# Epoch 24/50
# 222/222 - 3s - 14ms/step - auc_prc: 0.9999 - f1: 0.8371 - fn: 1.0000 - fp: 110.0000 - loss: 5.2901e-09 - precision: 0.9995 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226492.0000 - tp: 226601.0000 - val_auc_prc: 0.8318 - val_f1: 0.0091 - val_fn: 7.0000 - val_fp: 15.0000 - val_loss: 0.0055 - val_precision: 0.7273 - val_recall: 0.8511 - val_roc_auc: 0.9359 - val_tn: 28311.0000 - val_tp: 40.0000
# Epoch 25/50
# 222/222 - 3s - 12ms/step - auc_prc: 0.9999 - f1: 0.8407 - fn: 1.0000 - fp: 105.0000 - loss: 5.2286e-09 - precision: 0.9995 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226497.0000 - tp: 226601.0000 - val_auc_prc: 0.7874 - val_f1: 0.0091 - val_fn: 7.0000 - val_fp: 13.0000 - val_loss: 0.0055 - val_precision: 0.7547 - val_recall: 0.8511 - val_roc_auc: 0.9252 - val_tn: 28313.0000 - val_tp: 40.0000
# Epoch 26/50
# 222/222 - 2s - 10ms/step - auc_prc: 0.9999 - f1: 0.8461 - fn: 1.0000 - fp: 102.0000 - loss: 4.7864e-09 - precision: 0.9996 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226500.0000 - tp: 226601.0000 - val_auc_prc: 0.8086 - val_f1: 0.0101 - val_fn: 7.0000 - val_fp: 10.0000 - val_loss: 0.0055 - val_precision: 0.8000 - val_recall: 0.8511 - val_roc_auc: 0.9253 - val_tn: 28316.0000 - val_tp: 40.0000
# Epoch 27/50
# 222/222 - 2s - 10ms/step - auc_prc: 0.9999 - f1: 0.8419 - fn: 10.0000 - fp: 129.0000 - loss: 8.3806e-09 - precision: 0.9994 - recall: 1.0000 - roc_auc: 0.9999 - tn: 226473.0000 - tp: 226592.0000 - val_auc_prc: 0.8346 - val_f1: 0.0101 - val_fn: 7.0000 - val_fp: 10.0000 - val_loss: 0.0051 - val_precision: 0.8000 - val_recall: 0.8511 - val_roc_auc: 0.9360 - val_tn: 28316.0000 - val_tp: 40.0000
# Epoch 28/50
# 222/222 - 2s - 10ms/step - auc_prc: 0.9999 - f1: 0.8496 - fn: 6.0000 - fp: 107.0000 - loss: 5.0223e-09 - precision: 0.9995 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226495.0000 - tp: 226596.0000 - val_auc_prc: 0.8127 - val_f1: 0.0098 - val_fn: 7.0000 - val_fp: 12.0000 - val_loss: 0.0056 - val_precision: 0.7692 - val_recall: 0.8511 - val_roc_auc: 0.9359 - val_tn: 28314.0000 - val_tp: 40.0000
# Epoch 29/50
# 222/222 - 2s - 10ms/step - auc_prc: 0.9999 - f1: 0.8557 - fn: 3.0000 - fp: 88.0000 - loss: 4.0769e-09 - precision: 0.9996 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226514.0000 - tp: 226599.0000 - val_auc_prc: 0.8499 - val_f1: 0.0112 - val_fn: 7.0000 - val_fp: 10.0000 - val_loss: 0.0051 - val_precision: 0.8000 - val_recall: 0.8511 - val_roc_auc: 0.9254 - val_tn: 28316.0000 - val_tp: 40.0000
# Epoch 30/50
# 222/222 - 2s - 10ms/step - auc_prc: 1.0000 - f1: 0.8624 - fn: 2.0000 - fp: 83.0000 - loss: 3.7989e-09 - precision: 0.9996 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226519.0000 - tp: 226600.0000 - val_auc_prc: 0.8496 - val_f1: 0.0124 - val_fn: 7.0000 - val_fp: 9.0000 - val_loss: 0.0055 - val_precision: 0.8163 - val_recall: 0.8511 - val_roc_auc: 0.9254 - val_tn: 28317.0000 - val_tp: 40.0000
# Epoch 31/50
# 222/222 - 2s - 9ms/step - auc_prc: 0.9999 - f1: 0.8628 - fn: 2.0000 - fp: 85.0000 - loss: 4.2296e-09 - precision: 0.9996 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226517.0000 - tp: 226600.0000 - val_auc_prc: 0.8071 - val_f1: 0.0110 - val_fn: 7.0000 - val_fp: 10.0000 - val_loss: 0.0055 - val_precision: 0.8000 - val_recall: 0.8511 - val_roc_auc: 0.9253 - val_tn: 28316.0000 - val_tp: 40.0000
# Epoch 32/50
# 222/222 - 2s - 10ms/step - auc_prc: 1.0000 - f1: 0.8660 - fn: 2.0000 - fp: 84.0000 - loss: 3.9056e-09 - precision: 0.9996 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226518.0000 - tp: 226600.0000 - val_auc_prc: 0.8254 - val_f1: 0.0114 - val_fn: 7.0000 - val_fp: 9.0000 - val_loss: 0.0055 - val_precision: 0.8163 - val_recall: 0.8511 - val_roc_auc: 0.9254 - val_tn: 28317.0000 - val_tp: 40.0000
# Epoch 33/50
# 222/222 - 2s - 10ms/step - auc_prc: 1.0000 - f1: 0.8695 - fn: 2.0000 - fp: 82.0000 - loss: 3.7843e-09 - precision: 0.9996 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226520.0000 - tp: 226600.0000 - val_auc_prc: 0.8068 - val_f1: 0.0101 - val_fn: 7.0000 - val_fp: 17.0000 - val_loss: 0.0058 - val_precision: 0.7018 - val_recall: 0.8511 - val_roc_auc: 0.9253 - val_tn: 28309.0000 - val_tp: 40.0000
# Epoch 34/50
# 222/222 - 2s - 10ms/step - auc_prc: 1.0000 - f1: 0.8705 - fn: 3.0000 - fp: 75.0000 - loss: 3.7258e-09 - precision: 0.9997 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226527.0000 - tp: 226599.0000 - val_auc_prc: 0.8460 - val_f1: 0.0138 - val_fn: 7.0000 - val_fp: 7.0000 - val_loss: 0.0051 - val_precision: 0.8511 - val_recall: 0.8511 - val_roc_auc: 0.9254 - val_tn: 28319.0000 - val_tp: 40.0000
# Epoch 35/50
# 222/222 - 2s - 10ms/step - auc_prc: 0.9999 - f1: 0.8762 - fn: 1.0000 - fp: 78.0000 - loss: 3.5226e-09 - precision: 0.9997 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226524.0000 - tp: 226601.0000 - val_auc_prc: 0.8064 - val_f1: 0.0116 - val_fn: 7.0000 - val_fp: 11.0000 - val_loss: 0.0053 - val_precision: 0.7843 - val_recall: 0.8511 - val_roc_auc: 0.9253 - val_tn: 28315.0000 - val_tp: 40.0000
# Epoch 36/50
# 222/222 - 2s - 10ms/step - auc_prc: 1.0000 - f1: 0.8793 - fn: 1.0000 - fp: 68.0000 - loss: 3.2741e-09 - precision: 0.9997 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226534.0000 - tp: 226601.0000 - val_auc_prc: 0.8462 - val_f1: 0.0133 - val_fn: 7.0000 - val_fp: 8.0000 - val_loss: 0.0053 - val_precision: 0.8333 - val_recall: 0.8511 - val_roc_auc: 0.9254 - val_tn: 28318.0000 - val_tp: 40.0000
# Epoch 37/50
# 222/222 - 2s - 11ms/step - auc_prc: 1.0000 - f1: 0.8840 - fn: 0.0000e+00 - fp: 70.0000 - loss: 3.0003e-09 - precision: 0.9997 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226532.0000 - tp: 226602.0000 - val_auc_prc: 0.8465 - val_f1: 0.0157 - val_fn: 7.0000 - val_fp: 8.0000 - val_loss: 0.0055 - val_precision: 0.8333 - val_recall: 0.8511 - val_roc_auc: 0.9254 - val_tn: 28318.0000 - val_tp: 40.0000
# Epoch 38/50
# 222/222 - 2s - 11ms/step - auc_prc: 1.0000 - f1: 0.8864 - fn: 1.0000 - fp: 57.0000 - loss: 2.9198e-09 - precision: 0.9997 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226545.0000 - tp: 226601.0000 - val_auc_prc: 0.7887 - val_f1: 0.0170 - val_fn: 7.0000 - val_fp: 9.0000 - val_loss: 0.0061 - val_precision: 0.8163 - val_recall: 0.8511 - val_roc_auc: 0.9254 - val_tn: 28317.0000 - val_tp: 40.0000
# Epoch 39/50
# 222/222 - 2s - 10ms/step - auc_prc: 0.9999 - f1: 0.8846 - fn: 4.0000 - fp: 75.0000 - loss: 3.4931e-09 - precision: 0.9997 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226527.0000 - tp: 226598.0000 - val_auc_prc: 0.8257 - val_f1: 0.0142 - val_fn: 7.0000 - val_fp: 9.0000 - val_loss: 0.0055 - val_precision: 0.8163 - val_recall: 0.8511 - val_roc_auc: 0.9254 - val_tn: 28317.0000 - val_tp: 40.0000
# Epoch 40/50
# 222/222 - 2s - 9ms/step - auc_prc: 1.0000 - f1: 0.8906 - fn: 3.0000 - fp: 65.0000 - loss: 3.2292e-09 - precision: 0.9997 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226537.0000 - tp: 226599.0000 - val_auc_prc: 0.8259 - val_f1: 0.0173 - val_fn: 7.0000 - val_fp: 6.0000 - val_loss: 0.0056 - val_precision: 0.8696 - val_recall: 0.8511 - val_roc_auc: 0.9254 - val_tn: 28320.0000 - val_tp: 40.0000
# Epoch 41/50
# 222/222 - 2s - 10ms/step - auc_prc: 1.0000 - f1: 0.8918 - fn: 2.0000 - fp: 61.0000 - loss: 2.9935e-09 - precision: 0.9997 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226541.0000 - tp: 226600.0000 - val_auc_prc: 0.7885 - val_f1: 0.0126 - val_fn: 7.0000 - val_fp: 12.0000 - val_loss: 0.0060 - val_precision: 0.7692 - val_recall: 0.8511 - val_roc_auc: 0.9253 - val_tn: 28314.0000 - val_tp: 40.0000
# Epoch 42/50
# 222/222 - 2s - 10ms/step - auc_prc: 0.9999 - f1: 0.8872 - fn: 14.0000 - fp: 84.0000 - loss: 4.2747e-09 - precision: 0.9996 - recall: 0.9999 - roc_auc: 1.0000 - tn: 226518.0000 - tp: 226588.0000 - val_auc_prc: 0.8459 - val_f1: 0.0160 - val_fn: 7.0000 - val_fp: 7.0000 - val_loss: 0.0056 - val_precision: 0.8511 - val_recall: 0.8511 - val_roc_auc: 0.9254 - val_tn: 28319.0000 - val_tp: 40.0000
# Epoch 43/50
# 222/222 - 2s - 10ms/step - auc_prc: 1.0000 - f1: 0.8953 - fn: 3.0000 - fp: 67.0000 - loss: 3.0482e-09 - precision: 0.9997 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226535.0000 - tp: 226599.0000 - val_auc_prc: 0.7901 - val_f1: 0.0161 - val_fn: 7.0000 - val_fp: 9.0000 - val_loss: 0.0060 - val_precision: 0.8163 - val_recall: 0.8511 - val_roc_auc: 0.9254 - val_tn: 28317.0000 - val_tp: 40.0000
# Epoch 44/50
# 222/222 - 2s - 10ms/step - auc_prc: 0.9999 - f1: 0.9012 - fn: 5.0000 - fp: 56.0000 - loss: 2.8876e-09 - precision: 0.9998 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226546.0000 - tp: 226597.0000 - val_auc_prc: 0.8083 - val_f1: 0.0157 - val_fn: 7.0000 - val_fp: 7.0000 - val_loss: 0.0056 - val_precision: 0.8511 - val_recall: 0.8511 - val_roc_auc: 0.9254 - val_tn: 28319.0000 - val_tp: 40.0000
# Epoch 45/50
# 222/222 - 2s - 10ms/step - auc_prc: 1.0000 - f1: 0.9020 - fn: 1.0000 - fp: 52.0000 - loss: 2.7136e-09 - precision: 0.9998 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226550.0000 - tp: 226601.0000 - val_auc_prc: 0.7911 - val_f1: 0.0155 - val_fn: 7.0000 - val_fp: 8.0000 - val_loss: 0.0058 - val_precision: 0.8333 - val_recall: 0.8511 - val_roc_auc: 0.9253 - val_tn: 28318.0000 - val_tp: 40.0000
# Epoch 46/50
# 222/222 - 2s - 10ms/step - auc_prc: 1.0000 - f1: 0.9039 - fn: 3.0000 - fp: 60.0000 - loss: 2.7821e-09 - precision: 0.9997 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226542.0000 - tp: 226599.0000 - val_auc_prc: 0.8098 - val_f1: 0.0176 - val_fn: 7.0000 - val_fp: 9.0000 - val_loss: 0.0059 - val_precision: 0.8163 - val_recall: 0.8511 - val_roc_auc: 0.9254 - val_tn: 28317.0000 - val_tp: 40.0000
# Epoch 47/50
# 222/222 - 2s - 9ms/step - auc_prc: 1.0000 - f1: 0.9033 - fn: 2.0000 - fp: 49.0000 - loss: 2.2871e-09 - precision: 0.9998 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226553.0000 - tp: 226600.0000 - val_auc_prc: 0.8091 - val_f1: 0.0171 - val_fn: 7.0000 - val_fp: 8.0000 - val_loss: 0.0056 - val_precision: 0.8333 - val_recall: 0.8511 - val_roc_auc: 0.9254 - val_tn: 28318.0000 - val_tp: 40.0000
# Epoch 48/50
# 222/222 - 2s - 10ms/step - auc_prc: 1.0000 - f1: 0.9052 - fn: 4.0000 - fp: 56.0000 - loss: 2.7568e-09 - precision: 0.9998 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226546.0000 - tp: 226598.0000 - val_auc_prc: 0.8287 - val_f1: 0.0144 - val_fn: 7.0000 - val_fp: 10.0000 - val_loss: 0.0058 - val_precision: 0.8000 - val_recall: 0.8511 - val_roc_auc: 0.9253 - val_tn: 28316.0000 - val_tp: 40.0000
# Epoch 49/50
# 222/222 - 2s - 10ms/step - auc_prc: 1.0000 - f1: 0.9063 - fn: 1.0000 - fp: 51.0000 - loss: 2.4583e-09 - precision: 0.9998 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226551.0000 - tp: 226601.0000 - val_auc_prc: 0.8296 - val_f1: 0.0207 - val_fn: 7.0000 - val_fp: 4.0000 - val_loss: 0.0056 - val_precision: 0.9091 - val_recall: 0.8511 - val_roc_auc: 0.9254 - val_tn: 28322.0000 - val_tp: 40.0000
# Epoch 50/50
# 222/222 - 2s - 10ms/step - auc_prc: 1.0000 - f1: 0.9083 - fn: 1.0000 - fp: 42.0000 - loss: 2.1914e-09 - precision: 0.9998 - recall: 1.0000 - roc_auc: 1.0000 - tn: 226560.0000 - tp: 226601.0000 - val_auc_prc: 0.8504 - val_f1: 0.0190 - val_fn: 7.0000 - val_fp: 8.0000 - val_loss: 0.0060 - val_precision: 0.8333 - val_recall: 0.8511 - val_roc_auc: 0.9254 - val_tn: 28318.0000 - val_tp: 40.0000

# %%
# getting best epoch 
metric_history = hist.history["val_auc_prc"]
best_epoch = metric_history.index(max(metric_history)) + 1
print("Best epoch: ", best_epoch, "Best Value: ", max(metric_history))

# best_epoch=50
print("current fold: ", current_k_fold)
model.load_weights(f'./ckp/MLP_RandOver_CC/k{current_k_fold}_epoch_{best_epoch}.keras')
evaluate_model(model, X_test, y_test, as_table=True)
# Out:
# Best epoch:  18 Best Value:  0.8537222743034363
# current fold:  9
#    Model Name  AUCPRC      F1  G-Mean     MCC  Precision  Recall  ROCAUC  \
# 0  Sequential  0.7484  0.7556  0.8415  0.7569     0.8095  0.7083  0.9449
#
#    ACCURACY    TP   FP       TN    FN
# 0    0.9992  34.0  8.0  28317.0  14.0

# %%
# getting best epoch 
metric_history = hist.history["val_auc_prc"]
best_epoch = metric_history.index(max(metric_history)) + 1
print("Best epoch: ", best_epoch, "Best Value: ", max(metric_history))

# best_epoch=50
model.load_weights(f'./ckp/MLP_RandOver_CC/k{current_k_fold}_epoch_{best_epoch}.keras')
evaluate_model(model, X_test, y_test, as_table=True)
# Out:
#    Model Name  AUCPRC  ROCAUC      F1  G-Mean     MCC  ACCURACY    TP   FP  \
# 0  Sequential  0.8998  0.9902  0.8842  0.9452  0.8841    0.9996  42.0  6.0
#
#         TN   FN  Precision    Recall
# 0  28320.0  5.0      0.875  0.893617
