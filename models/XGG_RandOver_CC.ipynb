# %%
# load libraries
import pandas as pd
from pandas import DataFrame as df
import pickle
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
import xgboost as xgb
import matplotlib.pyplot as plt
import numpy as np
import time

# local module with helper utils
import model_utils as mutils
from model_utils.evaluation import get_metrics, evaluate_model

from imblearn.over_sampling import RandomOverSampler

current_k_fold = 10
# set seed
SEED=current_k_fold**3
np.random.seed(SEED)


# pandas options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# deserialize pre-processed data
path_to_pickle = f'../data/creditcard/cc13_preprocessed_k{current_k_fold}.pkl'

with open(path_to_pickle, 'rb') as f:
    data = pickle.load(f)
    X_train = data['X_train']
    y_train = data['y_train']

    X_val = data['X_val']
    y_val = data['y_val']

    X_test = data['X_test']
    y_test = data['y_test']

print('Data loaded successfully')

# get imbalance ratio for each data set
IR_train = mutils.imb_ratio(y_train.value_counts())
IR_val = mutils.imb_ratio(y_val.value_counts())
IR_test = mutils.imb_ratio(y_test.value_counts())

# print imbalance ratios. They should be (nearly) the same. pct = 0.172 such as in the paper!
print(f"Imbalance ratio in training data: {IR_train}")
print(f"Imbalance ratio in validation data: {IR_val}")
print(f"Imbalance ratio in test data: {IR_test}")

# print number of samples in each data set
print(f"\nNumber of samples in training data: {len(y_train)}")
print(f"Number of samples in validation data: {len(y_val)}")
print(f"Number of samples in test data: {len(y_test)}")

"""
## Oversample minority class for training only
"""

ros = RandomOverSampler(random_state=SEED, sampling_strategy=1)
X_train, y_train = ros.fit_resample(X_train.to_numpy(), y_train.to_numpy())

res_value_counts = df(y_train).value_counts()

print("New Imbalance ratio:", mutils.imb_ratio(res_value_counts))
# Out:
# Data loaded successfully
# Imbalance ratio in training data: 599.48
# Imbalance ratio in validation data: 590.1
# Imbalance ratio in test data: 602.68
#
# Number of samples in training data: 226980
# Number of samples in validation data: 28373
# Number of samples in test data: 28373
# New Imbalance ratio: 1.0

# %% [markdown]
# # Hyperparameter finding and tuning
#
# ## Grid Tuning

# %%
# xbg hyperparams grid search

# hyperparams grid; params from https://xgboost.readthedocs.io/en/latest/parameter.html & https://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/#:~:text=to%20Booster%20parameters.-,Booster%20Parameters,-Though%C2%A0there%20are
search_space_grid_tuned_1= {
     # general params
    'device': [mutils.get_device()], # specify the device to be used for XGBoost
    'objective': ['binary:logistic'], # logistic regression for binary classification, output probability
    'verbose': [3], # 0 (silent), 1 (warning), 2 (info), 3 (debug)

    # tree booster params
    'max_leaves': [2**8],
    'learning_rate': [0.1, 0.3], # alias: eta, step size
    'gamma': [0.1, 0.3], # min loss reduction to create new tree split
    'max_depth': [7, 8], # max depth of tree
    'subsample': [0.7, 1],
   # 'colsample_bytree': [0.5, 0.7, 1], # subsample ratio of columns when constructing each tree
    'reg_alpha': [0.9, 1], # l1 regularization term on weights
    'reg_lambda': [0.3, 1], # l2 regularization term on weights
    'scale_pos_weight': [1, 2, 4, 580], # control balance of positive and negative weights, useful for unbalanced classes. recommended to start with sum(negative instances) / sum(positive instances)
}

# clf = XGBClassifier(random_state=SEED, verbose=1, device=mutils.get_device())

# search  = GridSearchCV(clf, param_grid, scoring='roc_auc', verbose=1)
# search.fit(X_train, y_train)

# -> executed on Google Colab on A100 GPU, took ~ 37 minutes
# load clf from pickle
# clf_pkl = 'clf_xgb_cc.pkl'

# with open(clf_pkl, 'rb') as f:
#     data = pickle.load(f)
#     search = data['search']
#     results_df = data['results']

# results_df.head()

# %% [markdown]
# ## RandomSearch Tuning

# %%
# search space

# hyperparams grid; params from https://xgboost.readthedocs.io/en/latest/parameter.html & https://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/#:~:text=to%20Booster%20parameters.-,Booster%20Parameters,-Though%C2%A0there%20are
search_space_random_tuned_1= {
     # general params
    'device': [mutils.get_device()], # specify the device to be used for XGBoost
    'objective': ['binary:logistic'], # logistic regression for binary classification, output probability

    # tree booster params
    'max_leaves': [0, 2**6, 2**8], # default 0
    'learning_rate': [0.002, 0.1, 0.3], # alias: eta, step size
    'gamma': [0.1, 0.3], # min loss reduction to create new tree split
    'max_depth': [6, 12, 20, 25], # max depth of tree
    'subsample': [0.4, 0.7, 1],
    'colsample_bytree': [0.4, 0.5, 0.7, 1], # subsample ratio of columns when constructing each tree
    'reg_alpha': [0, 0.9, 1], # l1 regularization term on weights, default = 0
    'reg_lambda': [0.3, 1], # l2 regularization term on weights, default = 1
    'scale_pos_weight': [1, 2, 4, 580], # control balance of positive and negative weights, useful for unbalanced classes. recommended to start with sum(negative instances) / sum(positive instances)
    'eval_metric': ['auc'],
    'n_estimators': [100, 170, 500, 700, 1000, 2000, 5000],
    'booster': ['gbtree'],
    'tree_method': ['hist'],
}

clf = XGBClassifier(random_state=SEED, device=mutils.get_device())

random_search  = RandomizedSearchCV(clf, search_space_random_tuned_1, scoring='roc_auc', verbose=2, cv=5)
# random_search.fit(X_train, y_train)

# %%
rs_search_winner = random_search.best_estimator_
rs_search_winner.get_params()

# %%
rs_search_winner = random_search.best_estimator_
rs_search_winner.get_params()

# %% [markdown]
# # Train the model

# %%
param_grid_search_tuned_1 = {
    # general params
    "device": mutils.get_device(),  # specify the device to be used for XGBoost
    "objective": "binary:logistic",  # logistic regression for binary classification, output probability,
    # tree booster params
    "max_leaves": 2**8,
    "learning_rate": 0.3,  # alias: learning_rate, step size
    "gamma": 0.3,  # min loss reduction to create new tree split
    "max_depth": 6,  # max depth of tree
    "subsample": 0.7,
    # 'colsample_bytree': [0.5, 0.7, 1], # subsample ratio of columns when constructing each tree
    "reg_alpha": 1,  # l1 regularization term on weights
    "reg_lambda": 0.3,  # l2 regularization term on weights
    "scale_pos_weight": 580,  # control balance of positive and negative weights, useful for unbalanced classes. recommended to start with sum(negative instances) / sum(positive instances),
    "eval_metric": "auc",
    "n_estimators": 170,
    "booster": "gbtree",
    "tree_method": "hist",
}

param_random_searched_tuned = {
    "objective": "binary:logistic",
    "booster": "gbtree",
    "colsample_bytree": 0.7,
    "device": mutils.get_device(),
    "gamma": 0.1,
    "learning_rate": 0.1,
    "max_depth": 20,
    "max_leaves": 256,
    "n_estimators": 2000,
    "reg_alpha": 1,
    "reg_lambda": 1,
    "scale_pos_weight": 2,
    "subsample": 0.4,
    "tree_method": "hist",
	'eval_metric': 'auc',
}

param_adjusted_vanilla_xgb = {
    # general params
    "device": mutils.get_device(),  # specify the device to be used for XGBoost
    "objective": "binary:logistic",  # logistic regression for binary classification, output probability
    "scale_pos_weight": 580,  # control balance of positive and negative weights, useful for unbalanced classes. recommended to start with sum(negative instances) / sum(positive instances)
    "eval_metric": "auc",
    "booster": "gbtree",
    "tree_method": "hist",
}

# %%
# pandas.core.series.Series/Numpy to DataFrame
y_train = df(y_train)
y_val = df(y_val)
y_test = df(y_test)

# RandomOversampling removes column and returns numpy, reverse it
X_train = df(X_train)
X_train.columns = X_val.columns

eval_set = [(X_val, y_val)]

"""
Grid Tuned 1
"""
grid_tuned_1 = XGBClassifier(random_state=SEED, **param_grid_search_tuned_1)

grid_tuned_1.fit(X_train, y_train, eval_set=eval_set)

"""
Random Searched
"""
st = time.time()
random_search_tuned = XGBClassifier(random_state=SEED, **param_random_searched_tuned)

random_search_tuned.fit(X_train, y_train, eval_set=eval_set)
elapsed = time.time() - st
print('RStuned Execution time:', time.strftime("%H:%M:%S", time.gmtime(elapsed)))

"""
Vanilla XGB

- using default params: https://xgboost.readthedocs.io/en/stable/parameter.html#
"""
vanilla_xgb = XGBClassifier(random_state=SEED)

vanilla_xgb.fit(X_train, y_train, eval_set=eval_set)

"""
Slightly Adjusted Vanilla XGB
"""
adjusted_vanilla_xgb = XGBClassifier(random_state=SEED, **param_adjusted_vanilla_xgb)

adjusted_vanilla_xgb.fit(X_train, y_train, eval_set=eval_set)
# Out:
# [0]	validation_0-auc:0.69883
# [1]	validation_0-auc:0.91949
# [2]	validation_0-auc:0.92790
# [3]	validation_0-auc:0.92186
# [4]	validation_0-auc:0.93331
# [5]	validation_0-auc:0.92481
# [6]	validation_0-auc:0.92319
# [7]	validation_0-auc:0.91307
# [8]	validation_0-auc:0.91324
# [9]	validation_0-auc:0.88812
# [10]	validation_0-auc:0.89063
# [11]	validation_0-auc:0.89146
# [12]	validation_0-auc:0.89852
# [13]	validation_0-auc:0.90275
# [14]	validation_0-auc:0.88876
# [15]	validation_0-auc:0.87526
# [16]	validation_0-auc:0.87767
# [17]	validation_0-auc:0.86637
# [18]	validation_0-auc:0.86662
# [19]	validation_0-auc:0.86505
# [20]	validation_0-auc:0.86341
# [21]	validation_0-auc:0.86315
# [22]	validation_0-auc:0.85979
# [23]	validation_0-auc:0.86032
# [24]	validation_0-auc:0.86123
# [25]	validation_0-auc:0.86174
# [26]	validation_0-auc:0.86214
# [27]	validation_0-auc:0.86152
# [28]	validation_0-auc:0.86079
# [29]	validation_0-auc:0.85938
# [30]	validation_0-auc:0.86033
# [31]	validation_0-auc:0.85968
# [32]	validation_0-auc:0.86011
# [33]	validation_0-auc:0.85889
# [34]	validation_0-auc:0.85882
# [35]	validation_0-auc:0.85760
# [36]	validation_0-auc:0.85781
# [37]	validation_0-auc:0.85863
# [38]	validation_0-auc:0.85873
# [39]	validation_0-auc:0.86021
# [40]	validation_0-auc:0.85892
# [41]	validation_0-auc:0.85968
# [42]	validation_0-auc:0.85867
# [43]	validation_0-auc:0.85768
# [44]	validation_0-auc:0.85727
# [45]	validation_0-auc:0.85591
# [46]	validation_0-auc:0.85811
# [47]	validation_0-auc:0.85774
# [48]	validation_0-auc:0.85709
# [49]	validation_0-auc:0.85688
# [50]	validation_0-auc:0.85711
# [51]	validation_0-auc:0.85763
# [52]	validation_0-auc:0.85782
# [53]	validation_0-auc:0.85689
# [54]	validation_0-auc:0.85672
# [55]	validation_0-auc:0.85762
# [56]	validation_0-auc:0.85749
# [57]	validation_0-auc:0.85659
# [58]	validation_0-auc:0.85712
# [59]	validation_0-auc:0.85797
# [60]	validation_0-auc:0.85768
# [61]	validation_0-auc:0.85724
# [62]	validation_0-auc:0.85677
# [63]	validation_0-auc:0.85685
# [64]	validation_0-auc:0.85617
# [65]	validation_0-auc:0.85705
# [66]	validation_0-auc:0.85704
# [67]	validation_0-auc:0.85760
# [68]	validation_0-auc:0.85879
# [69]	validation_0-auc:0.85911
# [70]	validation_0-auc:0.85942
# [71]	validation_0-auc:0.86003
# [72]	validation_0-auc:0.86007
# [73]	validation_0-auc:0.86015
# [74]	validation_0-auc:0.86025
# [75]	validation_0-auc:0.86013
# [76]	validation_0-auc:0.86043
# [77]	validation_0-auc:0.86107
# [78]	validation_0-auc:0.85998
# [79]	validation_0-auc:0.86067
# [80]	validation_0-auc:0.86089
# [81]	validation_0-auc:0.86130
# [82]	validation_0-auc:0.86107
# [83]	validation_0-auc:0.86107
# [84]	validation_0-auc:0.86108
# [85]	validation_0-auc:0.86019
# [86]	validation_0-auc:0.86019
# [87]	validation_0-auc:0.86041
# [88]	validation_0-auc:0.86039
# [89]	validation_0-auc:0.86046
# [90]	validation_0-auc:0.86046
# [91]	validation_0-auc:0.86042
# [92]	validation_0-auc:0.86042
# [93]	validation_0-auc:0.86095
# [94]	validation_0-auc:0.86041
# [95]	validation_0-auc:0.86041
# [96]	validation_0-auc:0.86074
# [97]	validation_0-auc:0.86098
# [98]	validation_0-auc:0.86098
# [99]	validation_0-auc:0.86114
# [100]	validation_0-auc:0.86114
# [101]	validation_0-auc:0.86114
# [102]	validation_0-auc:0.86114
# [103]	validation_0-auc:0.86126
# [104]	validation_0-auc:0.86126
# [105]	validation_0-auc:0.86126
# [106]	validation_0-auc:0.86141
# [107]	validation_0-auc:0.86163
# [108]	validation_0-auc:0.86163
# [109]	validation_0-auc:0.86163
# [110]	validation_0-auc:0.86161
# [111]	validation_0-auc:0.86161
# [112]	validation_0-auc:0.86213
# [113]	validation_0-auc:0.86213
# [114]	validation_0-auc:0.86213
# [115]	validation_0-auc:0.86213
# [116]	validation_0-auc:0.86213
# [117]	validation_0-auc:0.86213
# [118]	validation_0-auc:0.86213
# [119]	validation_0-auc:0.86213
# [120]	validation_0-auc:0.86211
# [121]	validation_0-auc:0.86246
# [122]	validation_0-auc:0.86246
# [123]	validation_0-auc:0.86246
# [124]	validation_0-auc:0.86246
# [125]	validation_0-auc:0.86262
# [126]	validation_0-auc:0.86262
# [127]	validation_0-auc:0.86262
# [128]	validation_0-auc:0.86262
# [129]	validation_0-auc:0.86262
# [130]	validation_0-auc:0.86262
# [131]	validation_0-auc:0.86262
# [132]	validation_0-auc:0.86262
# [133]	validation_0-auc:0.86262
# [134]	validation_0-auc:0.86262
# [135]	validation_0-auc:0.86262
# [136]	validation_0-auc:0.86262
# [137]	validation_0-auc:0.86262
# [138]	validation_0-auc:0.86248
# [139]	validation_0-auc:0.86248
# [140]	validation_0-auc:0.86248
# [141]	validation_0-auc:0.86248
# [142]	validation_0-auc:0.86248
# [143]	validation_0-auc:0.86248
# [144]	validation_0-auc:0.86248
# [145]	validation_0-auc:0.86248
# [146]	validation_0-auc:0.86248
# [147]	validation_0-auc:0.86248
# [148]	validation_0-auc:0.86248
# [149]	validation_0-auc:0.86248
# [150]	validation_0-auc:0.86248
# [151]	validation_0-auc:0.86248
# [152]	validation_0-auc:0.86248
# [153]	validation_0-auc:0.86248
# [154]	validation_0-auc:0.86248
# [155]	validation_0-auc:0.86248
# [156]	validation_0-auc:0.86248
# [157]	validation_0-auc:0.86248
# [158]	validation_0-auc:0.86248
# [159]	validation_0-auc:0.86248
# [160]	validation_0-auc:0.86248
# [161]	validation_0-auc:0.86248
# [162]	validation_0-auc:0.86248
# [163]	validation_0-auc:0.86248
# [164]	validation_0-auc:0.86248
# [165]	validation_0-auc:0.86248
# [166]	validation_0-auc:0.86248
# [167]	validation_0-auc:0.86248
# [168]	validation_0-auc:0.86248
# [169]	validation_0-auc:0.86248
# [0]	validation_0-auc:0.95038
# [1]	validation_0-auc:0.95928
# [2]	validation_0-auc:0.95678
# [3]	validation_0-auc:0.96259
# [4]	validation_0-auc:0.96478
# [5]	validation_0-auc:0.96342
# [6]	validation_0-auc:0.96434
# [7]	validation_0-auc:0.96304
# [8]	validation_0-auc:0.96236
# [9]	validation_0-auc:0.96119
# [10]	validation_0-auc:0.96112
# [11]	validation_0-auc:0.96018
# [12]	validation_0-auc:0.96414
# [13]	validation_0-auc:0.96317
# [14]	validation_0-auc:0.96306
# [15]	validation_0-auc:0.96284
# [16]	validation_0-auc:0.96173
# [17]	validation_0-auc:0.96642
# [18]	validation_0-auc:0.96580
# [19]	validation_0-auc:0.96959
# [20]	validation_0-auc:0.97064
# [21]	validation_0-auc:0.96967
# [22]	validation_0-auc:0.96846
# [23]	validation_0-auc:0.96991
# [24]	validation_0-auc:0.97115
# [25]	validation_0-auc:0.97060
# [26]	validation_0-auc:0.97117
# [27]	validation_0-auc:0.97097
# [28]	validation_0-auc:0.97038
# [29]	validation_0-auc:0.96864
# [30]	validation_0-auc:0.96670
# [31]	validation_0-auc:0.96461
# [32]	validation_0-auc:0.96461
# [33]	validation_0-auc:0.96583
# [34]	validation_0-auc:0.96669
# [35]	validation_0-auc:0.96508
# [36]	validation_0-auc:0.96429
# [37]	validation_0-auc:0.96245
# [38]	validation_0-auc:0.96360
# [39]	validation_0-auc:0.96274
# [40]	validation_0-auc:0.96347
# [41]	validation_0-auc:0.96186
# [42]	validation_0-auc:0.96108
# [43]	validation_0-auc:0.96099
# [44]	validation_0-auc:0.96065
# [45]	validation_0-auc:0.96215
# [46]	validation_0-auc:0.96159
# [47]	validation_0-auc:0.96243
# [48]	validation_0-auc:0.96211
# [49]	validation_0-auc:0.96212
# [50]	validation_0-auc:0.96404
# [51]	validation_0-auc:0.96344
# [52]	validation_0-auc:0.96324
# [53]	validation_0-auc:0.96426
# [54]	validation_0-auc:0.97154
# [55]	validation_0-auc:0.97490
# [56]	validation_0-auc:0.97710
# [57]	validation_0-auc:0.97668
# [58]	validation_0-auc:0.97792
# [59]	validation_0-auc:0.97694
# [60]	validation_0-auc:0.98096
# [61]	validation_0-auc:0.98235
# [62]	validation_0-auc:0.98211
# [63]	validation_0-auc:0.98225
# [64]	validation_0-auc:0.98204
# [65]	validation_0-auc:0.98205
# [66]	validation_0-auc:0.98199
# [67]	validation_0-auc:0.98150
# [68]	validation_0-auc:0.98144
# [69]	validation_0-auc:0.98086
# [70]	validation_0-auc:0.98032
# [71]	validation_0-auc:0.98022
# [72]	validation_0-auc:0.98094
# [73]	validation_0-auc:0.97901
# [74]	validation_0-auc:0.97933
# [75]	validation_0-auc:0.97997
# [76]	validation_0-auc:0.98083
# [77]	validation_0-auc:0.98004
# [78]	validation_0-auc:0.98066
# [79]	validation_0-auc:0.98008
# [80]	validation_0-auc:0.98000
# [81]	validation_0-auc:0.97998
# [82]	validation_0-auc:0.98029
# [83]	validation_0-auc:0.98031
# [84]	validation_0-auc:0.98002
# [85]	validation_0-auc:0.98080
# [86]	validation_0-auc:0.98119
# [87]	validation_0-auc:0.98108
# [88]	validation_0-auc:0.98099
# [89]	validation_0-auc:0.98016
# [90]	validation_0-auc:0.98038
# [91]	validation_0-auc:0.97991
# [92]	validation_0-auc:0.97934
# [93]	validation_0-auc:0.97980
# [94]	validation_0-auc:0.98006
# [95]	validation_0-auc:0.97937
# [96]	validation_0-auc:0.97941
# [97]	validation_0-auc:0.97855
# [98]	validation_0-auc:0.97856
# [99]	validation_0-auc:0.97885
# [100]	validation_0-auc:0.97887
# [101]	validation_0-auc:0.97925
# [102]	validation_0-auc:0.98025
# [103]	validation_0-auc:0.98038
# [104]	validation_0-auc:0.97991
# [105]	validation_0-auc:0.97974
# [106]	validation_0-auc:0.97954
# [107]	validation_0-auc:0.98025
# [108]	validation_0-auc:0.97925
# [109]	validation_0-auc:0.97917
# [110]	validation_0-auc:0.97870
# [111]	validation_0-auc:0.97847
# [112]	validation_0-auc:0.97822
# [113]	validation_0-auc:0.97818
# [114]	validation_0-auc:0.97905
# [115]	validation_0-auc:0.97947
# [116]	validation_0-auc:0.97990
# [117]	validation_0-auc:0.97968
# [118]	validation_0-auc:0.97938
# [119]	validation_0-auc:0.97916
# [120]	validation_0-auc:0.97889
# [121]	validation_0-auc:0.97903
# [122]	validation_0-auc:0.97875
# [123]	validation_0-auc:0.97806
# [124]	validation_0-auc:0.97832
# [125]	validation_0-auc:0.97804
# [126]	validation_0-auc:0.97654
# [127]	validation_0-auc:0.97632
# [128]	validation_0-auc:0.97639
# [129]	validation_0-auc:0.97625
# [130]	validation_0-auc:0.97604
# [131]	validation_0-auc:0.97583
# [132]	validation_0-auc:0.97561
# [133]	validation_0-auc:0.97549
# [134]	validation_0-auc:0.97563
# [135]	validation_0-auc:0.97547
# [136]	validation_0-auc:0.97612
# [137]	validation_0-auc:0.97615
# [138]	validation_0-auc:0.97622
# [139]	validation_0-auc:0.97646
# [140]	validation_0-auc:0.97651
# [141]	validation_0-auc:0.97671
# [142]	validation_0-auc:0.97661
# [143]	validation_0-auc:0.97665
# [144]	validation_0-auc:0.97688
# [145]	validation_0-auc:0.97717
# [146]	validation_0-auc:0.97700
# [147]	validation_0-auc:0.97670
# [148]	validation_0-auc:0.97685
# [149]	validation_0-auc:0.97627
# [150]	validation_0-auc:0.97643
# [151]	validation_0-auc:0.97653
# [152]	validation_0-auc:0.97666
# [153]	validation_0-auc:0.97666
# [154]	validation_0-auc:0.97704
# [155]	validation_0-auc:0.97723
# [156]	validation_0-auc:0.97735
# [157]	validation_0-auc:0.97717
# [158]	validation_0-auc:0.97708
# [159]	validation_0-auc:0.97728
# [160]	validation_0-auc:0.97739
# [161]	validation_0-auc:0.97765
# [162]	validation_0-auc:0.97774
# [163]	validation_0-auc:0.97761
# [164]	validation_0-auc:0.97704
# [165]	validation_0-auc:0.97726
# [166]	validation_0-auc:0.97700
# [167]	validation_0-auc:0.97692
# [168]	validation_0-auc:0.97648
# [169]	validation_0-auc:0.97643
# [170]	validation_0-auc:0.97652
# [171]	validation_0-auc:0.97627
# [172]	validation_0-auc:0.97639
# [173]	validation_0-auc:0.97668
# [174]	validation_0-auc:0.97667
# [175]	validation_0-auc:0.97676
# [176]	validation_0-auc:0.97666
# [177]	validation_0-auc:0.97640
# [178]	validation_0-auc:0.97637
# [179]	validation_0-auc:0.97618
# [180]	validation_0-auc:0.97611
# [181]	validation_0-auc:0.97625
# [182]	validation_0-auc:0.97658
# [183]	validation_0-auc:0.97654
# [184]	validation_0-auc:0.97671
# [185]	validation_0-auc:0.97685
# [186]	validation_0-auc:0.97666
# [187]	validation_0-auc:0.97670
# [188]	validation_0-auc:0.97677
# [189]	validation_0-auc:0.97689
# [190]	validation_0-auc:0.97702
# [191]	validation_0-auc:0.97704
# [192]	validation_0-auc:0.97645
# [193]	validation_0-auc:0.97636
# [194]	validation_0-auc:0.97636
# [195]	validation_0-auc:0.97606
# [196]	validation_0-auc:0.97610
# [197]	validation_0-auc:0.97608
# [198]	validation_0-auc:0.97610
# [199]	validation_0-auc:0.97631
# [200]	validation_0-auc:0.97641
# [201]	validation_0-auc:0.97650
# [202]	validation_0-auc:0.97641
# [203]	validation_0-auc:0.97632
# [204]	validation_0-auc:0.97613
# [205]	validation_0-auc:0.97609
# [206]	validation_0-auc:0.97585
# [207]	validation_0-auc:0.97590
# [208]	validation_0-auc:0.97587
# [209]	validation_0-auc:0.97593
# [210]	validation_0-auc:0.97593
# [211]	validation_0-auc:0.97616
# [212]	validation_0-auc:0.97629
# [213]	validation_0-auc:0.97634
# [214]	validation_0-auc:0.97632
# [215]	validation_0-auc:0.97632
# [216]	validation_0-auc:0.97632
# [217]	validation_0-auc:0.97644
# [218]	validation_0-auc:0.97646
# [219]	validation_0-auc:0.97666
# [220]	validation_0-auc:0.97602
# [221]	validation_0-auc:0.97553
# [222]	validation_0-auc:0.97580
# [223]	validation_0-auc:0.97594
# [224]	validation_0-auc:0.97544
# [225]	validation_0-auc:0.97549
# [226]	validation_0-auc:0.97507
# [227]	validation_0-auc:0.97508
# [228]	validation_0-auc:0.97508
# [229]	validation_0-auc:0.97512
# [230]	validation_0-auc:0.97515
# [231]	validation_0-auc:0.97529
# [232]	validation_0-auc:0.97532
# [233]	validation_0-auc:0.97534
# [234]	validation_0-auc:0.97539
# [235]	validation_0-auc:0.97526
# [236]	validation_0-auc:0.97540
# [237]	validation_0-auc:0.97550
# [238]	validation_0-auc:0.97556
# [239]	validation_0-auc:0.97604
# [240]	validation_0-auc:0.97625
# [241]	validation_0-auc:0.97635
# [242]	validation_0-auc:0.97638
# [243]	validation_0-auc:0.97617
# [244]	validation_0-auc:0.97617
# [245]	validation_0-auc:0.97620
# [246]	validation_0-auc:0.97618
# [247]	validation_0-auc:0.97621
# [248]	validation_0-auc:0.97623
# [249]	validation_0-auc:0.97633
# [250]	validation_0-auc:0.97617
# [251]	validation_0-auc:0.97618
# [252]	validation_0-auc:0.97618
# [253]	validation_0-auc:0.97622
# [254]	validation_0-auc:0.97622
# [255]	validation_0-auc:0.97623
# [256]	validation_0-auc:0.97625
# [257]	validation_0-auc:0.97624
# [258]	validation_0-auc:0.97624
# [259]	validation_0-auc:0.97628
# [260]	validation_0-auc:0.97614
# [261]	validation_0-auc:0.97617
# [262]	validation_0-auc:0.97621
# [263]	validation_0-auc:0.97635
# [264]	validation_0-auc:0.97630
# [265]	validation_0-auc:0.97629
# [266]	validation_0-auc:0.97629
# [267]	validation_0-auc:0.97587
# [268]	validation_0-auc:0.97588
# [269]	validation_0-auc:0.97593
# [270]	validation_0-auc:0.97593
# [271]	validation_0-auc:0.97581
# [272]	validation_0-auc:0.97590
# [273]	validation_0-auc:0.97591
# [274]	validation_0-auc:0.97591
# [275]	validation_0-auc:0.97617
# [276]	validation_0-auc:0.97622
# [277]	validation_0-auc:0.97635
# [278]	validation_0-auc:0.97650
# [279]	validation_0-auc:0.97650
# [280]	validation_0-auc:0.97639
# [281]	validation_0-auc:0.97639
# [282]	validation_0-auc:0.97636
# [283]	validation_0-auc:0.97652
# [284]	validation_0-auc:0.97667
# [285]	validation_0-auc:0.97676
# [286]	validation_0-auc:0.97693
# [287]	validation_0-auc:0.97701
# [288]	validation_0-auc:0.97701
# [289]	validation_0-auc:0.97701
# [290]	validation_0-auc:0.97700
# [291]	validation_0-auc:0.97701
# [292]	validation_0-auc:0.97706
# [293]	validation_0-auc:0.97707
# [294]	validation_0-auc:0.97706
# [295]	validation_0-auc:0.97712
# [296]	validation_0-auc:0.97717
# [297]	validation_0-auc:0.97737
# [298]	validation_0-auc:0.97744
# [299]	validation_0-auc:0.97745
# [300]	validation_0-auc:0.97744
# [301]	validation_0-auc:0.97749
# [302]	validation_0-auc:0.97750
# [303]	validation_0-auc:0.97750
# [304]	validation_0-auc:0.97755
# [305]	validation_0-auc:0.97699
# [306]	validation_0-auc:0.97704
# [307]	validation_0-auc:0.97704
# [308]	validation_0-auc:0.97708
# [309]	validation_0-auc:0.97715
# [310]	validation_0-auc:0.97717
# [311]	validation_0-auc:0.97724
# [312]	validation_0-auc:0.97731
# [313]	validation_0-auc:0.97730
# [314]	validation_0-auc:0.97730
# [315]	validation_0-auc:0.97730
# [316]	validation_0-auc:0.97730
# [317]	validation_0-auc:0.97735
# [318]	validation_0-auc:0.97748
# [319]	validation_0-auc:0.97749
# [320]	validation_0-auc:0.97750
# [321]	validation_0-auc:0.97754
# [322]	validation_0-auc:0.97757
# [323]	validation_0-auc:0.97762
# [324]	validation_0-auc:0.97763
# [325]	validation_0-auc:0.97764
# [326]	validation_0-auc:0.97764
# [327]	validation_0-auc:0.97767
# [328]	validation_0-auc:0.97773
# [329]	validation_0-auc:0.97773
# [330]	validation_0-auc:0.97775
# [331]	validation_0-auc:0.97775
# [332]	validation_0-auc:0.97775
# [333]	validation_0-auc:0.97775
# [334]	validation_0-auc:0.97774
# [335]	validation_0-auc:0.97775
# [336]	validation_0-auc:0.97778
# [337]	validation_0-auc:0.97778
# [338]	validation_0-auc:0.97781
# [339]	validation_0-auc:0.97781
# [340]	validation_0-auc:0.97786
# [341]	validation_0-auc:0.97786
# [342]	validation_0-auc:0.97782
# [343]	validation_0-auc:0.97782
# [344]	validation_0-auc:0.97782
# [345]	validation_0-auc:0.97786
# [346]	validation_0-auc:0.97786
# [347]	validation_0-auc:0.97790
# [348]	validation_0-auc:0.97788
# [349]	validation_0-auc:0.97788
# [350]	validation_0-auc:0.97788
# [351]	validation_0-auc:0.97788
# [352]	validation_0-auc:0.97788
# [353]	validation_0-auc:0.97795
# [354]	validation_0-auc:0.97796
# [355]	validation_0-auc:0.97796
# [356]	validation_0-auc:0.97796
# [357]	validation_0-auc:0.97798
# [358]	validation_0-auc:0.97806
# [359]	validation_0-auc:0.97815
# [360]	validation_0-auc:0.97780
# [361]	validation_0-auc:0.97776
# [362]	validation_0-auc:0.97776
# [363]	validation_0-auc:0.97781
# [364]	validation_0-auc:0.97781
# [365]	validation_0-auc:0.97781
# [366]	validation_0-auc:0.97781
# [367]	validation_0-auc:0.97781
# [368]	validation_0-auc:0.97781
# [369]	validation_0-auc:0.97784
# [370]	validation_0-auc:0.97784
# [371]	validation_0-auc:0.97784
# [372]	validation_0-auc:0.97784
# [373]	validation_0-auc:0.97785
# [374]	validation_0-auc:0.97785
# [375]	validation_0-auc:0.97785
# [376]	validation_0-auc:0.97791
# [377]	validation_0-auc:0.97791
# [378]	validation_0-auc:0.97791
# [379]	validation_0-auc:0.97792
# [380]	validation_0-auc:0.97792
# [381]	validation_0-auc:0.97792
# [382]	validation_0-auc:0.97792
# [383]	validation_0-auc:0.97793
# [384]	validation_0-auc:0.97793
# [385]	validation_0-auc:0.97793
# [386]	validation_0-auc:0.97793
# [387]	validation_0-auc:0.97794
# [388]	validation_0-auc:0.97794
# [389]	validation_0-auc:0.97794
# [390]	validation_0-auc:0.97794
# [391]	validation_0-auc:0.97794
# [392]	validation_0-auc:0.97797
# [393]	validation_0-auc:0.97797
# [394]	validation_0-auc:0.97831
# [395]	validation_0-auc:0.97831
# [396]	validation_0-auc:0.97833
# [397]	validation_0-auc:0.97837
# [398]	validation_0-auc:0.97837
# [399]	validation_0-auc:0.97840
# [400]	validation_0-auc:0.97841
# [401]	validation_0-auc:0.97841
# [402]	validation_0-auc:0.97841
# [403]	validation_0-auc:0.97832
# [404]	validation_0-auc:0.97832
# [405]	validation_0-auc:0.97835
# [406]	validation_0-auc:0.97835
# [407]	validation_0-auc:0.97840
# [408]	validation_0-auc:0.97840
# [409]	validation_0-auc:0.97842
# [410]	validation_0-auc:0.97842
# [411]	validation_0-auc:0.97836
# [412]	validation_0-auc:0.97836
# [413]	validation_0-auc:0.97836
# [414]	validation_0-auc:0.97840
# [415]	validation_0-auc:0.97843
# [416]	validation_0-auc:0.97840
# [417]	validation_0-auc:0.97858
# [418]	validation_0-auc:0.97819
# [419]	validation_0-auc:0.97815
# [420]	validation_0-auc:0.97815
# [421]	validation_0-auc:0.97815
# [422]	validation_0-auc:0.97815
# [423]	validation_0-auc:0.97815
# [424]	validation_0-auc:0.97815
# [425]	validation_0-auc:0.97819
# [426]	validation_0-auc:0.97819
# [427]	validation_0-auc:0.97819
# [428]	validation_0-auc:0.97819
# [429]	validation_0-auc:0.97824
# [430]	validation_0-auc:0.97824
# [431]	validation_0-auc:0.97824
# [432]	validation_0-auc:0.97824
# [433]	validation_0-auc:0.97824
# [434]	validation_0-auc:0.97824
# [435]	validation_0-auc:0.97825
# [436]	validation_0-auc:0.97826
# [437]	validation_0-auc:0.97826
# [438]	validation_0-auc:0.97824
# [439]	validation_0-auc:0.97824
# [440]	validation_0-auc:0.97840
# [441]	validation_0-auc:0.97840
# [442]	validation_0-auc:0.97843
# [443]	validation_0-auc:0.97843
# [444]	validation_0-auc:0.97843
# [445]	validation_0-auc:0.97843
# [446]	validation_0-auc:0.97841
# [447]	validation_0-auc:0.97841
# [448]	validation_0-auc:0.97841
# [449]	validation_0-auc:0.97841
# [450]	validation_0-auc:0.97841
# [451]	validation_0-auc:0.97841
# [452]	validation_0-auc:0.97843
# [453]	validation_0-auc:0.97843
# [454]	validation_0-auc:0.97843
# [455]	validation_0-auc:0.97848
# [456]	validation_0-auc:0.97849
# [457]	validation_0-auc:0.97849
# [458]	validation_0-auc:0.97849
# [459]	validation_0-auc:0.97849
# [460]	validation_0-auc:0.97851
# [461]	validation_0-auc:0.97851
# [462]	validation_0-auc:0.97856
# [463]	validation_0-auc:0.97856
# [464]	validation_0-auc:0.97856
# [465]	validation_0-auc:0.97856
# [466]	validation_0-auc:0.97856
# [467]	validation_0-auc:0.97856
# [468]	validation_0-auc:0.97854
# [469]	validation_0-auc:0.97854
# [470]	validation_0-auc:0.97854
# [471]	validation_0-auc:0.97854
# [472]	validation_0-auc:0.97854
# [473]	validation_0-auc:0.97854
# [474]	validation_0-auc:0.97857
# [475]	validation_0-auc:0.97857
# [476]	validation_0-auc:0.97857
# [477]	validation_0-auc:0.97857
# [478]	validation_0-auc:0.97857
# [479]	validation_0-auc:0.97859
# [480]	validation_0-auc:0.97859
# [481]	validation_0-auc:0.97859
# [482]	validation_0-auc:0.97863
# [483]	validation_0-auc:0.97863
# [484]	validation_0-auc:0.97862
# [485]	validation_0-auc:0.97862
# [486]	validation_0-auc:0.97862
# [487]	validation_0-auc:0.97862
# [488]	validation_0-auc:0.97862
# [489]	validation_0-auc:0.97862
# [490]	validation_0-auc:0.97865
# [491]	validation_0-auc:0.97865
# [492]	validation_0-auc:0.97865
# [493]	validation_0-auc:0.97869
# [494]	validation_0-auc:0.97869
# [495]	validation_0-auc:0.97868
# [496]	validation_0-auc:0.97870
# [497]	validation_0-auc:0.97869
# [498]	validation_0-auc:0.97869
# [499]	validation_0-auc:0.97869
# [500]	validation_0-auc:0.97868
# [501]	validation_0-auc:0.97868
# [502]	validation_0-auc:0.97868
# [503]	validation_0-auc:0.97868
# [504]	validation_0-auc:0.97868
# [505]	validation_0-auc:0.97868
# [506]	validation_0-auc:0.97868
# [507]	validation_0-auc:0.97868
# [508]	validation_0-auc:0.97868
# [509]	validation_0-auc:0.97866
# [510]	validation_0-auc:0.97866
# [511]	validation_0-auc:0.97866
# [512]	validation_0-auc:0.97866
# [513]	validation_0-auc:0.97866
# [514]	validation_0-auc:0.97866
# [515]	validation_0-auc:0.97866
# [516]	validation_0-auc:0.97866
# [517]	validation_0-auc:0.97866
# [518]	validation_0-auc:0.97866
# [519]	validation_0-auc:0.97866
# [520]	validation_0-auc:0.97866
# [521]	validation_0-auc:0.97866
# [522]	validation_0-auc:0.97866
# [523]	validation_0-auc:0.97866
# [524]	validation_0-auc:0.97866
# [525]	validation_0-auc:0.97866
# [526]	validation_0-auc:0.97866
# [527]	validation_0-auc:0.97865
# [528]	validation_0-auc:0.97867
# [529]	validation_0-auc:0.97867
# [530]	validation_0-auc:0.97864
# [531]	validation_0-auc:0.97864
# [532]	validation_0-auc:0.97865
# [533]	validation_0-auc:0.97862
# [534]	validation_0-auc:0.97862
# [535]	validation_0-auc:0.97862
# [536]	validation_0-auc:0.97862
# [537]	validation_0-auc:0.97862
# [538]	validation_0-auc:0.97862
# [539]	validation_0-auc:0.97862
# [540]	validation_0-auc:0.97862
# [541]	validation_0-auc:0.97862
# [542]	validation_0-auc:0.97862
# [543]	validation_0-auc:0.97862
# [544]	validation_0-auc:0.97862
# [545]	validation_0-auc:0.97862
# [546]	validation_0-auc:0.97862
# [547]	validation_0-auc:0.97862
# [548]	validation_0-auc:0.97862
# [549]	validation_0-auc:0.97862
# [550]	validation_0-auc:0.97862
# [551]	validation_0-auc:0.97862
# [552]	validation_0-auc:0.97862
# [553]	validation_0-auc:0.97853
# [554]	validation_0-auc:0.97853
# [555]	validation_0-auc:0.97853
# [556]	validation_0-auc:0.97853
# [557]	validation_0-auc:0.97853
# [558]	validation_0-auc:0.97853
# [559]	validation_0-auc:0.97853
# [560]	validation_0-auc:0.97853
# [561]	validation_0-auc:0.97853
# [562]	validation_0-auc:0.97848
# [563]	validation_0-auc:0.97848
# [564]	validation_0-auc:0.97845
# [565]	validation_0-auc:0.97845
# [566]	validation_0-auc:0.97845
# [567]	validation_0-auc:0.97849
# [568]	validation_0-auc:0.97849
# [569]	validation_0-auc:0.97849
# [570]	validation_0-auc:0.97849
# [571]	validation_0-auc:0.97849
# [572]	validation_0-auc:0.97849
# [573]	validation_0-auc:0.97849
# [574]	validation_0-auc:0.97849
# [575]	validation_0-auc:0.97849
# [576]	validation_0-auc:0.97849
# [577]	validation_0-auc:0.97850
# [578]	validation_0-auc:0.97850
# [579]	validation_0-auc:0.97850
# [580]	validation_0-auc:0.97850
# [581]	validation_0-auc:0.97850
# [582]	validation_0-auc:0.97850
# [583]	validation_0-auc:0.97850
# [584]	validation_0-auc:0.97850
# [585]	validation_0-auc:0.97851
# [586]	validation_0-auc:0.97851
# [587]	validation_0-auc:0.97851
# [588]	validation_0-auc:0.97851
# [589]	validation_0-auc:0.97852
# [590]	validation_0-auc:0.97852
# [591]	validation_0-auc:0.97852
# [592]	validation_0-auc:0.97850
# [593]	validation_0-auc:0.97850
# [594]	validation_0-auc:0.97843
# [595]	validation_0-auc:0.97845
# [596]	validation_0-auc:0.97845
# [597]	validation_0-auc:0.97845
# [598]	validation_0-auc:0.97852
# [599]	validation_0-auc:0.97852
# [600]	validation_0-auc:0.97852
# [601]	validation_0-auc:0.97852
# [602]	validation_0-auc:0.97852
# [603]	validation_0-auc:0.97852
# [604]	validation_0-auc:0.97852
# [605]	validation_0-auc:0.97852
# [606]	validation_0-auc:0.97852
# [607]	validation_0-auc:0.97852
# [608]	validation_0-auc:0.97852
# [609]	validation_0-auc:0.97853
# [610]	validation_0-auc:0.97853
# [611]	validation_0-auc:0.97853
# [612]	validation_0-auc:0.97853
# [613]	validation_0-auc:0.97853
# [614]	validation_0-auc:0.97853
# [615]	validation_0-auc:0.97853
# [616]	validation_0-auc:0.97853
# [617]	validation_0-auc:0.97853
# [618]	validation_0-auc:0.97853
# [619]	validation_0-auc:0.97852
# [620]	validation_0-auc:0.97852
# [621]	validation_0-auc:0.97852
# [622]	validation_0-auc:0.97852
# [623]	validation_0-auc:0.97852
# [624]	validation_0-auc:0.97852
# [625]	validation_0-auc:0.97852
# [626]	validation_0-auc:0.97852
# [627]	validation_0-auc:0.97867
# [628]	validation_0-auc:0.97865
# [629]	validation_0-auc:0.97865
# [630]	validation_0-auc:0.97865
# [631]	validation_0-auc:0.97865
# [632]	validation_0-auc:0.97865
# [633]	validation_0-auc:0.97865
# [634]	validation_0-auc:0.97865
# [635]	validation_0-auc:0.97865
# [636]	validation_0-auc:0.97865
# [637]	validation_0-auc:0.97865
# [638]	validation_0-auc:0.97865
# [639]	validation_0-auc:0.97865
# [640]	validation_0-auc:0.97865
# [641]	validation_0-auc:0.97865
# [642]	validation_0-auc:0.97865
# [643]	validation_0-auc:0.97861
# [644]	validation_0-auc:0.97863
# [645]	validation_0-auc:0.97853
# [646]	validation_0-auc:0.97853
# [647]	validation_0-auc:0.97853
# [648]	validation_0-auc:0.97854
# [649]	validation_0-auc:0.97854
# [650]	validation_0-auc:0.97853
# [651]	validation_0-auc:0.97853
# [652]	validation_0-auc:0.97853
# [653]	validation_0-auc:0.97833
# [654]	validation_0-auc:0.97833
# [655]	validation_0-auc:0.97833
# [656]	validation_0-auc:0.97835
# [657]	validation_0-auc:0.97835
# [658]	validation_0-auc:0.97835
# [659]	validation_0-auc:0.97835
# [660]	validation_0-auc:0.97835
# [661]	validation_0-auc:0.97835
# [662]	validation_0-auc:0.97837
# [663]	validation_0-auc:0.97846
# [664]	validation_0-auc:0.97797
# [665]	validation_0-auc:0.97797
# [666]	validation_0-auc:0.97797
# [667]	validation_0-auc:0.97797
# [668]	validation_0-auc:0.97797
# [669]	validation_0-auc:0.97797
# [670]	validation_0-auc:0.97797
# [671]	validation_0-auc:0.97797
# [672]	validation_0-auc:0.97797
# [673]	validation_0-auc:0.97797
# [674]	validation_0-auc:0.97797
# [675]	validation_0-auc:0.97791
# [676]	validation_0-auc:0.97798
# [677]	validation_0-auc:0.97798
# [678]	validation_0-auc:0.97798
# [679]	validation_0-auc:0.97808
# [680]	validation_0-auc:0.97808
# [681]	validation_0-auc:0.97808
# [682]	validation_0-auc:0.97808
# [683]	validation_0-auc:0.97808
# [684]	validation_0-auc:0.97808
# [685]	validation_0-auc:0.97808
# [686]	validation_0-auc:0.97808
# [687]	validation_0-auc:0.97808
# [688]	validation_0-auc:0.97808
# [689]	validation_0-auc:0.97808
# [690]	validation_0-auc:0.97808
# [691]	validation_0-auc:0.97808
# [692]	validation_0-auc:0.97808
# [693]	validation_0-auc:0.97808
# [694]	validation_0-auc:0.97808
# [695]	validation_0-auc:0.97808
# [696]	validation_0-auc:0.97808
# [697]	validation_0-auc:0.97808
# [698]	validation_0-auc:0.97808
# [699]	validation_0-auc:0.97808
# [700]	validation_0-auc:0.97808
# [701]	validation_0-auc:0.97808
# [702]	validation_0-auc:0.97808
# [703]	validation_0-auc:0.97808
# [704]	validation_0-auc:0.97808
# [705]	validation_0-auc:0.97808
# [706]	validation_0-auc:0.97808
# [707]	validation_0-auc:0.97808
# [708]	validation_0-auc:0.97808
# [709]	validation_0-auc:0.97809
# [710]	validation_0-auc:0.97809
# [711]	validation_0-auc:0.97809
# [712]	validation_0-auc:0.97809
# [713]	validation_0-auc:0.97809
# [714]	validation_0-auc:0.97809
# [715]	validation_0-auc:0.97815
# [716]	validation_0-auc:0.97815
# [717]	validation_0-auc:0.97815
# [718]	validation_0-auc:0.97815
# [719]	validation_0-auc:0.97813
# [720]	validation_0-auc:0.97813
# [721]	validation_0-auc:0.97813
# [722]	validation_0-auc:0.97813
# [723]	validation_0-auc:0.97813
# [724]	validation_0-auc:0.97808
# [725]	validation_0-auc:0.97808
# [726]	validation_0-auc:0.97808
# [727]	validation_0-auc:0.97808
# [728]	validation_0-auc:0.97808
# [729]	validation_0-auc:0.97808
# [730]	validation_0-auc:0.97808
# [731]	validation_0-auc:0.97806
# [732]	validation_0-auc:0.97806
# [733]	validation_0-auc:0.97806
# [734]	validation_0-auc:0.97806
# [735]	validation_0-auc:0.97806
# [736]	validation_0-auc:0.97806
# [737]	validation_0-auc:0.97806
# [738]	validation_0-auc:0.97806
# [739]	validation_0-auc:0.97806
# [740]	validation_0-auc:0.97806
# [741]	validation_0-auc:0.97806
# [742]	validation_0-auc:0.97808
# [743]	validation_0-auc:0.97808
# [744]	validation_0-auc:0.97808
# [745]	validation_0-auc:0.97808
# [746]	validation_0-auc:0.97808
# [747]	validation_0-auc:0.97808
# [748]	validation_0-auc:0.97808
# [749]	validation_0-auc:0.97808
# [750]	validation_0-auc:0.97808
# [751]	validation_0-auc:0.97808
# [752]	validation_0-auc:0.97808
# [753]	validation_0-auc:0.97808
# [754]	validation_0-auc:0.97808
# [755]	validation_0-auc:0.97808
# [756]	validation_0-auc:0.97808
# [757]	validation_0-auc:0.97808
# [758]	validation_0-auc:0.97813
# [759]	validation_0-auc:0.97813
# [760]	validation_0-auc:0.97813
# [761]	validation_0-auc:0.97813
# [762]	validation_0-auc:0.97813
# [763]	validation_0-auc:0.97813
# [764]	validation_0-auc:0.97813
# [765]	validation_0-auc:0.97813
# [766]	validation_0-auc:0.97813
# [767]	validation_0-auc:0.97813
# [768]	validation_0-auc:0.97813
# [769]	validation_0-auc:0.97813
# [770]	validation_0-auc:0.97813
# [771]	validation_0-auc:0.97815
# [772]	validation_0-auc:0.97815
# [773]	validation_0-auc:0.97815
# [774]	validation_0-auc:0.97815
# [775]	validation_0-auc:0.97815
# [776]	validation_0-auc:0.97815
# [777]	validation_0-auc:0.97815
# [778]	validation_0-auc:0.97815
# [779]	validation_0-auc:0.97815
# [780]	validation_0-auc:0.97815
# [781]	validation_0-auc:0.97811
# [782]	validation_0-auc:0.97811
# [783]	validation_0-auc:0.97811
# [784]	validation_0-auc:0.97822
# [785]	validation_0-auc:0.97822
# [786]	validation_0-auc:0.97822
# [787]	validation_0-auc:0.97822
# [788]	validation_0-auc:0.97822
# [789]	validation_0-auc:0.97822
# [790]	validation_0-auc:0.97822
# [791]	validation_0-auc:0.97822
# [792]	validation_0-auc:0.97822
# [793]	validation_0-auc:0.97822
# [794]	validation_0-auc:0.97822
# [795]	validation_0-auc:0.97822
# [796]	validation_0-auc:0.97822
# [797]	validation_0-auc:0.97822
# [798]	validation_0-auc:0.97825
# [799]	validation_0-auc:0.97825
# [800]	validation_0-auc:0.97825
# [801]	validation_0-auc:0.97825
# [802]	validation_0-auc:0.97825
# [803]	validation_0-auc:0.97825
# [804]	validation_0-auc:0.97825
# [805]	validation_0-auc:0.97825
# [806]	validation_0-auc:0.97825
# [807]	validation_0-auc:0.97825
# [808]	validation_0-auc:0.97826
# [809]	validation_0-auc:0.97826
# [810]	validation_0-auc:0.97826
# [811]	validation_0-auc:0.97826
# [812]	validation_0-auc:0.97826
# [813]	validation_0-auc:0.97826
# [814]	validation_0-auc:0.97826
# [815]	validation_0-auc:0.97826
# [816]	validation_0-auc:0.97826
# [817]	validation_0-auc:0.97826
# [818]	validation_0-auc:0.97826
# [819]	validation_0-auc:0.97826
# [820]	validation_0-auc:0.97826
# [821]	validation_0-auc:0.97826
# [822]	validation_0-auc:0.97826
# [823]	validation_0-auc:0.97826
# [824]	validation_0-auc:0.97823
# [825]	validation_0-auc:0.97823
# [826]	validation_0-auc:0.97823
# [827]	validation_0-auc:0.97823
# [828]	validation_0-auc:0.97823
# [829]	validation_0-auc:0.97823
# [830]	validation_0-auc:0.97823
# [831]	validation_0-auc:0.97823
# [832]	validation_0-auc:0.97823
# [833]	validation_0-auc:0.97827
# [834]	validation_0-auc:0.97827
# [835]	validation_0-auc:0.97827
# [836]	validation_0-auc:0.97827
# [837]	validation_0-auc:0.97827
# [838]	validation_0-auc:0.97827
# [839]	validation_0-auc:0.97827
# [840]	validation_0-auc:0.97827
# [841]	validation_0-auc:0.97827
# [842]	validation_0-auc:0.97827
# [843]	validation_0-auc:0.97827
# [844]	validation_0-auc:0.97827
# [845]	validation_0-auc:0.97827
# [846]	validation_0-auc:0.97827
# [847]	validation_0-auc:0.97827
# [848]	validation_0-auc:0.97822
# [849]	validation_0-auc:0.97822
# [850]	validation_0-auc:0.97822
# [851]	validation_0-auc:0.97829
# [852]	validation_0-auc:0.97829
# [853]	validation_0-auc:0.97829
# [854]	validation_0-auc:0.97829
# [855]	validation_0-auc:0.97829
# [856]	validation_0-auc:0.97829
# [857]	validation_0-auc:0.97829
# [858]	validation_0-auc:0.97829
# [859]	validation_0-auc:0.97829
# [860]	validation_0-auc:0.97829
# [861]	validation_0-auc:0.97829
# [862]	validation_0-auc:0.97829
# [863]	validation_0-auc:0.97832
# [864]	validation_0-auc:0.97832
# [865]	validation_0-auc:0.97832
# [866]	validation_0-auc:0.97832
# [867]	validation_0-auc:0.97832
# [868]	validation_0-auc:0.97832
# [869]	validation_0-auc:0.97832
# [870]	validation_0-auc:0.97832
# [871]	validation_0-auc:0.97832
# [872]	validation_0-auc:0.97832
# [873]	validation_0-auc:0.97832
# [874]	validation_0-auc:0.97832
# [875]	validation_0-auc:0.97832
# [876]	validation_0-auc:0.97832
# [877]	validation_0-auc:0.97832
# [878]	validation_0-auc:0.97832
# [879]	validation_0-auc:0.97832
# [880]	validation_0-auc:0.97835
# [881]	validation_0-auc:0.97835
# [882]	validation_0-auc:0.97836
# [883]	validation_0-auc:0.97836
# [884]	validation_0-auc:0.97836
# [885]	validation_0-auc:0.97836
# [886]	validation_0-auc:0.97836
# [887]	validation_0-auc:0.97836
# [888]	validation_0-auc:0.97836
# [889]	validation_0-auc:0.97836
# [890]	validation_0-auc:0.97836
# [891]	validation_0-auc:0.97836
# [892]	validation_0-auc:0.97836
# [893]	validation_0-auc:0.97836
# [894]	validation_0-auc:0.97836
# [895]	validation_0-auc:0.97836
# [896]	validation_0-auc:0.97836
# [897]	validation_0-auc:0.97836
# [898]	validation_0-auc:0.97836
# [899]	validation_0-auc:0.97836
# [900]	validation_0-auc:0.97836
# [901]	validation_0-auc:0.97859
# [902]	validation_0-auc:0.97859
# [903]	validation_0-auc:0.97859
# [904]	validation_0-auc:0.97859
# [905]	validation_0-auc:0.97859
# [906]	validation_0-auc:0.97859
# [907]	validation_0-auc:0.97859
# [908]	validation_0-auc:0.97861
# [909]	validation_0-auc:0.97861
# [910]	validation_0-auc:0.97861
# [911]	validation_0-auc:0.97861
# [912]	validation_0-auc:0.97861
# [913]	validation_0-auc:0.97861
# [914]	validation_0-auc:0.97861
# [915]	validation_0-auc:0.97861
# [916]	validation_0-auc:0.97861
# [917]	validation_0-auc:0.97861
# [918]	validation_0-auc:0.97861
# [919]	validation_0-auc:0.97861
# [920]	validation_0-auc:0.97846
# [921]	validation_0-auc:0.97846
# [922]	validation_0-auc:0.97846
# [923]	validation_0-auc:0.97846
# [924]	validation_0-auc:0.97824
# [925]	validation_0-auc:0.97824
# [926]	validation_0-auc:0.97824
# [927]	validation_0-auc:0.97824
# [928]	validation_0-auc:0.97824
# [929]	validation_0-auc:0.97824
# [930]	validation_0-auc:0.97824
# [931]	validation_0-auc:0.97824
# [932]	validation_0-auc:0.97824
# [933]	validation_0-auc:0.97824
# [934]	validation_0-auc:0.97824
# [935]	validation_0-auc:0.97824
# [936]	validation_0-auc:0.97824
# [937]	validation_0-auc:0.97824
# [938]	validation_0-auc:0.97824
# [939]	validation_0-auc:0.97824
# [940]	validation_0-auc:0.97824
# [941]	validation_0-auc:0.97824
# [942]	validation_0-auc:0.97824
# [943]	validation_0-auc:0.97824
# [944]	validation_0-auc:0.97824
# [945]	validation_0-auc:0.97824
# [946]	validation_0-auc:0.97824
# [947]	validation_0-auc:0.97824
# [948]	validation_0-auc:0.97824
# [949]	validation_0-auc:0.97824
# [950]	validation_0-auc:0.97824
# [951]	validation_0-auc:0.97822
# [952]	validation_0-auc:0.97822
# [953]	validation_0-auc:0.97822
# [954]	validation_0-auc:0.97822
# [955]	validation_0-auc:0.97822
# [956]	validation_0-auc:0.97822
# [957]	validation_0-auc:0.97822
# [958]	validation_0-auc:0.97822
# [959]	validation_0-auc:0.97824
# [960]	validation_0-auc:0.97824
# [961]	validation_0-auc:0.97824
# [962]	validation_0-auc:0.97824
# [963]	validation_0-auc:0.97824
# [964]	validation_0-auc:0.97824
# [965]	validation_0-auc:0.97824
# [966]	validation_0-auc:0.97824
# [967]	validation_0-auc:0.97824
# [968]	validation_0-auc:0.97824
# [969]	validation_0-auc:0.97824
# [970]	validation_0-auc:0.97823
# [971]	validation_0-auc:0.97823
# [972]	validation_0-auc:0.97823
# [973]	validation_0-auc:0.97823
# [974]	validation_0-auc:0.97823
# [975]	validation_0-auc:0.97825
# [976]	validation_0-auc:0.97825
# [977]	validation_0-auc:0.97825
# [978]	validation_0-auc:0.97825
# [979]	validation_0-auc:0.97825
# [980]	validation_0-auc:0.97825
# [981]	validation_0-auc:0.97825
# [982]	validation_0-auc:0.97825
# [983]	validation_0-auc:0.97825
# [984]	validation_0-auc:0.97825
# [985]	validation_0-auc:0.97825
# [986]	validation_0-auc:0.97825
# [987]	validation_0-auc:0.97825
# [988]	validation_0-auc:0.97825
# [989]	validation_0-auc:0.97825
# [990]	validation_0-auc:0.97823
# [991]	validation_0-auc:0.97823
# [992]	validation_0-auc:0.97823
# [993]	validation_0-auc:0.97823
# [994]	validation_0-auc:0.97824
# [995]	validation_0-auc:0.97824
# [996]	validation_0-auc:0.97824
# [997]	validation_0-auc:0.97824
# [998]	validation_0-auc:0.97824
# [999]	validation_0-auc:0.97824
# [1000]	validation_0-auc:0.97824
# [1001]	validation_0-auc:0.97824
# [1002]	validation_0-auc:0.97824
# [1003]	validation_0-auc:0.97824
# [1004]	validation_0-auc:0.97824
# [1005]	validation_0-auc:0.97824
# [1006]	validation_0-auc:0.97824
# [1007]	validation_0-auc:0.97824
# [1008]	validation_0-auc:0.97824
# [1009]	validation_0-auc:0.97824
# [1010]	validation_0-auc:0.97825
# [1011]	validation_0-auc:0.97825
# [1012]	validation_0-auc:0.97825
# [1013]	validation_0-auc:0.97825
# [1014]	validation_0-auc:0.97826
# [1015]	validation_0-auc:0.97826
# [1016]	validation_0-auc:0.97826
# [1017]	validation_0-auc:0.97826
# [1018]	validation_0-auc:0.97826
# [1019]	validation_0-auc:0.97826
# [1020]	validation_0-auc:0.97825
# [1021]	validation_0-auc:0.97825
# [1022]	validation_0-auc:0.97825
# [1023]	validation_0-auc:0.97829
# [1024]	validation_0-auc:0.97829
# [1025]	validation_0-auc:0.97829
# [1026]	validation_0-auc:0.97829
# [1027]	validation_0-auc:0.97829
# [1028]	validation_0-auc:0.97829
# [1029]	validation_0-auc:0.97829
# [1030]	validation_0-auc:0.97829
# [1031]	validation_0-auc:0.97829
# [1032]	validation_0-auc:0.97829
# [1033]	validation_0-auc:0.97831
# [1034]	validation_0-auc:0.97831
# [1035]	validation_0-auc:0.97831
# [1036]	validation_0-auc:0.97831
# [1037]	validation_0-auc:0.97831
# [1038]	validation_0-auc:0.97831
# [1039]	validation_0-auc:0.97831
# [1040]	validation_0-auc:0.97831
# [1041]	validation_0-auc:0.97831
# [1042]	validation_0-auc:0.97831
# [1043]	validation_0-auc:0.97831
# [1044]	validation_0-auc:0.97831
# [1045]	validation_0-auc:0.97831
# [1046]	validation_0-auc:0.97831
# [1047]	validation_0-auc:0.97831
# [1048]	validation_0-auc:0.97831
# [1049]	validation_0-auc:0.97831
# [1050]	validation_0-auc:0.97831
# [1051]	validation_0-auc:0.97831
# [1052]	validation_0-auc:0.97831
# [1053]	validation_0-auc:0.97831
# [1054]	validation_0-auc:0.97831
# [1055]	validation_0-auc:0.97831
# [1056]	validation_0-auc:0.97831
# [1057]	validation_0-auc:0.97831
# [1058]	validation_0-auc:0.97831
# [1059]	validation_0-auc:0.97831
# [1060]	validation_0-auc:0.97831
# [1061]	validation_0-auc:0.97831
# [1062]	validation_0-auc:0.97831
# [1063]	validation_0-auc:0.97831
# [1064]	validation_0-auc:0.97831
# [1065]	validation_0-auc:0.97831
# [1066]	validation_0-auc:0.97831
# [1067]	validation_0-auc:0.97831
# [1068]	validation_0-auc:0.97831
# [1069]	validation_0-auc:0.97831
# [1070]	validation_0-auc:0.97831
# [1071]	validation_0-auc:0.97831
# [1072]	validation_0-auc:0.97831
# [1073]	validation_0-auc:0.97831
# [1074]	validation_0-auc:0.97831
# [1075]	validation_0-auc:0.97831
# [1076]	validation_0-auc:0.97831
# [1077]	validation_0-auc:0.97831
# [1078]	validation_0-auc:0.97831
# [1079]	validation_0-auc:0.97831
# [1080]	validation_0-auc:0.97831
# [1081]	validation_0-auc:0.97831
# [1082]	validation_0-auc:0.97831
# [1083]	validation_0-auc:0.97831
# [1084]	validation_0-auc:0.97831
# [1085]	validation_0-auc:0.97831
# [1086]	validation_0-auc:0.97831
# [1087]	validation_0-auc:0.97831
# [1088]	validation_0-auc:0.97831
# [1089]	validation_0-auc:0.97831
# [1090]	validation_0-auc:0.97834
# [1091]	validation_0-auc:0.97834
# [1092]	validation_0-auc:0.97834
# [1093]	validation_0-auc:0.97834
# [1094]	validation_0-auc:0.97834
# [1095]	validation_0-auc:0.97831
# [1096]	validation_0-auc:0.97831
# [1097]	validation_0-auc:0.97831
# [1098]	validation_0-auc:0.97831
# [1099]	validation_0-auc:0.97831
# [1100]	validation_0-auc:0.97831
# [1101]	validation_0-auc:0.97830
# [1102]	validation_0-auc:0.97830
# [1103]	validation_0-auc:0.97830
# [1104]	validation_0-auc:0.97830
# [1105]	validation_0-auc:0.97830
# [1106]	validation_0-auc:0.97830
# [1107]	validation_0-auc:0.97830
# [1108]	validation_0-auc:0.97830
# [1109]	validation_0-auc:0.97830
# [1110]	validation_0-auc:0.97830
# [1111]	validation_0-auc:0.97830
# [1112]	validation_0-auc:0.97830
# [1113]	validation_0-auc:0.97822
# [1114]	validation_0-auc:0.97822
# [1115]	validation_0-auc:0.97822
# [1116]	validation_0-auc:0.97822
# [1117]	validation_0-auc:0.97822
# [1118]	validation_0-auc:0.97822
# [1119]	validation_0-auc:0.97822
# [1120]	validation_0-auc:0.97822
# [1121]	validation_0-auc:0.97815
# [1122]	validation_0-auc:0.97815
# [1123]	validation_0-auc:0.97815
# [1124]	validation_0-auc:0.97815
# [1125]	validation_0-auc:0.97815
# [1126]	validation_0-auc:0.97815
# [1127]	validation_0-auc:0.97815
# [1128]	validation_0-auc:0.97815
# [1129]	validation_0-auc:0.97815
# [1130]	validation_0-auc:0.97815
# [1131]	validation_0-auc:0.97815
# [1132]	validation_0-auc:0.97815
# [1133]	validation_0-auc:0.97815
# [1134]	validation_0-auc:0.97815
# [1135]	validation_0-auc:0.97815
# [1136]	validation_0-auc:0.97815
# [1137]	validation_0-auc:0.97815
# [1138]	validation_0-auc:0.97815
# [1139]	validation_0-auc:0.97815
# [1140]	validation_0-auc:0.97815
# [1141]	validation_0-auc:0.97815
# [1142]	validation_0-auc:0.97815
# [1143]	validation_0-auc:0.97815
# [1144]	validation_0-auc:0.97815
# [1145]	validation_0-auc:0.97817
# [1146]	validation_0-auc:0.97817
# [1147]	validation_0-auc:0.97817
# [1148]	validation_0-auc:0.97817
# [1149]	validation_0-auc:0.97817
# [1150]	validation_0-auc:0.97817
# [1151]	validation_0-auc:0.97817
# [1152]	validation_0-auc:0.97817
# [1153]	validation_0-auc:0.97817
# [1154]	validation_0-auc:0.97817
# [1155]	validation_0-auc:0.97817
# [1156]	validation_0-auc:0.97817
# [1157]	validation_0-auc:0.97817
# [1158]	validation_0-auc:0.97817
# [1159]	validation_0-auc:0.97817
# [1160]	validation_0-auc:0.97817
# [1161]	validation_0-auc:0.97817
# [1162]	validation_0-auc:0.97817
# [1163]	validation_0-auc:0.97817
# [1164]	validation_0-auc:0.97817
# [1165]	validation_0-auc:0.97817
# [1166]	validation_0-auc:0.97817
# [1167]	validation_0-auc:0.97817
# [1168]	validation_0-auc:0.97817
# [1169]	validation_0-auc:0.97817
# [1170]	validation_0-auc:0.97817
# [1171]	validation_0-auc:0.97817
# [1172]	validation_0-auc:0.97817
# [1173]	validation_0-auc:0.97817
# [1174]	validation_0-auc:0.97817
# [1175]	validation_0-auc:0.97817
# [1176]	validation_0-auc:0.97817
# [1177]	validation_0-auc:0.97817
# [1178]	validation_0-auc:0.97817
# [1179]	validation_0-auc:0.97817
# [1180]	validation_0-auc:0.97817
# [1181]	validation_0-auc:0.97817
# [1182]	validation_0-auc:0.97817
# [1183]	validation_0-auc:0.97817
# [1184]	validation_0-auc:0.97817
# [1185]	validation_0-auc:0.97817
# [1186]	validation_0-auc:0.97819
# [1187]	validation_0-auc:0.97819
# [1188]	validation_0-auc:0.97819
# [1189]	validation_0-auc:0.97819
# [1190]	validation_0-auc:0.97819
# [1191]	validation_0-auc:0.97819
# [1192]	validation_0-auc:0.97819
# [1193]	validation_0-auc:0.97819
# [1194]	validation_0-auc:0.97819
# [1195]	validation_0-auc:0.97819
# [1196]	validation_0-auc:0.97819
# [1197]	validation_0-auc:0.97787
# [1198]	validation_0-auc:0.97787
# [1199]	validation_0-auc:0.97787
# [1200]	validation_0-auc:0.97787
# [1201]	validation_0-auc:0.97787
# [1202]	validation_0-auc:0.97787
# [1203]	validation_0-auc:0.97787
# [1204]	validation_0-auc:0.97787
# [1205]	validation_0-auc:0.97787
# [1206]	validation_0-auc:0.97787
# [1207]	validation_0-auc:0.97787
# [1208]	validation_0-auc:0.97787
# [1209]	validation_0-auc:0.97787
# [1210]	validation_0-auc:0.97787
# [1211]	validation_0-auc:0.97787
# [1212]	validation_0-auc:0.97787
# [1213]	validation_0-auc:0.97787
# [1214]	validation_0-auc:0.97787
# [1215]	validation_0-auc:0.97787
# [1216]	validation_0-auc:0.97787
# [1217]	validation_0-auc:0.97787
# [1218]	validation_0-auc:0.97787
# [1219]	validation_0-auc:0.97787
# [1220]	validation_0-auc:0.97787
# [1221]	validation_0-auc:0.97787
# [1222]	validation_0-auc:0.97787
# [1223]	validation_0-auc:0.97787
# [1224]	validation_0-auc:0.97787
# [1225]	validation_0-auc:0.97787
# [1226]	validation_0-auc:0.97787
# [1227]	validation_0-auc:0.97787
# [1228]	validation_0-auc:0.97787
# [1229]	validation_0-auc:0.97787
# [1230]	validation_0-auc:0.97787
# [1231]	validation_0-auc:0.97786
# [1232]	validation_0-auc:0.97786
# [1233]	validation_0-auc:0.97786
# [1234]	validation_0-auc:0.97786
# [1235]	validation_0-auc:0.97786
# [1236]	validation_0-auc:0.97787
# [1237]	validation_0-auc:0.97786
# [1238]	validation_0-auc:0.97786
# [1239]	validation_0-auc:0.97786
# [1240]	validation_0-auc:0.97786
# [1241]	validation_0-auc:0.97786
# [1242]	validation_0-auc:0.97786
# [1243]	validation_0-auc:0.97786
# [1244]	validation_0-auc:0.97786
# [1245]	validation_0-auc:0.97786
# [1246]	validation_0-auc:0.97786
# [1247]	validation_0-auc:0.97786
# [1248]	validation_0-auc:0.97786
# [1249]	validation_0-auc:0.97786
# [1250]	validation_0-auc:0.97786
# [1251]	validation_0-auc:0.97786
# [1252]	validation_0-auc:0.97786
# [1253]	validation_0-auc:0.97786
# [1254]	validation_0-auc:0.97786
# [1255]	validation_0-auc:0.97786
# [1256]	validation_0-auc:0.97786
# [1257]	validation_0-auc:0.97786
# [1258]	validation_0-auc:0.97786
# [1259]	validation_0-auc:0.97786
# [1260]	validation_0-auc:0.97786
# [1261]	validation_0-auc:0.97788
# [1262]	validation_0-auc:0.97788
# [1263]	validation_0-auc:0.97788
# [1264]	validation_0-auc:0.97788
# [1265]	validation_0-auc:0.97788
# [1266]	validation_0-auc:0.97788
# [1267]	validation_0-auc:0.97788
# [1268]	validation_0-auc:0.97788
# [1269]	validation_0-auc:0.97788
# [1270]	validation_0-auc:0.97788
# [1271]	validation_0-auc:0.97788
# [1272]	validation_0-auc:0.97788
# [1273]	validation_0-auc:0.97788
# [1274]	validation_0-auc:0.97788
# [1275]	validation_0-auc:0.97788
# [1276]	validation_0-auc:0.97788
# [1277]	validation_0-auc:0.97762
# [1278]	validation_0-auc:0.97762
# [1279]	validation_0-auc:0.97762
# [1280]	validation_0-auc:0.97762
# [1281]	validation_0-auc:0.97762
# [1282]	validation_0-auc:0.97762
# [1283]	validation_0-auc:0.97762
# [1284]	validation_0-auc:0.97762
# [1285]	validation_0-auc:0.97741
# [1286]	validation_0-auc:0.97741
# [1287]	validation_0-auc:0.97741
# [1288]	validation_0-auc:0.97741
# [1289]	validation_0-auc:0.97741
# [1290]	validation_0-auc:0.97741
# [1291]	validation_0-auc:0.97741
# [1292]	validation_0-auc:0.97741
# [1293]	validation_0-auc:0.97741
# [1294]	validation_0-auc:0.97741
# [1295]	validation_0-auc:0.97741
# [1296]	validation_0-auc:0.97741
# [1297]	validation_0-auc:0.97741
# [1298]	validation_0-auc:0.97741
# [1299]	validation_0-auc:0.97741
# [1300]	validation_0-auc:0.97741
# [1301]	validation_0-auc:0.97741
# [1302]	validation_0-auc:0.97741
# [1303]	validation_0-auc:0.97741
# [1304]	validation_0-auc:0.97741
# [1305]	validation_0-auc:0.97741
# [1306]	validation_0-auc:0.97741
# [1307]	validation_0-auc:0.97741
# [1308]	validation_0-auc:0.97741
# [1309]	validation_0-auc:0.97741
# [1310]	validation_0-auc:0.97741
# [1311]	validation_0-auc:0.97748
# [1312]	validation_0-auc:0.97748
# [1313]	validation_0-auc:0.97748
# [1314]	validation_0-auc:0.97748
# [1315]	validation_0-auc:0.97748
# [1316]	validation_0-auc:0.97748
# [1317]	validation_0-auc:0.97748
# [1318]	validation_0-auc:0.97748
# [1319]	validation_0-auc:0.97748
# [1320]	validation_0-auc:0.97751
# [1321]	validation_0-auc:0.97751
# [1322]	validation_0-auc:0.97751
# [1323]	validation_0-auc:0.97751
# [1324]	validation_0-auc:0.97751
# [1325]	validation_0-auc:0.97751
# [1326]	validation_0-auc:0.97751
# [1327]	validation_0-auc:0.97751
# [1328]	validation_0-auc:0.97750
# [1329]	validation_0-auc:0.97750
# [1330]	validation_0-auc:0.97749
# [1331]	validation_0-auc:0.97751
# [1332]	validation_0-auc:0.97751
# [1333]	validation_0-auc:0.97751
# [1334]	validation_0-auc:0.97751
# [1335]	validation_0-auc:0.97753
# [1336]	validation_0-auc:0.97753
# [1337]	validation_0-auc:0.97753
# [1338]	validation_0-auc:0.97753
# [1339]	validation_0-auc:0.97753
# [1340]	validation_0-auc:0.97753
# [1341]	validation_0-auc:0.97753
# [1342]	validation_0-auc:0.97753
# [1343]	validation_0-auc:0.97753
# [1344]	validation_0-auc:0.97753
# [1345]	validation_0-auc:0.97753
# [1346]	validation_0-auc:0.97753
# [1347]	validation_0-auc:0.97753
# [1348]	validation_0-auc:0.97753
# [1349]	validation_0-auc:0.97753
# [1350]	validation_0-auc:0.97753
# [1351]	validation_0-auc:0.97753
# [1352]	validation_0-auc:0.97753
# [1353]	validation_0-auc:0.97753
# [1354]	validation_0-auc:0.97753
# [1355]	validation_0-auc:0.97753
# [1356]	validation_0-auc:0.97753
# [1357]	validation_0-auc:0.97753
# [1358]	validation_0-auc:0.97753
# [1359]	validation_0-auc:0.97753
# [1360]	validation_0-auc:0.97753
# [1361]	validation_0-auc:0.97753
# [1362]	validation_0-auc:0.97753
# [1363]	validation_0-auc:0.97753
# [1364]	validation_0-auc:0.97753
# [1365]	validation_0-auc:0.97753
# [1366]	validation_0-auc:0.97753
# [1367]	validation_0-auc:0.97753
# [1368]	validation_0-auc:0.97753
# [1369]	validation_0-auc:0.97753
# [1370]	validation_0-auc:0.97753
# [1371]	validation_0-auc:0.97753
# [1372]	validation_0-auc:0.97753
# ...
# [1726]	validation_0-auc:0.97807
# [1727]	validation_0-auc:0.97807
# [1728]	validation_0-auc:0.97807
# [1729]	validation_0-auc:0.97807
# [1730]	validation_0-auc:0.97807
# [1731]	validation_0-auc:0.97808
# [1732]	validation_0-auc:0.97808
# [1733]	validation_0-auc:0.97808
# [1734]	validation_0-auc:0.97808
# [1735]	validation_0-auc:0.97808
# [1736]	validation_0-auc:0.97808
# [1737]	validation_0-auc:0.97808
# [1738]	validation_0-auc:0.97808
# [1739]	validation_0-auc:0.97808
# [1740]	validation_0-auc:0.97808
# [1741]	validation_0-auc:0.97808
# [1742]	validation_0-auc:0.97808
# [1743]	validation_0-auc:0.97808
# [1744]	validation_0-auc:0.97808
# [1745]	validation_0-auc:0.97808
# [1746]	validation_0-auc:0.97808
# [1747]	validation_0-auc:0.97806
# [1748]	validation_0-auc:0.97806
# [1749]	validation_0-auc:0.97806
# [1750]	validation_0-auc:0.97806
# [1751]	validation_0-auc:0.97806
# [1752]	validation_0-auc:0.97806
# [1753]	validation_0-auc:0.97806
# [1754]	validation_0-auc:0.97806
# [1755]	validation_0-auc:0.97806
# [1756]	validation_0-auc:0.97806
# [1757]	validation_0-auc:0.97806
# [1758]	validation_0-auc:0.97806
# [1759]	validation_0-auc:0.97806
# [1760]	validation_0-auc:0.97806
# [1761]	validation_0-auc:0.97806
# [1762]	validation_0-auc:0.97806
# [1763]	validation_0-auc:0.97806
# [1764]	validation_0-auc:0.97806
# [1765]	validation_0-auc:0.97806
# [1766]	validation_0-auc:0.97806
# [1767]	validation_0-auc:0.97806
# [1768]	validation_0-auc:0.97806
# [1769]	validation_0-auc:0.97806
# [1770]	validation_0-auc:0.97806
# [1771]	validation_0-auc:0.97806
# [1772]	validation_0-auc:0.97806
# [1773]	validation_0-auc:0.97806
# [1774]	validation_0-auc:0.97806
# [1775]	validation_0-auc:0.97806
# [1776]	validation_0-auc:0.97806
# [1777]	validation_0-auc:0.97806
# [1778]	validation_0-auc:0.97806
# [1779]	validation_0-auc:0.97806
# [1780]	validation_0-auc:0.97806
# [1781]	validation_0-auc:0.97806
# [1782]	validation_0-auc:0.97806
# [1783]	validation_0-auc:0.97806
# [1784]	validation_0-auc:0.97806
# [1785]	validation_0-auc:0.97806
# [1786]	validation_0-auc:0.97797
# [1787]	validation_0-auc:0.97796
# [1788]	validation_0-auc:0.97796
# [1789]	validation_0-auc:0.97796
# [1790]	validation_0-auc:0.97796
# [1791]	validation_0-auc:0.97796
# [1792]	validation_0-auc:0.97796
# [1793]	validation_0-auc:0.97796
# [1794]	validation_0-auc:0.97796
# [1795]	validation_0-auc:0.97796
# [1796]	validation_0-auc:0.97796
# [1797]	validation_0-auc:0.97796
# [1798]	validation_0-auc:0.97796
# [1799]	validation_0-auc:0.97796
# [1800]	validation_0-auc:0.97796
# [1801]	validation_0-auc:0.97796
# [1802]	validation_0-auc:0.97796
# [1803]	validation_0-auc:0.97796
# [1804]	validation_0-auc:0.97796
# [1805]	validation_0-auc:0.97796
# [1806]	validation_0-auc:0.97796
# [1807]	validation_0-auc:0.97796
# [1808]	validation_0-auc:0.97796
# [1809]	validation_0-auc:0.97796
# [1810]	validation_0-auc:0.97796
# [1811]	validation_0-auc:0.97796
# [1812]	validation_0-auc:0.97796
# [1813]	validation_0-auc:0.97796
# [1814]	validation_0-auc:0.97796
# [1815]	validation_0-auc:0.97796
# [1816]	validation_0-auc:0.97796
# [1817]	validation_0-auc:0.97796
# [1818]	validation_0-auc:0.97796
# [1819]	validation_0-auc:0.97796
# [1820]	validation_0-auc:0.97796
# [1821]	validation_0-auc:0.97796
# [1822]	validation_0-auc:0.97796
# [1823]	validation_0-auc:0.97796
# [1824]	validation_0-auc:0.97796
# [1825]	validation_0-auc:0.97796
# [1826]	validation_0-auc:0.97796
# [1827]	validation_0-auc:0.97796
# [1828]	validation_0-auc:0.97796
# [1829]	validation_0-auc:0.97796
# [1830]	validation_0-auc:0.97796
# [1831]	validation_0-auc:0.97796
# [1832]	validation_0-auc:0.97796
# [1833]	validation_0-auc:0.97796
# [1834]	validation_0-auc:0.97796
# [1835]	validation_0-auc:0.97796
# [1836]	validation_0-auc:0.97796
# [1837]	validation_0-auc:0.97796
# [1838]	validation_0-auc:0.97796
# [1839]	validation_0-auc:0.97796
# [1840]	validation_0-auc:0.97796
# [1841]	validation_0-auc:0.97796
# [1842]	validation_0-auc:0.97796
# [1843]	validation_0-auc:0.97796
# [1844]	validation_0-auc:0.97796
# [1845]	validation_0-auc:0.97796
# [1846]	validation_0-auc:0.97796
# [1847]	validation_0-auc:0.97796
# [1848]	validation_0-auc:0.97796
# [1849]	validation_0-auc:0.97796
# [1850]	validation_0-auc:0.97796
# [1851]	validation_0-auc:0.97796
# [1852]	validation_0-auc:0.97796
# [1853]	validation_0-auc:0.97796
# [1854]	validation_0-auc:0.97796
# [1855]	validation_0-auc:0.97796
# [1856]	validation_0-auc:0.97796
# [1857]	validation_0-auc:0.97796
# [1858]	validation_0-auc:0.97796
# [1859]	validation_0-auc:0.97796
# [1860]	validation_0-auc:0.97796
# [1861]	validation_0-auc:0.97796
# [1862]	validation_0-auc:0.97796
# [1863]	validation_0-auc:0.97796
# [1864]	validation_0-auc:0.97796
# [1865]	validation_0-auc:0.97796
# [1866]	validation_0-auc:0.97796
# [1867]	validation_0-auc:0.97796
# [1868]	validation_0-auc:0.97796
# [1869]	validation_0-auc:0.97796
# [1870]	validation_0-auc:0.97796
# [1871]	validation_0-auc:0.97796
# [1872]	validation_0-auc:0.97796
# [1873]	validation_0-auc:0.97796
# [1874]	validation_0-auc:0.97796
# [1875]	validation_0-auc:0.97796
# [1876]	validation_0-auc:0.97796
# [1877]	validation_0-auc:0.97796
# [1878]	validation_0-auc:0.97796
# [1879]	validation_0-auc:0.97796
# [1880]	validation_0-auc:0.97796
# [1881]	validation_0-auc:0.97796
# [1882]	validation_0-auc:0.97796
# [1883]	validation_0-auc:0.97796
# [1884]	validation_0-auc:0.97796
# [1885]	validation_0-auc:0.97796
# [1886]	validation_0-auc:0.97796
# [1887]	validation_0-auc:0.97796
# [1888]	validation_0-auc:0.97796
# [1889]	validation_0-auc:0.97796
# [1890]	validation_0-auc:0.97796
# [1891]	validation_0-auc:0.97796
# [1892]	validation_0-auc:0.97796
# [1893]	validation_0-auc:0.97796
# [1894]	validation_0-auc:0.97796
# [1895]	validation_0-auc:0.97796
# [1896]	validation_0-auc:0.97796
# [1897]	validation_0-auc:0.97796
# [1898]	validation_0-auc:0.97796
# [1899]	validation_0-auc:0.97796
# [1900]	validation_0-auc:0.97796
# [1901]	validation_0-auc:0.97796
# [1902]	validation_0-auc:0.97796
# [1903]	validation_0-auc:0.97796
# [1904]	validation_0-auc:0.97796
# [1905]	validation_0-auc:0.97796
# [1906]	validation_0-auc:0.97796
# [1907]	validation_0-auc:0.97796
# [1908]	validation_0-auc:0.97796
# [1909]	validation_0-auc:0.97796
# [1910]	validation_0-auc:0.97796
# [1911]	validation_0-auc:0.97796
# [1912]	validation_0-auc:0.97793
# [1913]	validation_0-auc:0.97793
# [1914]	validation_0-auc:0.97793
# [1915]	validation_0-auc:0.97793
# [1916]	validation_0-auc:0.97778
# [1917]	validation_0-auc:0.97778
# [1918]	validation_0-auc:0.97778
# [1919]	validation_0-auc:0.97778
# [1920]	validation_0-auc:0.97778
# [1921]	validation_0-auc:0.97778
# [1922]	validation_0-auc:0.97778
# [1923]	validation_0-auc:0.97778
# [1924]	validation_0-auc:0.97778
# [1925]	validation_0-auc:0.97778
# [1926]	validation_0-auc:0.97778
# [1927]	validation_0-auc:0.97778
# [1928]	validation_0-auc:0.97778
# [1929]	validation_0-auc:0.97778
# [1930]	validation_0-auc:0.97778
# [1931]	validation_0-auc:0.97778
# [1932]	validation_0-auc:0.97778
# [1933]	validation_0-auc:0.97778
# [1934]	validation_0-auc:0.97778
# [1935]	validation_0-auc:0.97782
# [1936]	validation_0-auc:0.97782
# [1937]	validation_0-auc:0.97782
# [1938]	validation_0-auc:0.97782
# [1939]	validation_0-auc:0.97782
# [1940]	validation_0-auc:0.97782
# [1941]	validation_0-auc:0.97782
# [1942]	validation_0-auc:0.97782
# [1943]	validation_0-auc:0.97782
# [1944]	validation_0-auc:0.97782
# [1945]	validation_0-auc:0.97782
# [1946]	validation_0-auc:0.97782
# [1947]	validation_0-auc:0.97782
# [1948]	validation_0-auc:0.97782
# [1949]	validation_0-auc:0.97782
# [1950]	validation_0-auc:0.97782
# [1951]	validation_0-auc:0.97782
# [1952]	validation_0-auc:0.97782
# [1953]	validation_0-auc:0.97782
# [1954]	validation_0-auc:0.97782
# [1955]	validation_0-auc:0.97782
# [1956]	validation_0-auc:0.97782
# [1957]	validation_0-auc:0.97782
# [1958]	validation_0-auc:0.97782
# [1959]	validation_0-auc:0.97782
# [1960]	validation_0-auc:0.97782
# [1961]	validation_0-auc:0.97782
# [1962]	validation_0-auc:0.97782
# [1963]	validation_0-auc:0.97782
# [1964]	validation_0-auc:0.97782
# [1965]	validation_0-auc:0.97782
# [1966]	validation_0-auc:0.97782
# [1967]	validation_0-auc:0.97782
# [1968]	validation_0-auc:0.97782
# [1969]	validation_0-auc:0.97782
# [1970]	validation_0-auc:0.97782
# [1971]	validation_0-auc:0.97782
# [1972]	validation_0-auc:0.97782
# [1973]	validation_0-auc:0.97782
# [1974]	validation_0-auc:0.97782
# [1975]	validation_0-auc:0.97782
# [1976]	validation_0-auc:0.97782
# [1977]	validation_0-auc:0.97782
# [1978]	validation_0-auc:0.97781
# [1979]	validation_0-auc:0.97781
# [1980]	validation_0-auc:0.97781
# [1981]	validation_0-auc:0.97781
# [1982]	validation_0-auc:0.97781
# [1983]	validation_0-auc:0.97781
# [1984]	validation_0-auc:0.97781
# [1985]	validation_0-auc:0.97782
# [1986]	validation_0-auc:0.97782
# [1987]	validation_0-auc:0.97782
# [1988]	validation_0-auc:0.97782
# [1989]	validation_0-auc:0.97782
# [1990]	validation_0-auc:0.97782
# [1991]	validation_0-auc:0.97782
# [1992]	validation_0-auc:0.97782
# [1993]	validation_0-auc:0.97782
# [1994]	validation_0-auc:0.97782
# [1995]	validation_0-auc:0.97782
# [1996]	validation_0-auc:0.97782
# [1997]	validation_0-auc:0.97782
# [1998]	validation_0-auc:0.97782
# [1999]	validation_0-auc:0.97782
# RStuned Execution time: 00:00:19
# [0]	validation_0-logloss:0.46052
# [1]	validation_0-logloss:0.32873
# [2]	validation_0-logloss:0.24201
# [3]	validation_0-logloss:0.18165
# [4]	validation_0-logloss:0.13865
# [5]	validation_0-logloss:0.10601
# [6]	validation_0-logloss:0.08214
# [7]	validation_0-logloss:0.06521
# [8]	validation_0-logloss:0.05236
# [9]	validation_0-logloss:0.04292
# [10]	validation_0-logloss:0.03549
# [11]	validation_0-logloss:0.03011
# [12]	validation_0-logloss:0.02602
# [13]	validation_0-logloss:0.02258
# [14]	validation_0-logloss:0.01971
# [15]	validation_0-logloss:0.01775
# [16]	validation_0-logloss:0.01587
# [17]	validation_0-logloss:0.01461
# [18]	validation_0-logloss:0.01319
# [19]	validation_0-logloss:0.01210
# [20]	validation_0-logloss:0.01067
# [21]	validation_0-logloss:0.00991
# [22]	validation_0-logloss:0.00940
# [23]	validation_0-logloss:0.00862
# [24]	validation_0-logloss:0.00804
# [25]	validation_0-logloss:0.00726
# [26]	validation_0-logloss:0.00657
# [27]	validation_0-logloss:0.00591
# [28]	validation_0-logloss:0.00554
# [29]	validation_0-logloss:0.00533
# [30]	validation_0-logloss:0.00500
# [31]	validation_0-logloss:0.00480
# [32]	validation_0-logloss:0.00462
# [33]	validation_0-logloss:0.00430
# [34]	validation_0-logloss:0.00414
# [35]	validation_0-logloss:0.00404
# [36]	validation_0-logloss:0.00391
# [37]	validation_0-logloss:0.00382
# [38]	validation_0-logloss:0.00369
# [39]	validation_0-logloss:0.00365
# [40]	validation_0-logloss:0.00362
# [41]	validation_0-logloss:0.00359
# [42]	validation_0-logloss:0.00354
# [43]	validation_0-logloss:0.00353
# [44]	validation_0-logloss:0.00350
# [45]	validation_0-logloss:0.00349
# [46]	validation_0-logloss:0.00345
# [47]	validation_0-logloss:0.00340
# [48]	validation_0-logloss:0.00342
# [49]	validation_0-logloss:0.00337
# [50]	validation_0-logloss:0.00336
# [51]	validation_0-logloss:0.00338
# [52]	validation_0-logloss:0.00337
# [53]	validation_0-logloss:0.00335
# [54]	validation_0-logloss:0.00336
# [55]	validation_0-logloss:0.00338
# [56]	validation_0-logloss:0.00335
# [57]	validation_0-logloss:0.00334
# [58]	validation_0-logloss:0.00333
# [59]	validation_0-logloss:0.00335
# [60]	validation_0-logloss:0.00335
# [61]	validation_0-logloss:0.00336
# [62]	validation_0-logloss:0.00336
# [63]	validation_0-logloss:0.00337
# [64]	validation_0-logloss:0.00337
# [65]	validation_0-logloss:0.00339
# [66]	validation_0-logloss:0.00342
# [67]	validation_0-logloss:0.00343
# [68]	validation_0-logloss:0.00345
# [69]	validation_0-logloss:0.00344
# [70]	validation_0-logloss:0.00346
# [71]	validation_0-logloss:0.00346
# [72]	validation_0-logloss:0.00346
# [73]	validation_0-logloss:0.00350
# [74]	validation_0-logloss:0.00351
# [75]	validation_0-logloss:0.00352
# [76]	validation_0-logloss:0.00353
# [77]	validation_0-logloss:0.00354
# [78]	validation_0-logloss:0.00356
# [79]	validation_0-logloss:0.00359
# [80]	validation_0-logloss:0.00357
# [81]	validation_0-logloss:0.00359
# [82]	validation_0-logloss:0.00362
# [83]	validation_0-logloss:0.00362
# [84]	validation_0-logloss:0.00363
# [85]	validation_0-logloss:0.00364
# [86]	validation_0-logloss:0.00366
# [87]	validation_0-logloss:0.00365
# [88]	validation_0-logloss:0.00365
# [89]	validation_0-logloss:0.00365
# [90]	validation_0-logloss:0.00365
# [91]	validation_0-logloss:0.00367
# [92]	validation_0-logloss:0.00367
# [93]	validation_0-logloss:0.00367
# [94]	validation_0-logloss:0.00368
# [95]	validation_0-logloss:0.00370
# [96]	validation_0-logloss:0.00369
# [97]	validation_0-logloss:0.00371
# [98]	validation_0-logloss:0.00371
# [99]	validation_0-logloss:0.00371
# [0]	validation_0-auc:0.69883
# [1]	validation_0-auc:0.91949
# [2]	validation_0-auc:0.92739
# [3]	validation_0-auc:0.92259
# [4]	validation_0-auc:0.93748
# [5]	validation_0-auc:0.93108
# [6]	validation_0-auc:0.92614
# [7]	validation_0-auc:0.91332
# [8]	validation_0-auc:0.91491
# [9]	validation_0-auc:0.91159
# [10]	validation_0-auc:0.91340
# [11]	validation_0-auc:0.91453
# [12]	validation_0-auc:0.92316
# [13]	validation_0-auc:0.92759
# [14]	validation_0-auc:0.92490
# [15]	validation_0-auc:0.91826
# [16]	validation_0-auc:0.91747
# [17]	validation_0-auc:0.91498
# [18]	validation_0-auc:0.91226
# [19]	validation_0-auc:0.91024
# [20]	validation_0-auc:0.91210
# [21]	validation_0-auc:0.90847
# [22]	validation_0-auc:0.90849
# [23]	validation_0-auc:0.91069
# [24]	validation_0-auc:0.90952
# [25]	validation_0-auc:0.90951
# [26]	validation_0-auc:0.90821
# [27]	validation_0-auc:0.90840
# [28]	validation_0-auc:0.90726
# [29]	validation_0-auc:0.90885
# [30]	validation_0-auc:0.90580
# [31]	validation_0-auc:0.90790
# [32]	validation_0-auc:0.90865
# [33]	validation_0-auc:0.90913
# [34]	validation_0-auc:0.90839
# [35]	validation_0-auc:0.90671
# [36]	validation_0-auc:0.90771
# [37]	validation_0-auc:0.90699
# [38]	validation_0-auc:0.90665
# [39]	validation_0-auc:0.90784
# [40]	validation_0-auc:0.90760
# [41]	validation_0-auc:0.90730
# [42]	validation_0-auc:0.90774
# [43]	validation_0-auc:0.90816
# [44]	validation_0-auc:0.90874
# [45]	validation_0-auc:0.90747
# [46]	validation_0-auc:0.90761
# [47]	validation_0-auc:0.90767
# [48]	validation_0-auc:0.90941
# [49]	validation_0-auc:0.90960
# [50]	validation_0-auc:0.90825
# [51]	validation_0-auc:0.91001
# [52]	validation_0-auc:0.90862
# [53]	validation_0-auc:0.90756
# [54]	validation_0-auc:0.90885
# [55]	validation_0-auc:0.90920
# [56]	validation_0-auc:0.90990
# [57]	validation_0-auc:0.91067
# [58]	validation_0-auc:0.91033
# [59]	validation_0-auc:0.91056
# [60]	validation_0-auc:0.91098
# [61]	validation_0-auc:0.91163
# [62]	validation_0-auc:0.91385
# [63]	validation_0-auc:0.91477
# [64]	validation_0-auc:0.91377
# [65]	validation_0-auc:0.91475
# [66]	validation_0-auc:0.91481
# [67]	validation_0-auc:0.91534
# [68]	validation_0-auc:0.91497
# [69]	validation_0-auc:0.91468
# [70]	validation_0-auc:0.91619
# [71]	validation_0-auc:0.91704
# [72]	validation_0-auc:0.91610
# [73]	validation_0-auc:0.91733
# [74]	validation_0-auc:0.91722
# [75]	validation_0-auc:0.91737
# [76]	validation_0-auc:0.91717
# [77]	validation_0-auc:0.91761
# [78]	validation_0-auc:0.91720
# [79]	validation_0-auc:0.91696
# [80]	validation_0-auc:0.91741
# [81]	validation_0-auc:0.91757
# [82]	validation_0-auc:0.91803
# [83]	validation_0-auc:0.91797
# [84]	validation_0-auc:0.91863
# [85]	validation_0-auc:0.91938
# [86]	validation_0-auc:0.92006
# [87]	validation_0-auc:0.92046
# [88]	validation_0-auc:0.92117
# [89]	validation_0-auc:0.92144
# [90]	validation_0-auc:0.92140
# [91]	validation_0-auc:0.92177
# [92]	validation_0-auc:0.92176
# [93]	validation_0-auc:0.92230
# [94]	validation_0-auc:0.92146
# [95]	validation_0-auc:0.92096
# [96]	validation_0-auc:0.92191
# [97]	validation_0-auc:0.92168
# [98]	validation_0-auc:0.92158
# [99]	validation_0-auc:0.92059
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=device(type='cpu'),
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='auc', feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=1000, ...)

# %%
print("current k fold: ", current_k_fold)
evaluate_model(
    [
        vanilla_xgb,
        adjusted_vanilla_xgb,
		random_search_tuned,
        grid_tuned_1,

    ],
    X_test,
    y_test,
    names=[
        "Vanilla XGB",
		"adjusted_vanilla_xgb",
        "Random Search Tuned",
        "GridTuned 1",
    ],
	as_table=True
)
# Out:
# current k fold:  10
#              Model Name  AUCPRC      F1  G-Mean     MCC  Precision  Recall  \
# 2   Random Search Tuned  0.9335  0.9231  0.9453  0.9235     0.9545  0.8936
# 1  adjusted_vanilla_xgb  0.9271  0.8958  0.9564  0.8959     0.8776  0.9149
# 0           Vanilla XGB  0.9108  0.9231  0.9453  0.9235     0.9545  0.8936
# 3           GridTuned 1  0.9091  0.8431  0.9563  0.8455     0.7818  0.9149
#
#    ROCAUC  ACCURACY    TP    FP       TN   FN
# 2  0.9901    0.9998  42.0   2.0  28324.0  5.0
# 1  0.9930    0.9996  43.0   6.0  28320.0  4.0
# 0  0.9892    0.9998  42.0   2.0  28324.0  5.0
# 3  0.9789    0.9994  43.0  12.0  28314.0  4.0
