# %% [markdown]
# Model Architecture from https://keras.io/examples/structured_data/imbalanced_classification/

# %%
import pickle
import time

# imoprt data science libraries
import pandas as pd
from pandas import DataFrame as df
import matplotlib.pyplot as plt
import numpy as np

# Import ML libraries
import keras
import model_utils as mutils
from model_utils.evaluation import get_metrics, evaluate_model, table
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# For SelfPacedEnsemble
from imbens.ensemble import SelfPacedEnsembleClassifier as SPE
from scikeras.wrappers import KerasClassifier

current_k_fold = 3
# set seed
SEED=current_k_fold**3
np.random.seed(SEED)

# pandas options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# deserialize pre-processed data
path_to_pickle = f'../data/creditcard/cc13_preprocessed_k{current_k_fold}.pkl'

with open(path_to_pickle, "rb") as f:
    data = pickle.load(f)
    X_train = data["X_train"].to_numpy()
    y_train = data["y_train"].to_numpy()

    X_val = data["X_val"].to_numpy()
    y_val = data["y_val"].to_numpy()

    X_test = data["X_test"].to_numpy()
    y_test = data["y_test"].to_numpy()

    col_names = data["col_names"]

print("Data loaded successfully")

# get imbalance ratio for each data set
IR_train = mutils.imb_ratio(data["y_train"].value_counts())
IR_val = mutils.imb_ratio(data["y_val"].value_counts())
IR_test = mutils.imb_ratio(data["y_test"].value_counts())

# print imbalance ratios. They should be (nearly) the same. pct = 0.172 such as in the paper!
print(f"Imbalance ratio in training data: {IR_train}")
print(f"Imbalance ratio in validation data: {IR_val}")
print(f"Imbalance ratio in test data: {IR_test}")

# print number of samples in each data set
print(f"\nNumber of samples in training data: {len(y_train)}")
print(f"Number of samples in validation data: {len(y_val)}")
print(f"Number of samples in test data: {len(y_test)}")

# Reshape
y_train = y_train.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)
y_val = y_val.reshape(-1, 1)

# Set Weight
res_value_counts = df(y_train).value_counts()
weight_for_0 = 1.0 / res_value_counts[0]
weight_for_1 = 1.0 / res_value_counts[1]

# print number of samples in each data set
print(f"\nNumber of samples in training data: {len(y_train)}")
print(f"Number of samples in validation data: {len(y_val)}")
print(f"Number of samples in test data: {len(y_test)}")

# Normalize Data
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)
# Out:
# Data loaded successfully
# Imbalance ratio in training data: 599.48
# Imbalance ratio in validation data: 602.68
# Imbalance ratio in test data: 590.1
#
# Number of samples in training data: 226980
# Number of samples in validation data: 28373
# Number of samples in test data: 28373
#
# Number of samples in training data: 226980
# Number of samples in validation data: 28373
# Number of samples in test data: 28373

# %% [markdown]
# ## Build the Model

# %%
np.shape(X_train)[1]
# Out:
# 29

# %%
{0: weight_for_0, 1: weight_for_1}
# Out:
# {0: 4.413023715589447e-06, 1: 0.0026455026455026454}

# %%
"""
## Credits for Model: https://keras.io/examples/structured_data/imbalanced_classification/
"""

# Hyperparams:
data_dim = np.shape(X_train)[1]
batch_size=2048
epochs=50
learning_rate=1e-2
Adam = keras.optimizers.Adam(learning_rate)
class_weight = {0: weight_for_0, 1: weight_for_1}

model = keras.Sequential(
    [
        keras.Input(shape=(data_dim,)),
        keras.layers.Dense(256, activation="relu"),
        keras.layers.Dense(256, activation="relu"),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(256, activation="relu"),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(1, activation="sigmoid"),
    ]
)

metrics = [
    keras.metrics.AUC(name="roc_auc", curve='ROC'),
    keras.metrics.AUC(name='auc_prc', curve="PR"),
	keras.metrics.F1Score(name="f1"),
	
    keras.metrics.FalseNegatives(name="fn"),
    keras.metrics.FalsePositives(name="fp"),
    keras.metrics.TrueNegatives(name="tn"),
    keras.metrics.TruePositives(name="tp"),
    keras.metrics.Precision(name="precision"),
    keras.metrics.Recall(name="recall"),
]

model.compile(
    optimizer=Adam, loss="binary_crossentropy", metrics=metrics
)

callbacks = [keras.callbacks.ModelCheckpoint(f"./ckp/MLP_Normal_CC/k{current_k_fold}"+"_epoch_{epoch}.keras")]


hist = model.fit(
    X_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    verbose=2,
    callbacks=callbacks,
    validation_data=(X_val, y_val),
    class_weight=class_weight,
)
# Out:
# Epoch 1/50
# 111/111 - 2s - 20ms/step - auc_prc: 0.3840 - f1: 0.0033 - fn: 43.0000 - fp: 30708.0000 - loss: 2.3285e-06 - precision: 0.0108 - recall: 0.8862 - roc_auc: 0.9557 - tn: 195894.0000 - tp: 335.0000 - val_auc_prc: 0.5805 - val_f1: 0.0033 - val_fn: 5.0000 - val_fp: 1260.0000 - val_loss: 0.1435 - val_precision: 0.0323 - val_recall: 0.8936 - val_roc_auc: 0.9808 - val_tn: 27066.0000 - val_tp: 42.0000
# Epoch 2/50
# 111/111 - 1s - 8ms/step - auc_prc: 0.4638 - f1: 0.0033 - fn: 29.0000 - fp: 9200.0000 - loss: 1.4274e-06 - precision: 0.0365 - recall: 0.9233 - roc_auc: 0.9816 - tn: 217402.0000 - tp: 349.0000 - val_auc_prc: 0.2677 - val_f1: 0.0033 - val_fn: 3.0000 - val_fp: 3190.0000 - val_loss: 0.3161 - val_precision: 0.0136 - val_recall: 0.9362 - val_roc_auc: 0.9797 - val_tn: 25136.0000 - val_tp: 44.0000
# Epoch 3/50
# 111/111 - 1s - 8ms/step - auc_prc: 0.4467 - f1: 0.0033 - fn: 25.0000 - fp: 8861.0000 - loss: 1.1370e-06 - precision: 0.0383 - recall: 0.9339 - roc_auc: 0.9897 - tn: 217741.0000 - tp: 353.0000 - val_auc_prc: 0.7201 - val_f1: 0.0033 - val_fn: 5.0000 - val_fp: 483.0000 - val_loss: 0.0595 - val_precision: 0.0800 - val_recall: 0.8936 - val_roc_auc: 0.9747 - val_tn: 27843.0000 - val_tp: 42.0000
# Epoch 4/50
# 111/111 - 1s - 8ms/step - auc_prc: 0.5735 - f1: 0.0033 - fn: 18.0000 - fp: 7981.0000 - loss: 8.9820e-07 - precision: 0.0432 - recall: 0.9524 - roc_auc: 0.9936 - tn: 218621.0000 - tp: 360.0000 - val_auc_prc: 0.6709 - val_f1: 0.0033 - val_fn: 5.0000 - val_fp: 1198.0000 - val_loss: 0.0987 - val_precision: 0.0339 - val_recall: 0.8936 - val_roc_auc: 0.9837 - val_tn: 27128.0000 - val_tp: 42.0000
# Epoch 5/50
# 111/111 - 1s - 8ms/step - auc_prc: 0.5846 - f1: 0.0034 - fn: 15.0000 - fp: 6986.0000 - loss: 7.1106e-07 - precision: 0.0494 - recall: 0.9603 - roc_auc: 0.9961 - tn: 219616.0000 - tp: 363.0000 - val_auc_prc: 0.6685 - val_f1: 0.0033 - val_fn: 5.0000 - val_fp: 1058.0000 - val_loss: 0.0843 - val_precision: 0.0382 - val_recall: 0.8936 - val_roc_auc: 0.9722 - val_tn: 27268.0000 - val_tp: 42.0000
# Epoch 6/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.4064 - f1: 0.0034 - fn: 12.0000 - fp: 8593.0000 - loss: 7.8452e-07 - precision: 0.0409 - recall: 0.9683 - roc_auc: 0.9951 - tn: 218009.0000 - tp: 366.0000 - val_auc_prc: 0.3937 - val_f1: 0.0033 - val_fn: 5.0000 - val_fp: 1078.0000 - val_loss: 0.0999 - val_precision: 0.0375 - val_recall: 0.8936 - val_roc_auc: 0.9750 - val_tn: 27248.0000 - val_tp: 42.0000
# Epoch 7/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.4308 - f1: 0.0034 - fn: 14.0000 - fp: 9083.0000 - loss: 7.7500e-07 - precision: 0.0385 - recall: 0.9630 - roc_auc: 0.9953 - tn: 217519.0000 - tp: 364.0000 - val_auc_prc: 0.6580 - val_f1: 0.0034 - val_fn: 5.0000 - val_fp: 1452.0000 - val_loss: 0.1028 - val_precision: 0.0281 - val_recall: 0.8936 - val_roc_auc: 0.9553 - val_tn: 26874.0000 - val_tp: 42.0000
# Epoch 8/50
# 111/111 - 1s - 8ms/step - auc_prc: 0.5411 - f1: 0.0035 - fn: 9.0000 - fp: 8706.0000 - loss: 7.4148e-07 - precision: 0.0407 - recall: 0.9762 - roc_auc: 0.9958 - tn: 217896.0000 - tp: 369.0000 - val_auc_prc: 0.7195 - val_f1: 0.0034 - val_fn: 5.0000 - val_fp: 714.0000 - val_loss: 0.0624 - val_precision: 0.0556 - val_recall: 0.8936 - val_roc_auc: 0.9784 - val_tn: 27612.0000 - val_tp: 42.0000
# Epoch 9/50
# 111/111 - 1s - 8ms/step - auc_prc: 0.6421 - f1: 0.0035 - fn: 12.0000 - fp: 6022.0000 - loss: 6.3156e-07 - precision: 0.0573 - recall: 0.9683 - roc_auc: 0.9967 - tn: 220580.0000 - tp: 366.0000 - val_auc_prc: 0.5602 - val_f1: 0.0035 - val_fn: 4.0000 - val_fp: 1062.0000 - val_loss: 0.0848 - val_precision: 0.0389 - val_recall: 0.9149 - val_roc_auc: 0.9886 - val_tn: 27264.0000 - val_tp: 43.0000
# Epoch 10/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.4859 - f1: 0.0038 - fn: 7.0000 - fp: 5966.0000 - loss: 5.5147e-07 - precision: 0.0585 - recall: 0.9815 - roc_auc: 0.9963 - tn: 220636.0000 - tp: 371.0000 - val_auc_prc: 0.0928 - val_f1: 0.0036 - val_fn: 3.0000 - val_fp: 2590.0000 - val_loss: 0.2854 - val_precision: 0.0167 - val_recall: 0.9362 - val_roc_auc: 0.9725 - val_tn: 25736.0000 - val_tp: 44.0000
# Epoch 11/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.4567 - f1: 0.0038 - fn: 9.0000 - fp: 7862.0000 - loss: 6.7176e-07 - precision: 0.0448 - recall: 0.9762 - roc_auc: 0.9963 - tn: 218740.0000 - tp: 369.0000 - val_auc_prc: 0.7319 - val_f1: 0.0040 - val_fn: 4.0000 - val_fp: 296.0000 - val_loss: 0.0333 - val_precision: 0.1268 - val_recall: 0.9149 - val_roc_auc: 0.9627 - val_tn: 28030.0000 - val_tp: 43.0000
# Epoch 12/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.4540 - f1: 0.0042 - fn: 6.0000 - fp: 6025.0000 - loss: 5.4524e-07 - precision: 0.0582 - recall: 0.9841 - roc_auc: 0.9974 - tn: 220577.0000 - tp: 372.0000 - val_auc_prc: 0.6906 - val_f1: 0.0041 - val_fn: 5.0000 - val_fp: 556.0000 - val_loss: 0.0524 - val_precision: 0.0702 - val_recall: 0.8936 - val_roc_auc: 0.9593 - val_tn: 27770.0000 - val_tp: 42.0000
# Epoch 13/50
# 111/111 - 1s - 8ms/step - auc_prc: 0.4660 - f1: 0.0046 - fn: 9.0000 - fp: 5547.0000 - loss: 4.8689e-07 - precision: 0.0624 - recall: 0.9762 - roc_auc: 0.9977 - tn: 221055.0000 - tp: 369.0000 - val_auc_prc: 0.7058 - val_f1: 0.0044 - val_fn: 5.0000 - val_fp: 928.0000 - val_loss: 0.0658 - val_precision: 0.0433 - val_recall: 0.8936 - val_roc_auc: 0.9593 - val_tn: 27398.0000 - val_tp: 42.0000
# Epoch 14/50
# 111/111 - 1s - 8ms/step - auc_prc: 0.6274 - f1: 0.0052 - fn: 4.0000 - fp: 5142.0000 - loss: 3.6122e-07 - precision: 0.0678 - recall: 0.9894 - roc_auc: 0.9987 - tn: 221460.0000 - tp: 374.0000 - val_auc_prc: 0.6449 - val_f1: 0.0061 - val_fn: 5.0000 - val_fp: 521.0000 - val_loss: 0.0463 - val_precision: 0.0746 - val_recall: 0.8936 - val_roc_auc: 0.9532 - val_tn: 27805.0000 - val_tp: 42.0000
# Epoch 15/50
# 111/111 - 1s - 8ms/step - auc_prc: 0.4767 - f1: 0.0056 - fn: 7.0000 - fp: 5975.0000 - loss: 4.9448e-07 - precision: 0.0585 - recall: 0.9815 - roc_auc: 0.9977 - tn: 220627.0000 - tp: 371.0000 - val_auc_prc: 0.5918 - val_f1: 0.0048 - val_fn: 5.0000 - val_fp: 1091.0000 - val_loss: 0.0809 - val_precision: 0.0371 - val_recall: 0.8936 - val_roc_auc: 0.9492 - val_tn: 27235.0000 - val_tp: 42.0000
# Epoch 16/50
# 111/111 - 1s - 11ms/step - auc_prc: 0.6415 - f1: 0.0056 - fn: 3.0000 - fp: 5973.0000 - loss: 4.0751e-07 - precision: 0.0591 - recall: 0.9921 - roc_auc: 0.9984 - tn: 220629.0000 - tp: 375.0000 - val_auc_prc: 0.7038 - val_f1: 0.0072 - val_fn: 5.0000 - val_fp: 277.0000 - val_loss: 0.0303 - val_precision: 0.1317 - val_recall: 0.8936 - val_roc_auc: 0.9439 - val_tn: 28049.0000 - val_tp: 42.0000
# Epoch 17/50
# 111/111 - 1s - 8ms/step - auc_prc: 0.3707 - f1: 0.0058 - fn: 6.0000 - fp: 6189.0000 - loss: 6.2336e-07 - precision: 0.0567 - recall: 0.9841 - roc_auc: 0.9974 - tn: 220413.0000 - tp: 372.0000 - val_auc_prc: 0.3082 - val_f1: 0.0058 - val_fn: 5.0000 - val_fp: 737.0000 - val_loss: 0.1684 - val_precision: 0.0539 - val_recall: 0.8936 - val_roc_auc: 0.9520 - val_tn: 27589.0000 - val_tp: 42.0000
# Epoch 18/50
# 111/111 - 1s - 8ms/step - auc_prc: 0.2677 - f1: 0.0050 - fn: 6.0000 - fp: 5865.0000 - loss: 8.8382e-07 - precision: 0.0596 - recall: 0.9841 - roc_auc: 0.9949 - tn: 220737.0000 - tp: 372.0000 - val_auc_prc: 0.4522 - val_f1: 0.0045 - val_fn: 5.0000 - val_fp: 803.0000 - val_loss: 0.1161 - val_precision: 0.0497 - val_recall: 0.8936 - val_roc_auc: 0.9405 - val_tn: 27523.0000 - val_tp: 42.0000
# Epoch 19/50
# 111/111 - 1s - 8ms/step - auc_prc: 0.2140 - f1: 0.0051 - fn: 6.0000 - fp: 7521.0000 - loss: 1.2971e-06 - precision: 0.0471 - recall: 0.9841 - roc_auc: 0.9941 - tn: 219081.0000 - tp: 372.0000 - val_auc_prc: 0.0813 - val_f1: 0.0048 - val_fn: 5.0000 - val_fp: 1513.0000 - val_loss: 0.3650 - val_precision: 0.0270 - val_recall: 0.8936 - val_roc_auc: 0.9333 - val_tn: 26813.0000 - val_tp: 42.0000
# Epoch 20/50
# 111/111 - 1s - 8ms/step - auc_prc: 0.2775 - f1: 0.0042 - fn: 15.0000 - fp: 7639.0000 - loss: 9.9108e-07 - precision: 0.0454 - recall: 0.9603 - roc_auc: 0.9937 - tn: 218963.0000 - tp: 363.0000 - val_auc_prc: 0.6730 - val_f1: 0.0035 - val_fn: 6.0000 - val_fp: 795.0000 - val_loss: 0.0805 - val_precision: 0.0490 - val_recall: 0.8723 - val_roc_auc: 0.9704 - val_tn: 27531.0000 - val_tp: 41.0000
# Epoch 21/50
# 111/111 - 1s - 8ms/step - auc_prc: 0.1360 - f1: 0.0040 - fn: 14.0000 - fp: 7869.0000 - loss: 4.0766e-06 - precision: 0.0442 - recall: 0.9630 - roc_auc: 0.9881 - tn: 218733.0000 - tp: 364.0000 - val_auc_prc: 0.4046 - val_f1: 0.0055 - val_fn: 5.0000 - val_fp: 657.0000 - val_loss: 0.8714 - val_precision: 0.0601 - val_recall: 0.8936 - val_roc_auc: 0.9406 - val_tn: 27669.0000 - val_tp: 42.0000
# Epoch 22/50
# 111/111 - 1s - 9ms/step - auc_prc: 0.2779 - f1: 0.0051 - fn: 16.0000 - fp: 6686.0000 - loss: 3.3857e-06 - precision: 0.0514 - recall: 0.9577 - roc_auc: 0.9909 - tn: 219916.0000 - tp: 362.0000 - val_auc_prc: 0.3792 - val_f1: 0.0039 - val_fn: 4.0000 - val_fp: 1007.0000 - val_loss: 0.3773 - val_precision: 0.0410 - val_recall: 0.9149 - val_roc_auc: 0.9789 - val_tn: 27319.0000 - val_tp: 43.0000
# Epoch 23/50
# 111/111 - 1s - 8ms/step - auc_prc: 0.2851 - f1: 0.0042 - fn: 10.0000 - fp: 6399.0000 - loss: 1.8893e-06 - precision: 0.0544 - recall: 0.9735 - roc_auc: 0.9911 - tn: 220203.0000 - tp: 368.0000 - val_auc_prc: 0.0916 - val_f1: 0.0034 - val_fn: 4.0000 - val_fp: 1547.0000 - val_loss: 0.5030 - val_precision: 0.0270 - val_recall: 0.9149 - val_roc_auc: 0.9745 - val_tn: 26779.0000 - val_tp: 43.0000
# Epoch 24/50
# 111/111 - 1s - 8ms/step - auc_prc: 0.1571 - f1: 0.0040 - fn: 17.0000 - fp: 7860.0000 - loss: 2.9844e-06 - precision: 0.0439 - recall: 0.9550 - roc_auc: 0.9885 - tn: 218742.0000 - tp: 361.0000 - val_auc_prc: 0.1311 - val_f1: 0.0052 - val_fn: 6.0000 - val_fp: 449.0000 - val_loss: 0.7915 - val_precision: 0.0837 - val_recall: 0.8723 - val_roc_auc: 0.9385 - val_tn: 27877.0000 - val_tp: 41.0000
# Epoch 25/50
# 111/111 - 1s - 8ms/step - auc_prc: 0.1953 - f1: 0.0052 - fn: 14.0000 - fp: 6723.0000 - loss: 1.0667e-05 - precision: 0.0514 - recall: 0.9630 - roc_auc: 0.9901 - tn: 219879.0000 - tp: 364.0000 - val_auc_prc: 0.3143 - val_f1: 0.0044 - val_fn: 4.0000 - val_fp: 473.0000 - val_loss: 1.2579 - val_precision: 0.0833 - val_recall: 0.9149 - val_roc_auc: 0.9694 - val_tn: 27853.0000 - val_tp: 43.0000
# Epoch 26/50
# 111/111 - 1s - 8ms/step - auc_prc: 0.4012 - f1: 0.0056 - fn: 9.0000 - fp: 3919.0000 - loss: 5.0418e-06 - precision: 0.0861 - recall: 0.9762 - roc_auc: 0.9963 - tn: 222683.0000 - tp: 369.0000 - val_auc_prc: 0.6307 - val_f1: 0.0055 - val_fn: 6.0000 - val_fp: 253.0000 - val_loss: 0.9158 - val_precision: 0.1395 - val_recall: 0.8723 - val_roc_auc: 0.9421 - val_tn: 28073.0000 - val_tp: 41.0000
# Epoch 27/50
# 111/111 - 1s - 9ms/step - auc_prc: 0.4494 - f1: 0.0066 - fn: 3.0000 - fp: 3110.0000 - loss: 2.8083e-06 - precision: 0.1076 - recall: 0.9921 - roc_auc: 0.9958 - tn: 223492.0000 - tp: 375.0000 - val_auc_prc: 0.2695 - val_f1: 0.0074 - val_fn: 5.0000 - val_fp: 632.0000 - val_loss: 0.5057 - val_precision: 0.0623 - val_recall: 0.8936 - val_roc_auc: 0.9410 - val_tn: 27694.0000 - val_tp: 42.0000
# Epoch 28/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.4068 - f1: 0.0074 - fn: 6.0000 - fp: 3410.0000 - loss: 2.6165e-06 - precision: 0.0984 - recall: 0.9841 - roc_auc: 0.9969 - tn: 223192.0000 - tp: 372.0000 - val_auc_prc: 0.6116 - val_f1: 0.0082 - val_fn: 5.0000 - val_fp: 323.0000 - val_loss: 0.1217 - val_precision: 0.1151 - val_recall: 0.8936 - val_roc_auc: 0.9544 - val_tn: 28003.0000 - val_tp: 42.0000
# Epoch 29/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.2326 - f1: 0.0072 - fn: 10.0000 - fp: 6537.0000 - loss: 3.7483e-06 - precision: 0.0533 - recall: 0.9735 - roc_auc: 0.9913 - tn: 220065.0000 - tp: 368.0000 - val_auc_prc: 0.4720 - val_f1: 0.0090 - val_fn: 6.0000 - val_fp: 801.0000 - val_loss: 0.3287 - val_precision: 0.0487 - val_recall: 0.8723 - val_roc_auc: 0.9415 - val_tn: 27525.0000 - val_tp: 41.0000
# Epoch 30/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.1866 - f1: 0.0081 - fn: 9.0000 - fp: 6114.0000 - loss: 4.1167e-06 - precision: 0.0569 - recall: 0.9762 - roc_auc: 0.9925 - tn: 220488.0000 - tp: 369.0000 - val_auc_prc: 0.3815 - val_f1: 0.0059 - val_fn: 5.0000 - val_fp: 349.0000 - val_loss: 0.6950 - val_precision: 0.1074 - val_recall: 0.8936 - val_roc_auc: 0.9617 - val_tn: 27977.0000 - val_tp: 42.0000
# Epoch 31/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.2612 - f1: 0.0062 - fn: 10.0000 - fp: 5295.0000 - loss: 2.4133e-06 - precision: 0.0650 - recall: 0.9735 - roc_auc: 0.9949 - tn: 221307.0000 - tp: 368.0000 - val_auc_prc: 0.5439 - val_f1: 0.0076 - val_fn: 6.0000 - val_fp: 344.0000 - val_loss: 0.3820 - val_precision: 0.1065 - val_recall: 0.8723 - val_roc_auc: 0.9423 - val_tn: 27982.0000 - val_tp: 41.0000
# Epoch 32/50
# 111/111 - 1s - 8ms/step - auc_prc: 0.2720 - f1: 0.0067 - fn: 7.0000 - fp: 4745.0000 - loss: 3.8191e-06 - precision: 0.0725 - recall: 0.9815 - roc_auc: 0.9939 - tn: 221857.0000 - tp: 371.0000 - val_auc_prc: 0.5101 - val_f1: 0.0071 - val_fn: 4.0000 - val_fp: 420.0000 - val_loss: 0.5145 - val_precision: 0.0929 - val_recall: 0.9149 - val_roc_auc: 0.9533 - val_tn: 27906.0000 - val_tp: 43.0000
# Epoch 33/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.4397 - f1: 0.0070 - fn: 6.0000 - fp: 5340.0000 - loss: 1.7606e-06 - precision: 0.0651 - recall: 0.9841 - roc_auc: 0.9967 - tn: 221262.0000 - tp: 372.0000 - val_auc_prc: 0.4978 - val_f1: 0.0091 - val_fn: 5.0000 - val_fp: 459.0000 - val_loss: 0.2118 - val_precision: 0.0838 - val_recall: 0.8936 - val_roc_auc: 0.9534 - val_tn: 27867.0000 - val_tp: 42.0000
# Epoch 34/50
# 111/111 - 1s - 8ms/step - auc_prc: 0.3995 - f1: 0.0091 - fn: 4.0000 - fp: 4948.0000 - loss: 2.6940e-06 - precision: 0.0703 - recall: 0.9894 - roc_auc: 0.9969 - tn: 221654.0000 - tp: 374.0000 - val_auc_prc: 0.5872 - val_f1: 0.0121 - val_fn: 5.0000 - val_fp: 426.0000 - val_loss: 0.2350 - val_precision: 0.0897 - val_recall: 0.8936 - val_roc_auc: 0.9436 - val_tn: 27900.0000 - val_tp: 42.0000
# Epoch 35/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.4967 - f1: 0.0108 - fn: 4.0000 - fp: 3409.0000 - loss: 7.6627e-07 - precision: 0.0989 - recall: 0.9894 - roc_auc: 0.9986 - tn: 223193.0000 - tp: 374.0000 - val_auc_prc: 0.2180 - val_f1: 0.0083 - val_fn: 5.0000 - val_fp: 966.0000 - val_loss: 0.1671 - val_precision: 0.0417 - val_recall: 0.8936 - val_roc_auc: 0.9397 - val_tn: 27360.0000 - val_tp: 42.0000
# Epoch 36/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.4200 - f1: 0.0091 - fn: 3.0000 - fp: 4153.0000 - loss: 7.6142e-07 - precision: 0.0828 - recall: 0.9921 - roc_auc: 0.9971 - tn: 222449.0000 - tp: 375.0000 - val_auc_prc: 0.6456 - val_f1: 0.0114 - val_fn: 5.0000 - val_fp: 288.0000 - val_loss: 0.0694 - val_precision: 0.1273 - val_recall: 0.8936 - val_roc_auc: 0.9440 - val_tn: 28038.0000 - val_tp: 42.0000
# Epoch 37/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.6373 - f1: 0.0120 - fn: 1.0000 - fp: 1738.0000 - loss: 3.6550e-07 - precision: 0.1783 - recall: 0.9974 - roc_auc: 0.9994 - tn: 224864.0000 - tp: 377.0000 - val_auc_prc: 0.5594 - val_f1: 0.0156 - val_fn: 5.0000 - val_fp: 170.0000 - val_loss: 0.0485 - val_precision: 0.1981 - val_recall: 0.8936 - val_roc_auc: 0.9448 - val_tn: 28156.0000 - val_tp: 42.0000
# Epoch 38/50
# 111/111 - 1s - 8ms/step - auc_prc: 0.5076 - f1: 0.0090 - fn: 2.0000 - fp: 2425.0000 - loss: 8.2586e-07 - precision: 0.1342 - recall: 0.9947 - roc_auc: 0.9977 - tn: 224177.0000 - tp: 376.0000 - val_auc_prc: 0.4989 - val_f1: 0.0123 - val_fn: 5.0000 - val_fp: 174.0000 - val_loss: 0.1114 - val_precision: 0.1944 - val_recall: 0.8936 - val_roc_auc: 0.9445 - val_tn: 28152.0000 - val_tp: 42.0000
# Epoch 39/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.4955 - f1: 0.0102 - fn: 2.0000 - fp: 2301.0000 - loss: 5.3366e-07 - precision: 0.1405 - recall: 0.9947 - roc_auc: 0.9990 - tn: 224301.0000 - tp: 376.0000 - val_auc_prc: 0.5465 - val_f1: 0.0122 - val_fn: 5.0000 - val_fp: 240.0000 - val_loss: 0.0473 - val_precision: 0.1489 - val_recall: 0.8936 - val_roc_auc: 0.9445 - val_tn: 28086.0000 - val_tp: 42.0000
# Epoch 40/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.5476 - f1: 0.0089 - fn: 2.0000 - fp: 2431.0000 - loss: 8.8151e-07 - precision: 0.1340 - recall: 0.9947 - roc_auc: 0.9990 - tn: 224171.0000 - tp: 376.0000 - val_auc_prc: 0.6474 - val_f1: 0.0105 - val_fn: 5.0000 - val_fp: 323.0000 - val_loss: 0.1417 - val_precision: 0.1151 - val_recall: 0.8936 - val_roc_auc: 0.9441 - val_tn: 28003.0000 - val_tp: 42.0000
# Epoch 41/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.6403 - f1: 0.0105 - fn: 1.0000 - fp: 2135.0000 - loss: 5.0738e-07 - precision: 0.1501 - recall: 0.9974 - roc_auc: 0.9994 - tn: 224467.0000 - tp: 377.0000 - val_auc_prc: 0.5723 - val_f1: 0.0133 - val_fn: 5.0000 - val_fp: 207.0000 - val_loss: 0.0786 - val_precision: 0.1687 - val_recall: 0.8936 - val_roc_auc: 0.9444 - val_tn: 28119.0000 - val_tp: 42.0000
# Epoch 42/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.6602 - f1: 0.0125 - fn: 3.0000 - fp: 1495.0000 - loss: 3.6092e-07 - precision: 0.2005 - recall: 0.9921 - roc_auc: 0.9995 - tn: 225107.0000 - tp: 375.0000 - val_auc_prc: 0.5168 - val_f1: 0.0138 - val_fn: 5.0000 - val_fp: 271.0000 - val_loss: 0.0698 - val_precision: 0.1342 - val_recall: 0.8936 - val_roc_auc: 0.9443 - val_tn: 28055.0000 - val_tp: 42.0000
# Epoch 43/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.6163 - f1: 0.0130 - fn: 1.0000 - fp: 1764.0000 - loss: 2.9909e-07 - precision: 0.1761 - recall: 0.9974 - roc_auc: 0.9994 - tn: 224838.0000 - tp: 377.0000 - val_auc_prc: 0.6256 - val_f1: 0.0166 - val_fn: 5.0000 - val_fp: 175.0000 - val_loss: 0.0516 - val_precision: 0.1935 - val_recall: 0.8936 - val_roc_auc: 0.9451 - val_tn: 28151.0000 - val_tp: 42.0000
# Epoch 44/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.7290 - f1: 0.0158 - fn: 0.0000e+00 - fp: 1037.0000 - loss: 1.9940e-07 - precision: 0.2671 - recall: 1.0000 - roc_auc: 0.9997 - tn: 225565.0000 - tp: 378.0000 - val_auc_prc: 0.6438 - val_f1: 0.0207 - val_fn: 6.0000 - val_fp: 79.0000 - val_loss: 0.0254 - val_precision: 0.3417 - val_recall: 0.8723 - val_roc_auc: 0.9456 - val_tn: 28247.0000 - val_tp: 41.0000
# Epoch 45/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.5579 - f1: 0.0157 - fn: 2.0000 - fp: 1697.0000 - loss: 2.4226e-07 - precision: 0.1814 - recall: 0.9947 - roc_auc: 0.9992 - tn: 224905.0000 - tp: 376.0000 - val_auc_prc: 0.4976 - val_f1: 0.0173 - val_fn: 5.0000 - val_fp: 279.0000 - val_loss: 0.0539 - val_precision: 0.1308 - val_recall: 0.8936 - val_roc_auc: 0.9446 - val_tn: 28047.0000 - val_tp: 42.0000
# Epoch 46/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.6271 - f1: 0.0155 - fn: 1.0000 - fp: 1426.0000 - loss: 2.7710e-07 - precision: 0.2091 - recall: 0.9974 - roc_auc: 0.9981 - tn: 225176.0000 - tp: 377.0000 - val_auc_prc: 0.6583 - val_f1: 0.0188 - val_fn: 5.0000 - val_fp: 118.0000 - val_loss: 0.0224 - val_precision: 0.2625 - val_recall: 0.8936 - val_roc_auc: 0.9454 - val_tn: 28208.0000 - val_tp: 42.0000
# Epoch 47/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.7004 - f1: 0.0183 - fn: 0.0000e+00 - fp: 991.0000 - loss: 1.3091e-07 - precision: 0.2761 - recall: 1.0000 - roc_auc: 0.9996 - tn: 225611.0000 - tp: 378.0000 - val_auc_prc: 0.6455 - val_f1: 0.0252 - val_fn: 6.0000 - val_fp: 70.0000 - val_loss: 0.0187 - val_precision: 0.3694 - val_recall: 0.8723 - val_roc_auc: 0.9459 - val_tn: 28256.0000 - val_tp: 41.0000
# Epoch 48/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.6415 - f1: 0.0207 - fn: 0.0000e+00 - fp: 844.0000 - loss: 1.3491e-07 - precision: 0.3093 - recall: 1.0000 - roc_auc: 0.9995 - tn: 225758.0000 - tp: 378.0000 - val_auc_prc: 0.6640 - val_f1: 0.0253 - val_fn: 6.0000 - val_fp: 75.0000 - val_loss: 0.0187 - val_precision: 0.3534 - val_recall: 0.8723 - val_roc_auc: 0.9459 - val_tn: 28251.0000 - val_tp: 41.0000
# Epoch 49/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.6450 - f1: 0.0220 - fn: 1.0000 - fp: 885.0000 - loss: 1.2530e-07 - precision: 0.2987 - recall: 0.9974 - roc_auc: 0.9995 - tn: 225717.0000 - tp: 377.0000 - val_auc_prc: 0.6065 - val_f1: 0.0262 - val_fn: 6.0000 - val_fp: 85.0000 - val_loss: 0.0192 - val_precision: 0.3254 - val_recall: 0.8723 - val_roc_auc: 0.9457 - val_tn: 28241.0000 - val_tp: 41.0000
# Epoch 50/50
# 111/111 - 1s - 7ms/step - auc_prc: 0.7170 - f1: 0.0244 - fn: 0.0000e+00 - fp: 676.0000 - loss: 1.0621e-07 - precision: 0.3586 - recall: 1.0000 - roc_auc: 0.9996 - tn: 225926.0000 - tp: 378.0000 - val_auc_prc: 0.6850 - val_f1: 0.0301 - val_fn: 6.0000 - val_fp: 56.0000 - val_loss: 0.0162 - val_precision: 0.4227 - val_recall: 0.8723 - val_roc_auc: 0.9355 - val_tn: 28270.0000 - val_tp: 41.0000

# %%
# getting best epoch 
metric_history = hist.history["val_auc_prc"]
best_epoch = metric_history.index(max(metric_history)) + 1
print("Best epoch: ", best_epoch, "Best Value: ", max(metric_history))
# or 
# metric_history = hist.history["val_loss"]
# best_epoch = metric_history.index(min(metric_history)) + 1
# print("Best epoch: ", best_epoch, "Best Value: ", max(metric_history))

# best_epoch=42
model.load_weights(f'./ckp/MLP_Normal_CC/k{current_k_fold}_epoch_{best_epoch}.keras')
# Out:
# Best epoch:  11 Best Value:  0.7319148182868958

# %% [markdown]
# # Self Paced Ensemble for MLP

# %%
# wrap Keras MLP into a scikit-learn API-compatible Wrapper class with `scikeras.KerasClassifier`
model2 = model

mlp = KerasClassifier(model2,
					  epochs=epochs, 
					  optimizer=Adam, 
					  batch_size=batch_size,
					  metrics=metrics,
					  loss="binary_crossentropy",
					  random_state=SEED,
                      verbose=0,
					  class_weight=class_weight
					  )
# Initialize Instance. Note: Do not run mlp.fit(). This would retrain the model.
mlp.initialize(X_train, y_train)

# create SelfPacedEnsembleClassifier
mlp_spe = SPE(
	estimator=mlp,
    verbose=0,
	n_estimators=50, # number of mlp's in ensemble (default: 50)
	random_state=SEED)

# Fit SPE-boosted MLP
mlp_spe.fit(
	X_train,
	y_train,
	eval_datasets={"valid": (X_val, y_val)},
	)

# path_to_spe_model = './saved_models/MLP/MLP_SPE_CC.pkl'

# # load model
# with open(path_to_spe_model, 'rb') as f:
#     mlp_spe = pickle.load(f)

print("results for fold: ", current_k_fold)
evaluate_model([model, mlp_spe], X_test, y_test, as_table=True)
# Out:
# results for fold:  3
#                     Model Name  AUCPRC      F1  G-Mean     MCC  Precision  \
# 0                   Sequential  0.8106  0.2275  0.9417  0.3395     0.1303
# 1  SelfPacedEnsembleClassifier  0.7994  0.0513  0.9296  0.1502     0.0264
#
#    Recall  ROCAUC  ACCURACY    TP      FP       TN   FN
# 0  0.8958  0.9630    0.9897  43.0   287.0  28038.0  5.0
# 1  0.9167  0.9632    0.9427  44.0  1623.0  26702.0  4.0
