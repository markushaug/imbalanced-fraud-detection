# %%
import pandas as pd
from pandas import DataFrame as df
from scipy.stats import ttest_ind, mannwhitneyu

fold1 = [{'tn': 28305.0, 'fp': 20.0, 'fn': 10.0, 'tp': 38.0, 'precision': 0.6552, 'recall': 0.7917, 'AUCPRC': 0.7809, 'F1': 0.717, 'ROCAUC': 0.9544, 'MCC': 0.7197, 'ACC': 0.9989, 'GMEAN': 0.8894, 'model_name': '10pct_mean'}, {'tn': 28303.0, 'fp': 22.0, 'fn': 10.0, 'tp': 38.0, 'precision': 0.6333, 'recall': 0.7917, 'AUCPRC': 0.7815, 'F1': 0.7037, 'ROCAUC': 0.951, 'MCC': 0.7075, 'ACC': 0.9989, 'GMEAN': 0.8894, 'model_name': '10pct_median'}, {'tn': 28304.0, 'fp': 21.0, 'fn': 10.0, 'tp': 38.0, 'precision': 0.6441, 'recall': 0.7917, 'AUCPRC': 0.7707, 'F1': 0.7103, 'ROCAUC': 0.9657, 'MCC': 0.7135, 'ACC': 0.9989, 'GMEAN': 0.8894, 'model_name': '10pct_iterative'}, {'tn': 28311.0, 'fp': 14.0, 'fn': 10.0, 'tp': 38.0, 'precision': 0.7308, 'recall': 0.7917, 'AUCPRC': 0.7263, 'F1': 0.76, 'ROCAUC': 0.9553, 'MCC': 0.7602, 'ACC': 0.9992, 'GMEAN': 0.8895, 'model_name': '20pct_mean'}, {'tn': 28309.0, 'fp': 16.0, 'fn': 10.0, 'tp': 38.0, 'precision': 0.7037, 'recall': 0.7917, 'AUCPRC': 0.7553, 'F1': 0.7451, 'ROCAUC': 0.9522, 'MCC': 0.7459, 'ACC': 0.9991, 'GMEAN': 0.8895, 'model_name': '20pct_median'}, {'tn': 28311.0, 'fp': 14.0, 'fn': 10.0, 'tp': 38.0, 'precision': 0.7308, 'recall': 0.7917, 'AUCPRC': 0.7277, 'F1': 0.76, 'ROCAUC': 0.9681, 'MCC': 0.7602, 'ACC': 0.9992, 'GMEAN': 0.8895, 'model_name': '20pct_iterative'}, {'tn': 28309.0, 'fp': 16.0, 'fn': 10.0, 'tp': 38.0, 'precision': 0.7037, 'recall': 0.7917, 'AUCPRC': 0.7113, 'F1': 0.7451, 'ROCAUC': 0.9705, 'MCC': 0.7459, 'ACC': 0.9991, 'GMEAN': 0.8895, 'model_name': '30pct_mean'}, {'tn': 28312.0, 'fp': 13.0, 'fn': 10.0, 'tp': 38.0, 'precision': 0.7451, 'recall': 0.7917, 'AUCPRC': 0.6218, 'F1': 0.7677, 'ROCAUC': 0.9686, 'MCC': 0.7676, 'ACC': 0.9992, 'GMEAN': 0.8896, 'model_name': '30pct_median'}, {'tn': 28311.0, 'fp': 14.0, 'fn': 10.0, 'tp': 38.0, 'precision': 0.7308, 'recall': 0.7917, 'AUCPRC': 0.678, 'F1': 0.76, 'ROCAUC': 0.9659, 'MCC': 0.7602, 'ACC': 0.9992, 'GMEAN': 0.8895, 'model_name': '30pct_iterative'}, {'tn': 28310.0, 'fp': 15.0, 'fn': 10.0, 'tp': 38.0, 'precision': 0.717, 'recall': 0.7917, 'AUCPRC': 0.6339, 'F1': 0.7525, 'ROCAUC': 0.961, 'MCC': 0.753, 'ACC': 0.9991, 'GMEAN': 0.8895, 'model_name': '50pct_mean'}, {'tn': 28312.0, 'fp': 13.0, 'fn': 10.0, 'tp': 38.0, 'precision': 0.7451, 'recall': 0.7917, 'AUCPRC': 0.6303, 'F1': 0.7677, 'ROCAUC': 0.9548, 'MCC': 0.7676, 'ACC': 0.9992, 'GMEAN': 0.8896, 'model_name': '50pct_median'}, {'tn': 28314.0, 'fp': 11.0, 'fn': 10.0, 'tp': 38.0, 'precision': 0.7755, 'recall': 0.7917, 'AUCPRC': 0.7461, 'F1': 0.7835, 'ROCAUC': 0.9588, 'MCC': 0.7832, 'ACC': 0.9993, 'GMEAN': 0.8896, 'model_name': '50pct_iterative'}]

fold2 = [{'tn': 28306.0, 'fp': 19.0, 'fn': 10.0, 'tp': 38.0, 'precision': 0.6667, 'recall': 0.7917, 'AUCPRC': 0.774, 'F1': 0.7238, 'ROCAUC': 0.9583, 'MCC': 0.726, 'ACC': 0.999, 'GMEAN': 0.8895, 'model_name': '10pct_mean'}, {'tn': 28301.0, 'fp': 24.0, 'fn': 10.0, 'tp': 38.0, 'precision': 0.6129, 'recall': 0.7917, 'AUCPRC': 0.7851, 'F1': 0.6909, 'ROCAUC': 0.957, 'MCC': 0.696, 'ACC': 0.9988, 'GMEAN': 0.8894, 'model_name': '10pct_median'}, {'tn': 28304.0, 'fp': 21.0, 'fn': 10.0, 'tp': 38.0, 'precision': 0.6441, 'recall': 0.7917, 'AUCPRC': 0.7678, 'F1': 0.7103, 'ROCAUC': 0.9571, 'MCC': 0.7135, 'ACC': 0.9989, 'GMEAN': 0.8894, 'model_name': '10pct_iterative'}, {'tn': 28313.0, 'fp': 12.0, 'fn': 10.0, 'tp': 38.0, 'precision': 0.76, 'recall': 0.7917, 'AUCPRC': 0.766, 'F1': 0.7755, 'ROCAUC': 0.9545, 'MCC': 0.7753, 'ACC': 0.9992, 'GMEAN': 0.8896, 'model_name': '20pct_mean'}, {'tn': 28314.0, 'fp': 11.0, 'fn': 10.0, 'tp': 38.0, 'precision': 0.7755, 'recall': 0.7917, 'AUCPRC': 0.7683, 'F1': 0.7835, 'ROCAUC': 0.9619, 'MCC': 0.7832, 'ACC': 0.9993, 'GMEAN': 0.8896, 'model_name': '20pct_median'}, {'tn': 28310.0, 'fp': 15.0, 'fn': 10.0, 'tp': 38.0, 'precision': 0.717, 'recall': 0.7917, 'AUCPRC': 0.7538, 'F1': 0.7525, 'ROCAUC': 0.9625, 'MCC': 0.753, 'ACC': 0.9991, 'GMEAN': 0.8895, 'model_name': '20pct_iterative'}, {'tn': 28317.0, 'fp': 8.0, 'fn': 11.0, 'tp': 37.0, 'precision': 0.8222, 'recall': 0.7708, 'AUCPRC': 0.682, 'F1': 0.7957, 'ROCAUC': 0.9622, 'MCC': 0.7958, 'ACC': 0.9993, 'GMEAN': 0.8778, 'model_name': '30pct_mean'}, {'tn': 28316.0, 'fp': 9.0, 'fn': 11.0, 'tp': 37.0, 'precision': 0.8043, 'recall': 0.7708, 'AUCPRC': 0.7105, 'F1': 0.7872, 'ROCAUC': 0.9533, 'MCC': 0.7871, 'ACC': 0.9993, 'GMEAN': 0.8778, 'model_name': '30pct_median'}, {'tn': 28315.0, 'fp': 10.0, 'fn': 11.0, 'tp': 37.0, 'precision': 0.7872, 'recall': 0.7708, 'AUCPRC': 0.7313, 'F1': 0.7789, 'ROCAUC': 0.96, 'MCC': 0.7786, 'ACC': 0.9993, 'GMEAN': 0.8778, 'model_name': '30pct_iterative'}, {'tn': 28317.0, 'fp': 8.0, 'fn': 10.0, 'tp': 38.0, 'precision': 0.8261, 'recall': 0.7917, 'AUCPRC': 0.7828, 'F1': 0.8085, 'ROCAUC': 0.9541, 'MCC': 0.8084, 'ACC': 0.9994, 'GMEAN': 0.8896, 'model_name': '50pct_mean'}, {'tn': 28318.0, 'fp': 7.0, 'fn': 11.0, 'tp': 37.0, 'precision': 0.8409, 'recall': 0.7708, 'AUCPRC': 0.7234, 'F1': 0.8043, 'ROCAUC': 0.9593, 'MCC': 0.8048, 'ACC': 0.9994, 'GMEAN': 0.8779, 'model_name': '50pct_median'}, {'tn': 28317.0, 'fp': 8.0, 'fn': 11.0, 'tp': 37.0, 'precision': 0.8222, 'recall': 0.7708, 'AUCPRC': 0.7289, 'F1': 0.7957, 'ROCAUC': 0.9546, 'MCC': 0.7958, 'ACC': 0.9993, 'GMEAN': 0.8778, 'model_name': '50pct_iterative'}]

fold3 = [{'tn': 28301.0, 'fp': 24.0, 'fn': 6.0, 'tp': 42.0, 'precision': 0.6364, 'recall': 0.875, 'AUCPRC': 0.857, 'F1': 0.7368, 'ROCAUC': 0.9634, 'MCC': 0.7457, 'ACC': 0.9989, 'GMEAN': 0.935, 'model_name': '10pct_mean'}, {'tn': 28299.0, 'fp': 26.0, 'fn': 6.0, 'tp': 42.0, 'precision': 0.6176, 'recall': 0.875, 'AUCPRC': 0.8601, 'F1': 0.7241, 'ROCAUC': 0.9564, 'MCC': 0.7346, 'ACC': 0.9989, 'GMEAN': 0.935, 'model_name': '10pct_median'}, {'tn': 28297.0, 'fp': 28.0, 'fn': 6.0, 'tp': 42.0, 'precision': 0.6, 'recall': 0.875, 'AUCPRC': 0.7392, 'F1': 0.7119, 'ROCAUC': 0.9562, 'MCC': 0.724, 'ACC': 0.9988, 'GMEAN': 0.935, 'model_name': '10pct_iterative'}, {'tn': 28307.0, 'fp': 18.0, 'fn': 6.0, 'tp': 42.0, 'precision': 0.7, 'recall': 0.875, 'AUCPRC': 0.8009, 'F1': 0.7778, 'ROCAUC': 0.9691, 'MCC': 0.7822, 'ACC': 0.9992, 'GMEAN': 0.9351, 'model_name': '20pct_mean'}, {'tn': 28307.0, 'fp': 18.0, 'fn': 6.0, 'tp': 42.0, 'precision': 0.7, 'recall': 0.875, 'AUCPRC': 0.8124, 'F1': 0.7778, 'ROCAUC': 0.9641, 'MCC': 0.7822, 'ACC': 0.9992, 'GMEAN': 0.9351, 'model_name': '20pct_median'}, {'tn': 28303.0, 'fp': 22.0, 'fn': 6.0, 'tp': 42.0, 'precision': 0.6562, 'recall': 0.875, 'AUCPRC': 0.7612, 'F1': 0.75, 'ROCAUC': 0.966, 'MCC': 0.7573, 'ACC': 0.999, 'GMEAN': 0.9351, 'model_name': '20pct_iterative'}, {'tn': 28312.0, 'fp': 13.0, 'fn': 6.0, 'tp': 42.0, 'precision': 0.7636, 'recall': 0.875, 'AUCPRC': 0.853, 'F1': 0.8155, 'ROCAUC': 0.9607, 'MCC': 0.8171, 'ACC': 0.9993, 'GMEAN': 0.9352, 'model_name': '30pct_mean'}, {'tn': 28310.0, 'fp': 15.0, 'fn': 6.0, 'tp': 42.0, 'precision': 0.7368, 'recall': 0.875, 'AUCPRC': 0.8519, 'F1': 0.8, 'ROCAUC': 0.9702, 'MCC': 0.8026, 'ACC': 0.9993, 'GMEAN': 0.9352, 'model_name': '30pct_median'}, {'tn': 28309.0, 'fp': 16.0, 'fn': 6.0, 'tp': 42.0, 'precision': 0.7241, 'recall': 0.875, 'AUCPRC': 0.8508, 'F1': 0.7925, 'ROCAUC': 0.9591, 'MCC': 0.7956, 'ACC': 0.9992, 'GMEAN': 0.9352, 'model_name': '30pct_iterative'}, {'tn': 28317.0, 'fp': 8.0, 'fn': 7.0, 'tp': 41.0, 'precision': 0.8367, 'recall': 0.8542, 'AUCPRC': 0.7656, 'F1': 0.8454, 'ROCAUC': 0.963, 'MCC': 0.8451, 'ACC': 0.9995, 'GMEAN': 0.9241, 'model_name': '50pct_mean'}, {'tn': 28318.0, 'fp': 7.0, 'fn': 6.0, 'tp': 42.0, 'precision': 0.8571, 'recall': 0.875, 'AUCPRC': 0.8444, 'F1': 0.866, 'ROCAUC': 0.9627, 'MCC': 0.8658, 'ACC': 0.9995, 'GMEAN': 0.9353, 'model_name': '50pct_median'}, {'tn': 28318.0, 'fp': 7.0, 'fn': 6.0, 'tp': 42.0, 'precision': 0.8571, 'recall': 0.875, 'AUCPRC': 0.7722, 'F1': 0.866, 'ROCAUC': 0.9573, 'MCC': 0.8658, 'ACC': 0.9995, 'GMEAN': 0.9353, 'model_name': '50pct_iterative'}]

fold4 = [{'tn': 28302.0, 'fp': 24.0, 'fn': 8.0, 'tp': 39.0, 'precision': 0.619, 'recall': 0.8298, 'AUCPRC': 0.7912, 'F1': 0.7091, 'ROCAUC': 0.971, 'MCC': 0.7162, 'ACC': 0.9989, 'GMEAN': 0.9105, 'model_name': '10pct_mean'}, {'tn': 28308.0, 'fp': 18.0, 'fn': 8.0, 'tp': 39.0, 'precision': 0.6842, 'recall': 0.8298, 'AUCPRC': 0.8158, 'F1': 0.75, 'ROCAUC': 0.9646, 'MCC': 0.753, 'ACC': 0.9991, 'GMEAN': 0.9106, 'model_name': '10pct_median'}, {'tn': 28308.0, 'fp': 18.0, 'fn': 8.0, 'tp': 39.0, 'precision': 0.6842, 'recall': 0.8298, 'AUCPRC': 0.8052, 'F1': 0.75, 'ROCAUC': 0.9647, 'MCC': 0.753, 'ACC': 0.9991, 'GMEAN': 0.9106, 'model_name': '10pct_iterative'}, {'tn': 28308.0, 'fp': 18.0, 'fn': 8.0, 'tp': 39.0, 'precision': 0.6842, 'recall': 0.8298, 'AUCPRC': 0.7019, 'F1': 0.75, 'ROCAUC': 0.9699, 'MCC': 0.753, 'ACC': 0.9991, 'GMEAN': 0.9106, 'model_name': '20pct_mean'}, {'tn': 28312.0, 'fp': 14.0, 'fn': 8.0, 'tp': 39.0, 'precision': 0.7358, 'recall': 0.8298, 'AUCPRC': 0.8066, 'F1': 0.78, 'ROCAUC': 0.9643, 'MCC': 0.781, 'ACC': 0.9992, 'GMEAN': 0.9107, 'model_name': '20pct_median'}, {'tn': 28312.0, 'fp': 14.0, 'fn': 8.0, 'tp': 39.0, 'precision': 0.7358, 'recall': 0.8298, 'AUCPRC': 0.7394, 'F1': 0.78, 'ROCAUC': 0.9724, 'MCC': 0.781, 'ACC': 0.9992, 'GMEAN': 0.9107, 'model_name': '20pct_iterative'}, {'tn': 28313.0, 'fp': 13.0, 'fn': 8.0, 'tp': 39.0, 'precision': 0.75, 'recall': 0.8298, 'AUCPRC': 0.7808, 'F1': 0.7879, 'ROCAUC': 0.9626, 'MCC': 0.7885, 'ACC': 0.9993, 'GMEAN': 0.9107, 'model_name': '30pct_mean'}, {'tn': 28316.0, 'fp': 10.0, 'fn': 8.0, 'tp': 39.0, 'precision': 0.7959, 'recall': 0.8298, 'AUCPRC': 0.7627, 'F1': 0.8125, 'ROCAUC': 0.9573, 'MCC': 0.8124, 'ACC': 0.9994, 'GMEAN': 0.9108, 'model_name': '30pct_median'}, {'tn': 28312.0, 'fp': 14.0, 'fn': 8.0, 'tp': 39.0, 'precision': 0.7358, 'recall': 0.8298, 'AUCPRC': 0.7113, 'F1': 0.78, 'ROCAUC': 0.9627, 'MCC': 0.781, 'ACC': 0.9992, 'GMEAN': 0.9107, 'model_name': '30pct_iterative'}, {'tn': 28316.0, 'fp': 10.0, 'fn': 8.0, 'tp': 39.0, 'precision': 0.7959, 'recall': 0.8298, 'AUCPRC': 0.79, 'F1': 0.8125, 'ROCAUC': 0.9404, 'MCC': 0.8124, 'ACC': 0.9994, 'GMEAN': 0.9108, 'model_name': '50pct_mean'}, {'tn': 28318.0, 'fp': 8.0, 'fn': 8.0, 'tp': 39.0, 'precision': 0.8298, 'recall': 0.8298, 'AUCPRC': 0.6644, 'F1': 0.8298, 'ROCAUC': 0.947, 'MCC': 0.8295, 'ACC': 0.9994, 'GMEAN': 0.9108, 'model_name': '50pct_median'}, {'tn': 28315.0, 'fp': 11.0, 'fn': 8.0, 'tp': 39.0, 'precision': 0.78, 'recall': 0.8298, 'AUCPRC': 0.699, 'F1': 0.8041, 'ROCAUC': 0.9432, 'MCC': 0.8042, 'ACC': 0.9993, 'GMEAN': 0.9107, 'model_name': '50pct_iterative'}]

fold5 = [{'tn': 28295.0, 'fp': 30.0, 'fn': 6.0, 'tp': 42.0, 'precision': 0.5833, 'recall': 0.875, 'AUCPRC': 0.5945, 'F1': 0.7, 'ROCAUC': 0.9935, 'MCC': 0.7139, 'ACC': 0.9987, 'GMEAN': 0.9349, 'model_name': '10pct_mean'}, {'tn': 28300.0, 'fp': 25.0, 'fn': 5.0, 'tp': 43.0, 'precision': 0.6324, 'recall': 0.8958, 'AUCPRC': 0.7813, 'F1': 0.7414, 'ROCAUC': 0.9973, 'MCC': 0.7522, 'ACC': 0.9989, 'GMEAN': 0.9461, 'model_name': '10pct_median'}, {'tn': 28296.0, 'fp': 29.0, 'fn': 6.0, 'tp': 42.0, 'precision': 0.5915, 'recall': 0.875, 'AUCPRC': 0.833, 'F1': 0.7059, 'ROCAUC': 0.9952, 'MCC': 0.7189, 'ACC': 0.9988, 'GMEAN': 0.9349, 'model_name': '10pct_iterative'}, {'tn': 28297.0, 'fp': 28.0, 'fn': 6.0, 'tp': 42.0, 'precision': 0.6, 'recall': 0.875, 'AUCPRC': 0.7422, 'F1': 0.7119, 'ROCAUC': 0.9965, 'MCC': 0.724, 'ACC': 0.9988, 'GMEAN': 0.935, 'model_name': '20pct_mean'}, {'tn': 28299.0, 'fp': 26.0, 'fn': 6.0, 'tp': 42.0, 'precision': 0.6176, 'recall': 0.875, 'AUCPRC': 0.7416, 'F1': 0.7241, 'ROCAUC': 0.9959, 'MCC': 0.7346, 'ACC': 0.9989, 'GMEAN': 0.935, 'model_name': '20pct_median'}, {'tn': 28295.0, 'fp': 30.0, 'fn': 6.0, 'tp': 42.0, 'precision': 0.5833, 'recall': 0.875, 'AUCPRC': 0.836, 'F1': 0.7, 'ROCAUC': 0.9965, 'MCC': 0.7139, 'ACC': 0.9987, 'GMEAN': 0.9349, 'model_name': '20pct_iterative'}, {'tn': 28294.0, 'fp': 31.0, 'fn': 6.0, 'tp': 42.0, 'precision': 0.5753, 'recall': 0.875, 'AUCPRC': 0.5995, 'F1': 0.6942, 'ROCAUC': 0.9948, 'MCC': 0.7089, 'ACC': 0.9987, 'GMEAN': 0.9349, 'model_name': '30pct_mean'}, {'tn': 28298.0, 'fp': 27.0, 'fn': 6.0, 'tp': 42.0, 'precision': 0.6087, 'recall': 0.875, 'AUCPRC': 0.7126, 'F1': 0.7179, 'ROCAUC': 0.9917, 'MCC': 0.7293, 'ACC': 0.9988, 'GMEAN': 0.935, 'model_name': '30pct_median'}, {'tn': 28297.0, 'fp': 28.0, 'fn': 6.0, 'tp': 42.0, 'precision': 0.6, 'recall': 0.875, 'AUCPRC': 0.7441, 'F1': 0.7119, 'ROCAUC': 0.9927, 'MCC': 0.724, 'ACC': 0.9988, 'GMEAN': 0.935, 'model_name': '30pct_iterative'}, {'tn': 28302.0, 'fp': 23.0, 'fn': 6.0, 'tp': 42.0, 'precision': 0.6462, 'recall': 0.875, 'AUCPRC': 0.6718, 'F1': 0.7434, 'ROCAUC': 0.9947, 'MCC': 0.7514, 'ACC': 0.999, 'GMEAN': 0.935, 'model_name': '50pct_mean'}, {'tn': 28302.0, 'fp': 23.0, 'fn': 6.0, 'tp': 42.0, 'precision': 0.6462, 'recall': 0.875, 'AUCPRC': 0.5904, 'F1': 0.7434, 'ROCAUC': 0.9959, 'MCC': 0.7514, 'ACC': 0.999, 'GMEAN': 0.935, 'model_name': '50pct_median'}, {'tn': 28302.0, 'fp': 23.0, 'fn': 6.0, 'tp': 42.0, 'precision': 0.6462, 'recall': 0.875, 'AUCPRC': 0.597, 'F1': 0.7434, 'ROCAUC': 0.9946, 'MCC': 0.7514, 'ACC': 0.999, 'GMEAN': 0.935, 'model_name': '50pct_iterative'}]

fold6 = [{'tn': 28307.0, 'fp': 19.0, 'fn': 9.0, 'tp': 38.0, 'precision': 0.6667, 'recall': 0.8085, 'AUCPRC': 0.743, 'F1': 0.7308, 'ROCAUC': 0.9591, 'MCC': 0.7337, 'ACC': 0.999, 'GMEAN': 0.8989, 'model_name': '10pct_mean'}, {'tn': 28308.0, 'fp': 18.0, 'fn': 9.0, 'tp': 38.0, 'precision': 0.6786, 'recall': 0.8085, 'AUCPRC': 0.7415, 'F1': 0.7379, 'ROCAUC': 0.9735, 'MCC': 0.7402, 'ACC': 0.999, 'GMEAN': 0.8989, 'model_name': '10pct_median'}, {'tn': 28310.0, 'fp': 16.0, 'fn': 9.0, 'tp': 38.0, 'precision': 0.7037, 'recall': 0.8085, 'AUCPRC': 0.7388, 'F1': 0.7525, 'ROCAUC': 0.9763, 'MCC': 0.7539, 'ACC': 0.9991, 'GMEAN': 0.8989, 'model_name': '10pct_iterative'}, {'tn': 28304.0, 'fp': 22.0, 'fn': 9.0, 'tp': 38.0, 'precision': 0.6333, 'recall': 0.8085, 'AUCPRC': 0.5677, 'F1': 0.7103, 'ROCAUC': 0.9693, 'MCC': 0.7151, 'ACC': 0.9989, 'GMEAN': 0.8988, 'model_name': '20pct_mean'}, {'tn': 28302.0, 'fp': 24.0, 'fn': 9.0, 'tp': 38.0, 'precision': 0.6129, 'recall': 0.8085, 'AUCPRC': 0.6233, 'F1': 0.6972, 'ROCAUC': 0.9711, 'MCC': 0.7034, 'ACC': 0.9988, 'GMEAN': 0.8988, 'model_name': '20pct_median'}, {'tn': 28304.0, 'fp': 22.0, 'fn': 9.0, 'tp': 38.0, 'precision': 0.6333, 'recall': 0.8085, 'AUCPRC': 0.7653, 'F1': 0.7103, 'ROCAUC': 0.9657, 'MCC': 0.7151, 'ACC': 0.9989, 'GMEAN': 0.8988, 'model_name': '20pct_iterative'}, {'tn': 28312.0, 'fp': 14.0, 'fn': 9.0, 'tp': 38.0, 'precision': 0.7308, 'recall': 0.8085, 'AUCPRC': 0.7816, 'F1': 0.7677, 'ROCAUC': 0.9616, 'MCC': 0.7683, 'ACC': 0.9992, 'GMEAN': 0.8989, 'model_name': '30pct_mean'}, {'tn': 28314.0, 'fp': 12.0, 'fn': 9.0, 'tp': 38.0, 'precision': 0.76, 'recall': 0.8085, 'AUCPRC': 0.5678, 'F1': 0.7835, 'ROCAUC': 0.964, 'MCC': 0.7835, 'ACC': 0.9993, 'GMEAN': 0.899, 'model_name': '30pct_median'}, {'tn': 28312.0, 'fp': 14.0, 'fn': 8.0, 'tp': 39.0, 'precision': 0.7358, 'recall': 0.8298, 'AUCPRC': 0.5705, 'F1': 0.78, 'ROCAUC': 0.9631, 'MCC': 0.781, 'ACC': 0.9992, 'GMEAN': 0.9107, 'model_name': '30pct_iterative'}, {'tn': 28312.0, 'fp': 14.0, 'fn': 9.0, 'tp': 38.0, 'precision': 0.7308, 'recall': 0.8085, 'AUCPRC': 0.6886, 'F1': 0.7677, 'ROCAUC': 0.9632, 'MCC': 0.7683, 'ACC': 0.9992, 'GMEAN': 0.8989, 'model_name': '50pct_mean'}, {'tn': 28311.0, 'fp': 15.0, 'fn': 9.0, 'tp': 38.0, 'precision': 0.717, 'recall': 0.8085, 'AUCPRC': 0.7509, 'F1': 0.76, 'ROCAUC': 0.9569, 'MCC': 0.761, 'ACC': 0.9992, 'GMEAN': 0.8989, 'model_name': '50pct_median'}, {'tn': 28313.0, 'fp': 13.0, 'fn': 9.0, 'tp': 38.0, 'precision': 0.7451, 'recall': 0.8085, 'AUCPRC': 0.7206, 'F1': 0.7755, 'ROCAUC': 0.9567, 'MCC': 0.7758, 'ACC': 0.9992, 'GMEAN': 0.899, 'model_name': '50pct_iterative'}]

fold7 = [{'tn': 28294.0, 'fp': 31.0, 'fn': 2.0, 'tp': 46.0, 'precision': 0.5974, 'recall': 0.9583, 'AUCPRC': 0.7968, 'F1': 0.736, 'ROCAUC': 0.9995, 'MCC': 0.7562, 'ACC': 0.9988, 'GMEAN': 0.9784, 'model_name': '10pct_mean'}, {'tn': 28292.0, 'fp': 33.0, 'fn': 3.0, 'tp': 45.0, 'precision': 0.5769, 'recall': 0.9375, 'AUCPRC': 0.8542, 'F1': 0.7143, 'ROCAUC': 0.9996, 'MCC': 0.7349, 'ACC': 0.9987, 'GMEAN': 0.9677, 'model_name': '10pct_median'}, {'tn': 28291.0, 'fp': 34.0, 'fn': 3.0, 'tp': 45.0, 'precision': 0.5696, 'recall': 0.9375, 'AUCPRC': 0.9019, 'F1': 0.7087, 'ROCAUC': 0.9995, 'MCC': 0.7302, 'ACC': 0.9987, 'GMEAN': 0.9677, 'model_name': '10pct_iterative'}, {'tn': 28302.0, 'fp': 23.0, 'fn': 3.0, 'tp': 45.0, 'precision': 0.6618, 'recall': 0.9375, 'AUCPRC': 0.705, 'F1': 0.7759, 'ROCAUC': 0.999, 'MCC': 0.7873, 'ACC': 0.9991, 'GMEAN': 0.9679, 'model_name': '20pct_mean'}, {'tn': 28306.0, 'fp': 19.0, 'fn': 3.0, 'tp': 45.0, 'precision': 0.7031, 'recall': 0.9375, 'AUCPRC': 0.7314, 'F1': 0.8036, 'ROCAUC': 0.9988, 'MCC': 0.8115, 'ACC': 0.9992, 'GMEAN': 0.9679, 'model_name': '20pct_median'}, {'tn': 28305.0, 'fp': 20.0, 'fn': 3.0, 'tp': 45.0, 'precision': 0.6923, 'recall': 0.9375, 'AUCPRC': 0.7426, 'F1': 0.7965, 'ROCAUC': 0.9992, 'MCC': 0.8053, 'ACC': 0.9992, 'GMEAN': 0.9679, 'model_name': '20pct_iterative'}, {'tn': 28312.0, 'fp': 13.0, 'fn': 3.0, 'tp': 45.0, 'precision': 0.7759, 'recall': 0.9375, 'AUCPRC': 0.662, 'F1': 0.8491, 'ROCAUC': 0.9934, 'MCC': 0.8526, 'ACC': 0.9994, 'GMEAN': 0.968, 'model_name': '30pct_mean'}, {'tn': 28312.0, 'fp': 13.0, 'fn': 3.0, 'tp': 45.0, 'precision': 0.7759, 'recall': 0.9375, 'AUCPRC': 0.7066, 'F1': 0.8491, 'ROCAUC': 0.9927, 'MCC': 0.8526, 'ACC': 0.9994, 'GMEAN': 0.968, 'model_name': '30pct_median'}, {'tn': 28309.0, 'fp': 16.0, 'fn': 3.0, 'tp': 45.0, 'precision': 0.7377, 'recall': 0.9375, 'AUCPRC': 0.7042, 'F1': 0.8257, 'ROCAUC': 0.9957, 'MCC': 0.8313, 'ACC': 0.9993, 'GMEAN': 0.968, 'model_name': '30pct_iterative'}, {'tn': 28311.0, 'fp': 14.0, 'fn': 3.0, 'tp': 45.0, 'precision': 0.7627, 'recall': 0.9375, 'AUCPRC': 0.6607, 'F1': 0.8411, 'ROCAUC': 0.992, 'MCC': 0.8453, 'ACC': 0.9994, 'GMEAN': 0.968, 'model_name': '50pct_mean'}, {'tn': 28310.0, 'fp': 15.0, 'fn': 3.0, 'tp': 45.0, 'precision': 0.75, 'recall': 0.9375, 'AUCPRC': 0.7467, 'F1': 0.8333, 'ROCAUC': 0.981, 'MCC': 0.8382, 'ACC': 0.9994, 'GMEAN': 0.968, 'model_name': '50pct_median'}, {'tn': 28308.0, 'fp': 17.0, 'fn': 3.0, 'tp': 45.0, 'precision': 0.7258, 'recall': 0.9375, 'AUCPRC': 0.6777, 'F1': 0.8182, 'ROCAUC': 0.9959, 'MCC': 0.8246, 'ACC': 0.9993, 'GMEAN': 0.968, 'model_name': '50pct_iterative'}]

fold8 = [{'tn': 28305.0, 'fp': 20.0, 'fn': 4.0, 'tp': 44.0, 'precision': 0.6875, 'recall': 0.9167, 'AUCPRC': 0.8093, 'F1': 0.7857, 'ROCAUC': 0.9844, 'MCC': 0.7935, 'ACC': 0.9992, 'GMEAN': 0.9571, 'model_name': '10pct_mean'}, {'tn': 28306.0, 'fp': 19.0, 'fn': 4.0, 'tp': 44.0, 'precision': 0.6984, 'recall': 0.9167, 'AUCPRC': 0.8261, 'F1': 0.7928, 'ROCAUC': 0.9807, 'MCC': 0.7998, 'ACC': 0.9992, 'GMEAN': 0.9571, 'model_name': '10pct_median'}, {'tn': 28308.0, 'fp': 17.0, 'fn': 4.0, 'tp': 44.0, 'precision': 0.7213, 'recall': 0.9167, 'AUCPRC': 0.9042, 'F1': 0.8073, 'ROCAUC': 0.9846, 'MCC': 0.8128, 'ACC': 0.9993, 'GMEAN': 0.9571, 'model_name': '10pct_iterative'}, {'tn': 28305.0, 'fp': 20.0, 'fn': 3.0, 'tp': 45.0, 'precision': 0.6923, 'recall': 0.9375, 'AUCPRC': 0.8858, 'F1': 0.7965, 'ROCAUC': 0.9732, 'MCC': 0.8053, 'ACC': 0.9992, 'GMEAN': 0.9679, 'model_name': '20pct_mean'}, {'tn': 28300.0, 'fp': 25.0, 'fn': 4.0, 'tp': 44.0, 'precision': 0.6377, 'recall': 0.9167, 'AUCPRC': 0.7621, 'F1': 0.7521, 'ROCAUC': 0.965, 'MCC': 0.7641, 'ACC': 0.999, 'GMEAN': 0.957, 'model_name': '20pct_median'}, {'tn': 28297.0, 'fp': 28.0, 'fn': 3.0, 'tp': 45.0, 'precision': 0.6164, 'recall': 0.9375, 'AUCPRC': 0.9035, 'F1': 0.7438, 'ROCAUC': 0.9678, 'MCC': 0.7597, 'ACC': 0.9989, 'GMEAN': 0.9678, 'model_name': '20pct_iterative'}, {'tn': 28311.0, 'fp': 14.0, 'fn': 4.0, 'tp': 44.0, 'precision': 0.7586, 'recall': 0.9167, 'AUCPRC': 0.9069, 'F1': 0.8302, 'ROCAUC': 0.969, 'MCC': 0.8336, 'ACC': 0.9994, 'GMEAN': 0.9572, 'model_name': '30pct_mean'}, {'tn': 28310.0, 'fp': 15.0, 'fn': 4.0, 'tp': 44.0, 'precision': 0.7458, 'recall': 0.9167, 'AUCPRC': 0.8105, 'F1': 0.8224, 'ROCAUC': 0.9743, 'MCC': 0.8265, 'ACC': 0.9993, 'GMEAN': 0.9572, 'model_name': '30pct_median'}, {'tn': 28314.0, 'fp': 11.0, 'fn': 4.0, 'tp': 44.0, 'precision': 0.8, 'recall': 0.9167, 'AUCPRC': 0.7942, 'F1': 0.8544, 'ROCAUC': 0.9723, 'MCC': 0.8561, 'ACC': 0.9995, 'GMEAN': 0.9572, 'model_name': '30pct_iterative'}, {'tn': 28311.0, 'fp': 14.0, 'fn': 4.0, 'tp': 44.0, 'precision': 0.7586, 'recall': 0.9167, 'AUCPRC': 0.8274, 'F1': 0.8302, 'ROCAUC': 0.9796, 'MCC': 0.8336, 'ACC': 0.9994, 'GMEAN': 0.9572, 'model_name': '50pct_mean'}, {'tn': 28310.0, 'fp': 15.0, 'fn': 4.0, 'tp': 44.0, 'precision': 0.7458, 'recall': 0.9167, 'AUCPRC': 0.8399, 'F1': 0.8224, 'ROCAUC': 0.9763, 'MCC': 0.8265, 'ACC': 0.9993, 'GMEAN': 0.9572, 'model_name': '50pct_median'}, {'tn': 28313.0, 'fp': 12.0, 'fn': 4.0, 'tp': 44.0, 'precision': 0.7857, 'recall': 0.9167, 'AUCPRC': 0.8366, 'F1': 0.8462, 'ROCAUC': 0.9714, 'MCC': 0.8484, 'ACC': 0.9994, 'GMEAN': 0.9572, 'model_name': '50pct_iterative'}]

fold9 = [{'tn': 28307.0, 'fp': 18.0, 'fn': 11.0, 'tp': 37.0, 'precision': 0.6727, 'recall': 0.7708, 'AUCPRC': 0.7592, 'F1': 0.7184, 'ROCAUC': 0.952, 'MCC': 0.7196, 'ACC': 0.999, 'GMEAN': 0.8777, 'model_name': '10pct_mean'}, {'tn': 28306.0, 'fp': 19.0, 'fn': 11.0, 'tp': 37.0, 'precision': 0.6607, 'recall': 0.7708, 'AUCPRC': 0.7594, 'F1': 0.7115, 'ROCAUC': 0.9619, 'MCC': 0.7131, 'ACC': 0.9989, 'GMEAN': 0.8777, 'model_name': '10pct_median'}, {'tn': 28309.0, 'fp': 16.0, 'fn': 11.0, 'tp': 37.0, 'precision': 0.6981, 'recall': 0.7708, 'AUCPRC': 0.7656, 'F1': 0.7327, 'ROCAUC': 0.9645, 'MCC': 0.7331, 'ACC': 0.999, 'GMEAN': 0.8777, 'model_name': '10pct_iterative'}, {'tn': 28315.0, 'fp': 10.0, 'fn': 12.0, 'tp': 36.0, 'precision': 0.7826, 'recall': 0.75, 'AUCPRC': 0.7666, 'F1': 0.766, 'ROCAUC': 0.9658, 'MCC': 0.7657, 'ACC': 0.9992, 'GMEAN': 0.8659, 'model_name': '20pct_mean'}, {'tn': 28311.0, 'fp': 14.0, 'fn': 11.0, 'tp': 37.0, 'precision': 0.7255, 'recall': 0.7708, 'AUCPRC': 0.7624, 'F1': 0.7475, 'ROCAUC': 0.9576, 'MCC': 0.7474, 'ACC': 0.9991, 'GMEAN': 0.8778, 'model_name': '20pct_median'}, {'tn': 28312.0, 'fp': 13.0, 'fn': 11.0, 'tp': 37.0, 'precision': 0.74, 'recall': 0.7708, 'AUCPRC': 0.7411, 'F1': 0.7551, 'ROCAUC': 0.9743, 'MCC': 0.7548, 'ACC': 0.9992, 'GMEAN': 0.8778, 'model_name': '20pct_iterative'}, {'tn': 28316.0, 'fp': 9.0, 'fn': 11.0, 'tp': 37.0, 'precision': 0.8043, 'recall': 0.7708, 'AUCPRC': 0.6748, 'F1': 0.7872, 'ROCAUC': 0.9632, 'MCC': 0.7871, 'ACC': 0.9993, 'GMEAN': 0.8778, 'model_name': '30pct_mean'}, {'tn': 28315.0, 'fp': 10.0, 'fn': 11.0, 'tp': 37.0, 'precision': 0.7872, 'recall': 0.7708, 'AUCPRC': 0.762, 'F1': 0.7789, 'ROCAUC': 0.9483, 'MCC': 0.7786, 'ACC': 0.9993, 'GMEAN': 0.8778, 'model_name': '30pct_median'}, {'tn': 28315.0, 'fp': 10.0, 'fn': 11.0, 'tp': 37.0, 'precision': 0.7872, 'recall': 0.7708, 'AUCPRC': 0.6596, 'F1': 0.7789, 'ROCAUC': 0.9602, 'MCC': 0.7786, 'ACC': 0.9993, 'GMEAN': 0.8778, 'model_name': '30pct_iterative'}, {'tn': 28317.0, 'fp': 8.0, 'fn': 12.0, 'tp': 36.0, 'precision': 0.8182, 'recall': 0.75, 'AUCPRC': 0.6505, 'F1': 0.7826, 'ROCAUC': 0.9532, 'MCC': 0.783, 'ACC': 0.9993, 'GMEAN': 0.8659, 'model_name': '50pct_mean'}, {'tn': 28317.0, 'fp': 8.0, 'fn': 12.0, 'tp': 36.0, 'precision': 0.8182, 'recall': 0.75, 'AUCPRC': 0.6876, 'F1': 0.7826, 'ROCAUC': 0.9599, 'MCC': 0.783, 'ACC': 0.9993, 'GMEAN': 0.8659, 'model_name': '50pct_median'}, {'tn': 28318.0, 'fp': 7.0, 'fn': 12.0, 'tp': 36.0, 'precision': 0.8372, 'recall': 0.75, 'AUCPRC': 0.6703, 'F1': 0.7912, 'ROCAUC': 0.9408, 'MCC': 0.7921, 'ACC': 0.9993, 'GMEAN': 0.8659, 'model_name': '50pct_iterative'}]

fold10 = [{'tn': 28297.0, 'fp': 29.0, 'fn': 3.0, 'tp': 44.0, 'precision': 0.6027, 'recall': 0.9362, 'AUCPRC': 0.9107, 'F1': 0.7333, 'ROCAUC': 0.9891, 'MCC': 0.7507, 'ACC': 0.9989, 'GMEAN': 0.9671, 'model_name': '10pct_mean'}, {'tn': 28296.0, 'fp': 30.0, 'fn': 3.0, 'tp': 44.0, 'precision': 0.5946, 'recall': 0.9362, 'AUCPRC': 0.919, 'F1': 0.7273, 'ROCAUC': 0.9916, 'MCC': 0.7456, 'ACC': 0.9988, 'GMEAN': 0.967, 'model_name': '10pct_median'}, {'tn': 28299.0, 'fp': 27.0, 'fn': 3.0, 'tp': 44.0, 'precision': 0.6197, 'recall': 0.9362, 'AUCPRC': 0.9103, 'F1': 0.7458, 'ROCAUC': 0.9923, 'MCC': 0.7612, 'ACC': 0.9989, 'GMEAN': 0.9671, 'model_name': '10pct_iterative'}, {'tn': 28310.0, 'fp': 16.0, 'fn': 3.0, 'tp': 44.0, 'precision': 0.7333, 'recall': 0.9362, 'AUCPRC': 0.9176, 'F1': 0.8224, 'ROCAUC': 0.9906, 'MCC': 0.8283, 'ACC': 0.9993, 'GMEAN': 0.9673, 'model_name': '20pct_mean'}, {'tn': 28315.0, 'fp': 11.0, 'fn': 3.0, 'tp': 44.0, 'precision': 0.8, 'recall': 0.9362, 'AUCPRC': 0.9059, 'F1': 0.8627, 'ROCAUC': 0.99, 'MCC': 0.8652, 'ACC': 0.9995, 'GMEAN': 0.9674, 'model_name': '20pct_median'}, {'tn': 28312.0, 'fp': 14.0, 'fn': 3.0, 'tp': 44.0, 'precision': 0.7586, 'recall': 0.9362, 'AUCPRC': 0.9119, 'F1': 0.8381, 'ROCAUC': 0.9931, 'MCC': 0.8425, 'ACC': 0.9994, 'GMEAN': 0.9673, 'model_name': '20pct_iterative'}, {'tn': 28314.0, 'fp': 12.0, 'fn': 3.0, 'tp': 44.0, 'precision': 0.7857, 'recall': 0.9362, 'AUCPRC': 0.9073, 'F1': 0.8544, 'ROCAUC': 0.9861, 'MCC': 0.8574, 'ACC': 0.9995, 'GMEAN': 0.9674, 'model_name': '30pct_mean'}, {'tn': 28312.0, 'fp': 14.0, 'fn': 3.0, 'tp': 44.0, 'precision': 0.7586, 'recall': 0.9362, 'AUCPRC': 0.8719, 'F1': 0.8381, 'ROCAUC': 0.9803, 'MCC': 0.8425, 'ACC': 0.9994, 'GMEAN': 0.9673, 'model_name': '30pct_median'}, {'tn': 28314.0, 'fp': 12.0, 'fn': 3.0, 'tp': 44.0, 'precision': 0.7857, 'recall': 0.9362, 'AUCPRC': 0.8777, 'F1': 0.8544, 'ROCAUC': 0.9854, 'MCC': 0.8574, 'ACC': 0.9995, 'GMEAN': 0.9674, 'model_name': '30pct_iterative'}, {'tn': 28319.0, 'fp': 7.0, 'fn': 4.0, 'tp': 43.0, 'precision': 0.86, 'recall': 0.9149, 'AUCPRC': 0.8623, 'F1': 0.8866, 'ROCAUC': 0.9879, 'MCC': 0.8868, 'ACC': 0.9996, 'GMEAN': 0.9564, 'model_name': '50pct_mean'}, {'tn': 28319.0, 'fp': 7.0, 'fn': 4.0, 'tp': 43.0, 'precision': 0.86, 'recall': 0.9149, 'AUCPRC': 0.838, 'F1': 0.8866, 'ROCAUC': 0.9943, 'MCC': 0.8868, 'ACC': 0.9996, 'GMEAN': 0.9564, 'model_name': '50pct_median'}, {'tn': 28319.0, 'fp': 7.0, 'fn': 3.0, 'tp': 44.0, 'precision': 0.8627, 'recall': 0.9362, 'AUCPRC': 0.8618, 'F1': 0.898, 'ROCAUC': 0.9941, 'MCC': 0.8985, 'ACC': 0.9996, 'GMEAN': 0.9674, 'model_name': '50pct_iterative'}]

# %% [markdown]
# # Evaluate the folds

# %%
kfold_results = df(columns=['tn', 'fp', 'fn', 'tp', 'precision', 'recall', 'AUCPRC', 'F1', 'ROCAUC',
       'MCC', 'ACC', 'GMEAN', 'model_name'])

for fold in [fold1, fold2, fold3, fold4, fold5, fold6, fold7, fold8, fold9, fold10]:
	kfold_results = pd.concat([kfold_results, df(fold)])

kfold_results = kfold_results.drop(['tn', 'fp', 'fn', 'tp', 'ROCAUC', 'ACC'], axis=1)

grouped_df = kfold_results.groupby("model_name")

result = grouped_df.agg(lambda x: f"{x.mean():.4f} ± {x.std():.4f}")

result
# Out:
# /var/folders/b5/y93p_qw91z98pk044cfd6b800000gn/T/ipykernel_88851/2264849202.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   kfold_results = pd.concat([kfold_results, df(fold)])
#                        precision           recall           AUCPRC  \
# model_name
# 10pct_iterative  0.6476 ± 0.0525  0.8533 ± 0.0631  0.8137 ± 0.0693
# 10pct_mean       0.6388 ± 0.0363  0.8554 ± 0.0665  0.7817 ± 0.0820
# 10pct_median     0.6390 ± 0.0404  0.8554 ± 0.0643  0.8124 ± 0.0538
# 20pct_iterative  0.6864 ± 0.0603  0.8554 ± 0.0657  0.7883 ± 0.0696
# 20pct_mean       0.6978 ± 0.0564  0.8533 ± 0.0690  0.7580 ± 0.0984
# 20pct_median     0.7012 ± 0.0632  0.8533 ± 0.0631  0.7669 ± 0.0712
# ...

# %% [markdown]
# # T-Test & Mann-Whitney U Test

# %%
# Drop the specified columns
ttest_data = df(columns=[ 'model_name', 'tn', 'fp', 'fn', 'tp', 'precision', 'recall', 'AUCPRC', 'F1', 'ROCAUC',
       'MCC', 'ACC', 'GMEAN',])

for fold in [fold1, fold2, fold3, fold4, fold5, fold6, fold7, fold8, fold9, fold10]:
	ttest_data = pd.concat([ttest_data, df(fold)], ignore_index=True)

datasets =  ['10pct', '20pct', '30pct', '50pct']
imputers = ['mean', 'median']
alpha = 0.05

for ds in datasets:
	for imputer in imputers:
		current_name = f"{ds}_{imputer}"
		iterative_name = f"{ds}_iterative"

		current_imputer_aucprc = ttest_data[ttest_data['model_name'] == current_name]['AUCPRC'].to_list()
		current_iterative_aucprc = ttest_data[ttest_data['model_name'] == iterative_name]['AUCPRC'].to_list()

		t_stat, p_value = ttest_ind(current_imputer_aucprc, current_iterative_aucprc)
		print("t-test:")
		if p_value < alpha:
			print(f"Reject the null hypothesis: There is a significant difference between the imputers ({current_name}, {iterative_name})")
		else:
			print(f"There is no significant difference between the imputers ({current_name}, {iterative_name})")

		print("mannwhitney test:")
		# Perform Mann-Whitney U test
		u_stat, p_value_mannwhitney = mannwhitneyu(current_imputer_aucprc, current_iterative_aucprc, alternative='two-sided')

		if p_value_mannwhitney < alpha:
			print(f"Reject the null hypothesis: There is a significant difference between the imputers ({current_name}, {iterative_name} (p = {p_value_mannwhitney:.4f}, u_stat = {u_stat:.4f}, alpha = {alpha}, n = {len(current_imputer_aucprc)}))")
		else:
			print(f"There is no significant difference between the imputers ({current_name}, {iterative_name}) (p = {p_value_mannwhitney:.4f}, u_stat = {u_stat:.4f}, alpha = {alpha}, n = {len(current_imputer_aucprc)})")
				
		print("")
# Out:
# t-test:
# There is no significant difference between the imputers (10pct_mean, 10pct_iterative)
# mannwhitney test:
# There is no significant difference between the imputers (10pct_mean, 10pct_iterative) (p = 0.8501, u_stat = 47.0000, alpha = 0.05, n = 10)
#
# t-test:
# There is no significant difference between the imputers (10pct_median, 10pct_iterative)
# mannwhitney test:
# There is no significant difference between the imputers (10pct_median, 10pct_iterative) (p = 0.7337, u_stat = 55.0000, alpha = 0.05, n = 10)
#
# t-test:
# There is no significant difference between the imputers (20pct_mean, 20pct_iterative)
# mannwhitney test:
# There is no significant difference between the imputers (20pct_mean, 20pct_iterative) (p = 0.5708, u_stat = 42.0000, alpha = 0.05, n = 10)
#
# t-test:
# There is no significant difference between the imputers (20pct_median, 20pct_iterative)
# mannwhitney test:
# ...
